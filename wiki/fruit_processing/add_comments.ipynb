# %%
# !ls -l ../interactive_lm/wiki/models/
# Out:
# total 28
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:30 't5-base stage 2 p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:22 't5-base stage 2 p(comment, x_t+1 | x_t, doc)_new'
# drwxrwxr-x 5 shapkin shapkin 4096 Jan 30 07:51 't5-small p(comment | x_t, x_t+1, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  6 10:32 't5-small stage 2 _ 2 losses _ full p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  5 21:28 't5-small stage 2 _ 2 losses p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  7 10:04 't5-small stage 2 p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:10 't5-small stage 2 p(comment, x_t+1 | x_t, doc)_new'

# %%
import os
os.environ['TOKENIZERS_PARALLELISM']='true'
os.environ['CUDA_VISIBLE_DEVICES']='2'

# %%
import re
import os
import torch
import json
import numpy as np
import pandas as pd
import seaborn as sns
import transformers
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from transformers import T5Tokenizer, T5TokenizerFast, T5ForConditionalGeneration
from transformers.tokenization_utils import PreTrainedTokenizer
from transformers.tokenization_utils_fast import PreTrainedTokenizerFast
from typing import Callable, Union, Tuple
from tqdm.notebook import tqdm
from collections import Counter
from torch import nn
from catalyst import dl
from catalyst.callbacks.periodic_loader import PeriodicLoaderCallback
from langdetect import detect
from easse.sari import corpus_sari
from rouge import Rouge 

import sys
sys.path.append('../interactive_lm/wiki')
from utils.dataset_utils import extract_com8text_from_tgt, extract_text8docs_from_src
from utils.dataset_utils import ExplainDataset, get_tgt, get_src, COM_SEP, TEXT_SEP_SRC, TEXT_SEP_TGT, DOCS_SEP
from utils.metrics_utils import PeerEditMetricsCallback
from utils.config import Config


DOCS_DIR = 'data'
PAGES_DIR = 'data'

# %%
CONFIG = Config()
CONFIG.seed = 1337
CONFIG.beam_size = 1

# %%
import random

random.seed(CONFIG.seed)
os.environ['PYTHONHASHSEED'] = str(CONFIG.seed)
np.random.seed(CONFIG.seed)
torch.manual_seed(CONFIG.seed)
torch.cuda.manual_seed(CONFIG.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Data preparing

# %%
train = pd.read_csv(r'train_fruit.csv')

# %%
train.head()
# Out:
#    Unnamed: 0                                          old_texts  \
# 0           0  Daniel R. Lucey is a senior scholar with the O...
# 1           1  Rob Daviau is a prolific American game designe...
# 2           2  North Down is a parliamentary constituency in ...
# 3           3  Chaldean Catholics (; ), also known as Chaldea...
# 4           4  Prevalence of tobacco use is reported by the W...
#
#                                            new_texts  \
# 0  Daniel R. Lucey is an American physician, rese...
# 1  Rob Daviau is an American game designer known ...
# 2  North Down is a parliamentary constituency in ...
# 3  Chaldean Catholics () (), also known as Chalde...
# 4  Prevalence of tobacco use is reported by the W...
#
#                                            doc_texts  \
# 0  DOC0: 2016 Angola and DR Congo yellow fever ou...
# 1  DOC0: Return to Dark Tower Development In addi...
# 2  DOC0: List of parliamentary constituencies in ...
# 3  DOC0: Nusaybin History - Modern history Syrian...
# 4  DOC0: Sustainable Development Goal 3 Targets, ...
#
#                                              titles
# 0  Public Health Emergency of International Concern
# 1                                  Spiel des Jahres
# 2                  Liberalism in the United Kingdom
# 3                               Ibrahim Pasha Milli
# 4                            Heated tobacco product

# %%
train['comment'] = ''
train = train.rename(columns={"old_texts": "old_text", "new_texts": "new_text", "doc_texts": "docs_processed"})

# %%
train['old_text'] = train['old_text'].apply(str)
train['new_text'] = train['new_text'].apply(str)


train.head()
# Out:
#    Unnamed: 0                                           old_text  \
# 0           0  Daniel R. Lucey is a senior scholar with the O...
# 1           1  Rob Daviau is a prolific American game designe...
# 2           2  North Down is a parliamentary constituency in ...
# 3           3  Chaldean Catholics (; ), also known as Chaldea...
# 4           4  Prevalence of tobacco use is reported by the W...
#
#                                             new_text  \
# 0  Daniel R. Lucey is an American physician, rese...
# 1  Rob Daviau is an American game designer known ...
# 2  North Down is a parliamentary constituency in ...
# 3  Chaldean Catholics () (), also known as Chalde...
# 4  Prevalence of tobacco use is reported by the W...
#
#                                       docs_processed  \
# 0  DOC0: 2016 Angola and DR Congo yellow fever ou...
# 1  DOC0: Return to Dark Tower Development In addi...
# 2  DOC0: List of parliamentary constituencies in ...
# 3  DOC0: Nusaybin History - Modern history Syrian...
# 4  DOC0: Sustainable Development Goal 3 Targets, ...
#
#                                              titles comment
# 0  Public Health Emergency of International Concern
# 1                                  Spiel des Jahres
# 2                  Liberalism in the United Kingdom
# 3                               Ibrahim Pasha Milli
# 4                            Heated tobacco product

# %%
CONFIG.src_max_len = 1024
CONFIG.tgt_max_len = 512
CONFIG.pretrained = 't5-small'
CONFIG.pattern_path = './models/t5-small p(comment | x_t, x_t+1, doc)'
CONFIG.batch_size = 4

tokenizer = T5TokenizerFast.from_pretrained(CONFIG.pretrained, model_max_length=CONFIG.src_max_len)

# %% [markdown]
# **Make dataset**

# %%
ds_train = ExplainDataset(train, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
#ds_val = ExplainDataset(val1, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
#ds_val_full = EditDataset(val, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)

# %% [markdown]
# **Len distribution**

# %%
idx_num = 100
src_text = tokenizer.decode(ds_train[idx_num][0]['input_ids'], skip_special_tokens=True)
tgt_text = tokenizer.decode(ds_train[idx_num][1]['input_ids'], skip_special_tokens=True)

# %%
print(f'{src_text}\n\n{tgt_text}')
# Out:
# wycombe wanderers football club is a professional association football club based in the town of high wycombe, buckinghamshire, england. the team play in league one, the third tier of english football. the club plays at adams park, which is situated on the western outskirts of high wycombe, and traditionally play in quartered shirts of navy (oxford blue) and pale blue (cambridge blue). the club's nicknames are "the chairboys" and "the blues". the current manager of the club is gareth ainsworth, who was appointed as player/manager following a period during which he served as caretaker manager, after gary waddock was relieved of his duties following a 1–0 defeat at home to wimbledon on 22 september 2012. ainsworth retired from playing at the end of the 2012–13 season. he is assisted by richard dobson. the club was awarded the family club of the year award twice in a row in 2006–07 and 2007–08. this is the only time that the award has been given to the same club in consecutive seasons. the club received a football league family excellence award after the 2009–10, 2011–12 and 2013–14 seasons. TEXT_SEP wycombe wanderers football club is a professional association football club based in the town of high wycombe, buckinghamshire, england. the team compete in the, the second tier of the english football league system. they play their home matches at adams park, located on the western outskirts of high wycombe, having moved after 95 years at loakes park in 1990. the club traditionally plays in quartered shirts of navy (oxford blue) and pale blue (cambridge blue). the club's nicknames are "the chairboys" and "the blues". founded in 1887, they entered the southern league in 1896. they switched to the great western suburban league in 1908 and then the spartan league in 1919, before joining the isthmian league after winning the spartan league in 1919–20 and 1920–21. they spent 64 years in the isthmian league, winning eight league titles and one fa amateur cup title. having rejected numerous invitations to join the alliance premier (gola) league (now national league), they finally accepted an offer in 1985 and eventually found success in the fifth tier of english football under the management of martin o'neill, winning promotion into the football league as gm vauxhall conference champions in 1992–93. they also lifted the fa trophy in 1991 and 1993, and won the conference league cup, conference shield (three times) and conference charity shield. wycombe made an immediate impact in the football league, winning promotion out of the third division via the play-offs in 1994. they spent a decade in the third tier and reached the fa cup semi-finals in 2001, though were relegated three years later. they also reached the league cup semi-finals in 2007 and then gained promotion out of league two in 2008–09. this was the first of four successive seasons of promotions and relegations between league two and league one, which was followed by a decline that saw the club only avoid relegation into non-league on goal difference in 2014. the club secured promotion out of league two under gareth ainsworth's stewardship in 2017–18, who then took the club to the championship for the first time in the club's history with victory in the 2020 league one play-off final. DOCS_SEP doc0: uche ikpeazu statistics - table-0-17 [header] [col] club [col] season [col] league [col] fa cup [col] league cup [col] other [col] total [row] [col] wycombe wanderers [col] 2020–21 [col] championship [col] 4 [col] 0 [col] 0 [col] 0 [col] 0 [col] 0 [col] 0 [col] 0 [col] 4 [col] 0 doc1: fred onyedinma introduction wilfred oluwafemi onyedinma (born 24 november 1996) is a nigerian professional footballer who plays as a midfielder for championship club wycombe wanderers. doc

# %% [markdown]
# ## Model training

# %%
class EditModel(nn.Module):
    def __init__(self, 
                 pretrained: transformers.modeling_utils.PreTrainedModel, 
                 config: Config):
        super(EditModel, self).__init__()
        self.pretrained = pretrained
        

    def forward(self, 
                x: Tuple[torch.Tensor, torch.Tensor]):
        src, tgt = x
        
        tgt[tgt == 0] == -100
        
        loss = self.pretrained(
            input_ids = src,
            attention_mask = (src != 0).float(),
            labels=tgt,
        ).loss
        return loss
    
    
class Criterion(nn.Module):
    def __init__(self):
        super(Criterion, self).__init__()
        
    def forward(self, pred, tgt):
        return pred

# %%
CONFIG.device = 'cuda'
CONFIG.pattern_path = '../interactive_lm/wiki/models/t5-small p(comment | x_t, x_t+1, doc)'

# %%
model_edit = EditModel(T5ForConditionalGeneration.from_pretrained(CONFIG.pretrained), CONFIG)
model_edit.load_state_dict(
    torch.load(f'{CONFIG.pattern_path}/checkpoints/model.best.pth', 
               map_location=CONFIG.device))
model_edit = model_edit.pretrained
model_edit.to(CONFIG.device)
model_edit.eval()
print('Success')
# Out:
# Success

# %%
from IPython.display import HTML as html_print

def colored(s, color='black'):
    if color == 'green':
        return f'\033[93m {s}'
    if color == 'yellow':
        return f'\033[92m {s}'
    if color == 'red':
        return f'\033[91m {s}'
    if color == 'blue':
        return f'\033[94m {s}'
    if color == 'pink':
        return f'\033[95m {s}'
    if color == 'bold':
        return f'\x1B[1mText {s} \x1b[0m'
    return f'\033[39m {s}'

device = CONFIG.device
CONFIG.beam_size = 3
idx_ = np.random.choice(len(ds_train), 5)

with torch.no_grad():
    for i in idx_:
        src_, tgt_ = ds_train[i]

        generated = model_edit.generate(torch.tensor(src_['input_ids']).view(1,-1).to(device), 
                                                      num_beams=CONFIG.beam_size, 
#                                                       pad_token_id=tokenizer.pad_token_id, 
#                                                       bos_token_id=tokenizer.bos_token_id, 
#                                                       eos_token_id=tokenizer.eos_token_id,
                                                          num_return_sequences=1,
                                                     max_length=512)
        generated = generated.cpu()

        src_text = tokenizer.decode(src_['input_ids'], skip_special_tokens=True)
        tgt_text = tokenizer.decode(tgt_['input_ids'], skip_special_tokens=True)
        
        print(colored(f'\n\n---------- QUERY {i} ----------', 'red'))
        print(colored(f'SRC:\n', 'pink') + colored(src_text) + '\n', sep='')
        print(colored(f'TGT:\n', 'pink') + colored(tgt_text) + '\n', sep='')

        for j in range(1):
            to_gen = generated[j]
            gen_text = tokenizer.decode(to_gen, skip_special_tokens=True)
            print(colored(f'GEN:', 'blue') + colored(gen_text) + '\n', sep='')
    
        #diff = ds_train.iloc[i]['diff']
        #print(colored(f'Tgt diff:\n', 'bold') + colored(diff) + '\n', sep='')
# Out:
#
#
# ---------- QUERY 3223 ----------
#  SRC:
#  ''the head'' began as mini-series that originally ran under the title ''mtv's oddities'', on mtv between 1994 and 1996. it has begun airing on mtv2 in august 2009. it was released on dvd on december 15, 2009. TEXT_SEP ''the head'' is an american adult animated television series created by eric fogel for mtv. it originated as a science-fiction mini-series that aired under the ''mtv's oddities'' label between 1994 and 1996, and was followed by ''the maxx''. the was released on dvd on december 15, 2009. DOCS_SEP doc0: list of adult animated television series 1990s - united states - table-0-8 [header] [col] title [col] genre [col] seasons/episodes [col] show creator(s) [col] original release [col] network [col] studio [col] age rating [col] status [row] [col] ''the head'' [col] • action • adventure [col] 2 seasons, 14 episodes [col] eric fogel [col] september 1, 1994 – march 1, 1996 [col] mtv [col] mtv animation [col] tv-14 [col] ended doc1: mtv animation productions - television series - 1990s - table-0-3 [header] [col] ''liquid television'' [col] japhet asher [col] june 2, 1991may 15, 2014 [col] march 6, 1994june 12, 2014 [col] original series:(colossal) picturesbig picturesnoyes & laybourne enterprisesbbc enterprisesrevival series:titmouse, inc. [col] revived for the internet in 2014. [row] [col] ''the head'' [col] eric fogel [col] september 1, 1994 [col] march 1, 1996 [col] [col] doc2: 1996 in american television television programs - ending this year - table-0-14 [header] style="background:#ccc;" [col] date [col] show [col] debut [row] [col] march 1 [col] ''the head'' [col] 1994 doc3: list of animated television series of 1994 introduction - table-0-41 [caption] animated television series first aired in 1994 [row] [col] ''the head'' [col] 2 [col] 14 [col] us [col] 1994–1996 [col] mtv [col] traditional doc4: teletoon at night programming - acquired series - table-0-25 [header] [col] title [col] premiere date [col] reruns [col] source(s) [row] [col] ''the head'' [col] prime [col] reruns [col] doc5: history of animation 1990s other 1990s cartoon series on mtv included ''the head'' (1994-1996) and ''the maxx'' (1995), both under the ''mtv's oddities'' banner. doc6: list of superhero television series animated - table-0-160 [header] [col] title [col] year(s) [col] publisher [col] network [col] notes [row] [col] ''the head'' [col] 1994–1996 [col] original [col] mtv [col] doc7: chris reilly filmography - television - table-0-1 [header] [col] [col] title [col] role [col] notes [row] [col] 2020 [col] ''the head'' [col] nils hedlund [col] doc8: mike judge filmography - television - table-0-4 [header] [col] year [col] title [col] functioned as [col] notes [row] [col] 1994 [col] ''the head'' [col] [col] [col] [col] [col] butt-head (voice) [col] episode: "the head/the date"
#
#  TGT:
#
#
#  GEN: /* release */ tense
#
#
#
# ---------- QUERY 57533 ----------
#  SRC:
#  2201 oljato, provisional designation, is a stony and extremely eccentric asteroid and sizable near-earth object of the apollo group, approximately 2 kilometers in diameter. it has an earth minimum orbit intersection distance of and is associated with the beta taurids daytime meteor shower. TEXT_SEP 2201 oljato, provisional designation, is a stony and extremely eccentric active asteroid and sizable near-earth object of the apollo group, approximately 2 kilometers in diameter. it has an earth minimum orbit intersection distance of and is associated with the beta taurids daytime meteor shower. DOCS_SEP doc0: active asteroid members - table-0-3 [header] ---- [col] name [col] semi-major axis (au) [col] perihelion (au) [col] diameter (km) [col] cause [row] [col] 2201 oljato [col] 2.18 [col] 0.62 [col] 1.8 [col] outgassing
#
#  TGT:
#
#
#  GEN: added "active" to description of the subject.
#
#
#
# ---------- QUERY 99164 ----------
#  SRC:
#  ding junhui (; born 1 april 1987) is a chinese professional snooker player who has been considered the most successful asian player in the history of the sport. throughout his career, he has won 13 major ranking titles, including two uk championships in 2005 and 2009, two shanghai masters titles in 2013 and 2016, and one german masters title in 2014. he has also twice reached the final of the masters, winning once in 2011. representing china at the asian games, ding has won five gold medals in individual and team events. in 2016, he became the first asian player to reach the final of the world championship. the same year, he won his first six-red world championship. ding began playing snooker at age nine and rose to international prominence in 2002 after winning the asian under-21 championship, the asian championship. at age 15, he became the youngest winner of the ibsf world under-21 championship. in 2003, ding turned professional at the age of 16. his first major professional successes came in 2005 when he won the china open and the uk championship, becoming the first player from outside great britain and ireland to win the title. in the 2013/2014 season, ding tied stephen hendry's record of winning five ranking titles in a single season. during his career, ding—who is known as a prolific break-builder—has compiled more than 500 century breaks, including six maximum breaks, in professional play. he was the first and only asian player to be ranked world number one, which he first achieved in 2014 to become the 11th player to reach the top spot. aside from snooker, ding enrolled at shanghai jiao tong university in 2006 to study business administration and management. he is a long-time resident of sheffield, england, and practices at the english institute of sport. TEXT_SEP ding junhui (; born 1 april 1987) is a chinese professional snooker player who has been considered the most successful asian player in the history of the sport. throughout his career, he has won 14 major ranking titles, including three uk championships in 2005, 2009, and 2019; two shanghai masters titles in 2013 and 2016; and one german masters title in 2014. he has also twice reached the final of the masters, winning once in 2011. representing china at the asian games, ding has won five gold medals in individual and team events. in 2016, he became the first asian player to reach the final of the world championship. the same year, he won his first six-red world championship. ding began playing snooker at age nine and rose to international prominence in 2002 after winning the asian under-21 championship and the asian championship. at age 15, he became the youngest winner of the ibsf world under-21 championship. in 2003, ding turned professional at the age of 16. his first major professional successes came in 2005 when he won the china open and the uk championship, becoming the first player from outside great britain and ireland to win the title. during his career, ding—who is known as a prolific break-builder—has compiled more than 500 century breaks, including six maximum breaks, in professional play. he was the first and only asian player to be ranked world number one, which he first achieved in 2014 to become the 11th player to reach the top spot. aside from snooker, ding enrolled at shanghai jiao tong university in 2006 to study business administration and management. he is a long-time resident of sheffield, england, and practices at the english institute of sport. DOCS_SEP doc0: 2019–20 snooker season calendar - table-0-21 [header] [col] date [col] country [col] rank [col] tournament name [col] venue [col] city [col] winner [col] runner-up [col] score [col] [row] [col] 11-26 [col] 12-08 [col] [col] wr [col] uk championship [col] barbican centre [col] york [col] ding junhui [col] stephen maguire [col] 10–6 [col] doc1: 2020 uk championship introduction the
#
#  TGT:
#
#
#  GEN: ding has now won 14 major ranking titles.
#
#
#
# ---------- QUERY 9448 ----------
#  SRC:
#  "" (; in peace and joy i now depart) is a hymn by martin luther, a paraphrase in german of the, the canticle of simeon. luther wrote the text and melody in 1524 and it was first published in the same year. originally a song for purification, it has been used for funerals. luther included it in 1542 in'(christian chants... for funeral). the hymn appears in several translations, for example catherine winkworth's "in peace and joy i now depart", in nine hymnals. it has been used as the base for music, especially for vocal music such as dieterich buxtehude's funeral music and johann sebastian bach's chorale cantata. TEXT_SEP "" (; in peace and joy i now depart) is a hymn by martin luther, a paraphrase in german of the, the canticle of simeon. luther wrote the text and melody, zahn no. 3986, in 1524 and it was first published in the same year. originally a song for purification, it has been used for funerals. luther included it in 1542 in'(christian chants... for funeral). the hymn appears in several translations, for example catherine winkworth's "in peace and joy i now depart", in nine hymnals. it has been used as the base for music, especially for vocal music such as dieterich buxtehude's funeral music and johann sebastian bach's chorale cantata. DOCS_SEP doc0: bach cantata bach cantatas listed in the first chapter of the ''bach-werke-verzeichnis'' (1998) | cantata ''gottes zeit ist die allerbeste zeit'' (funeral; aka ''actus tragicus'') | e maj. | data-sort-value="satbsatb flx2 vdgx2 bc" | satbsatb 2fl 2vdg bc | data-sort-value="000.23: 147" | 23: 147 | data-sort-value="i/34: 001" | i/34: 1 | after z 1680 (/2d), 3986 (/3b), 2461 (/4); text after [[johann olearius|olearius, j. doc1: bach cantata bach cantatas listed in the first chapter of the ''bach-werke-verzeichnis'' (1998) | rowspan="2" | 1724-02-02 | cantata ''erfreute zeit im neuen bunde'' (purification) | f maj. | data-sort-value="atbsatb hnx2 obx2 vl str bc" | atbsatb 2hn 2ob vl str bc | data-sort-value="000.20 1: 051" | 201: 51 | data-sort-value="i/28 1: 003" | i/28.1: 3 | after z 3986 (/5); text after lk 2:29-31 (/2), hb 4:16 (/3), by luther (/5) | |- style="background: #e3f6ce;" | data-sort-value="0083.005" | 83/5 | chorale setting "mit fried und freud ich fahr dahin" (s. 4) | d min. doc2: dietel manuscript content - table-1-49 [caption] four-part chorales in the dietel manuscript [header] [col] # [col] title (in dietel manuscript) [col] zahn [col] bwv [col] occasion [col] year [col] m-d [col] other info [row] [col] [http://www.bach-chorales.com/bwv0382.htm 51] [col] mit fried und freud ich fahr dahin [col] 3986 [col] [https://www.
#
#  TGT:
#
#
#  GEN: /* top */ zahn no. 3986
#
#
# ---------- QUERY 85159 ----------
#  SRC:
#  ''the special london bridge special'' is a 1972 musical variety special. it was made to celebrate the acquisition of the london bridge in lake havasu city, arizona. it was filmed in lake havasu following the opening of the london bridge. it was produced, directed and choreographed by david winters and it starred tom jones, and jennifer o'neill. other guests included the carpenters, kirk douglas, jonathan winters, hermione gingold, lorne greene, chief dan george, charlton heston, george kirby, michael landon, terry-thomas, engelbert humperdinck, elliott gould, merle park, and rudolf nureyev. TEXT_SEP ''the special london bridge special'' is a 1972 musical variety television special. it was made to celebrate the acquisition of the london bridge in lake havasu city, arizona. it was filmed in lake havasu following the opening of the london bridge. it was produced, directed and choreographed by david winters and it starred tom jones and jennifer o'neill. other guests included the carpenters, kirk douglas, jonathan winters, hermione gingold, lorne greene, chief dan george, charlton heston, george kirby, michael landon, terry-thomas, engelbert humperdinck, elliott gould, merle park, and rudolf nureyev. DOCS_SEP doc0: chief dan george acting career - 1971–1981: subsequent success in 1972, he was a guest in david winters' musical television special ''the special london bridge special'', starring tom jones, and jennifer o'neill. doc1: kirk douglas career - 1970s–2020 in 1972, he was a guest on david winters' television special ''the special london bridge special'', starring tom jones. doc2: tom jones (singer) career - 1970s and 1980s decline in 1972, he reunited with director and choreographer david winters for the musical television special ''the special london bridge special'', co-starring jennifer o'neill. doc3: charlton heston filmography television - 1961–1980 - table-0-13 [header] style="background:#b0c4de;" [col] date [col] title [col] episode [col] role [row] [col] may 7, 1972 [col] ''the special london bridge special'' [col] (tv special) [col] tennis player doc4: kirk douglas filmography filmography - table-0-58 [header] [col] year [col] title [col] role [col] notes [row] [col] ''the special london bridge special'' [col] the indian fighter [col] tv movie
#
#  TGT:
#
#
#  GEN: added "television special"

# %%
generated_comments = []

for i in tqdm(range(len(ds_train))):
    src_, tgt_ = ds_train[i]

    generated = model_edit.generate(torch.tensor(src_['input_ids']).view(1,-1).to(device), 
                                                  num_beams=CONFIG.beam_size, 
#                                                       pad_token_id=tokenizer.pad_token_id, 
#                                                       bos_token_id=tokenizer.bos_token_id, 
#                                                       eos_token_id=tokenizer.eos_token_id,
                                                      num_return_sequences=1,
                                                 max_length=512)
    generated = generated.cpu()

    src_text = tokenizer.decode(src_['input_ids'], skip_special_tokens=True)
    tgt_text = tokenizer.decode(tgt_['input_ids'], skip_special_tokens=True)

    #print(colored(f'\n\n---------- QUERY {i} ----------', 'red'))
    #print(colored(f'SRC:\n', 'pink') + colored(src_text) + '\n', sep='')
    #print(colored(f'TGT:\n', 'pink') + colored(tgt_text) + '\n', sep='')

    for j in range(1):
        to_gen = generated[j]
        gen_text = tokenizer.decode(to_gen, skip_special_tokens=True)
        # print(colored(f'GEN:', 'blue') + colored(gen_text) + '\n', sep='')
        generated_comments.append(gen_text)
# Out:
#   0%|          | 0/114515 [00:00<?, ?it/s]

# %%
ds_train['generated_comment'] = generated_comments

# %%
ds_train.to_csv('train_fruit_full.csv')

# %%
ds_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_305471/3540012213.py in <module>
# ----> 1 ds_train.head()
#
# AttributeError: 'ExplainDataset' object has no attribute 'head'

# %%
train['generated_comment'] = generated_comments
train.to_csv('train_fruit_full.csv')

# %%
train.head()
# Out:
#    Unnamed: 0                                           old_text  \
# 0           0  Daniel R. Lucey is a senior scholar with the O...
# 1           1  Rob Daviau is a prolific American game designe...
# 2           2  North Down is a parliamentary constituency in ...
# 3           3  Chaldean Catholics (; ), also known as Chaldea...
# 4           4  Prevalence of tobacco use is reported by the W...
#
#                                             new_text  \
# 0  Daniel R. Lucey is an American physician, rese...
# 1  Rob Daviau is an American game designer known ...
# 2  North Down is a parliamentary constituency in ...
# 3  Chaldean Catholics () (), also known as Chalde...
# 4  Prevalence of tobacco use is reported by the W...
#
#                                       docs_processed  \
# 0  DOC0: 2016 Angola and DR Congo yellow fever ou...
# 1  DOC0: Return to Dark Tower Development In addi...
# 2  DOC0: List of parliamentary constituencies in ...
# 3  DOC0: Nusaybin History - Modern history Syrian...
# 4  DOC0: Sustainable Development Goal 3 Targets, ...
#
#                                              titles comment  \
# 0  Public Health Emergency of International Concern
# 1                                  Spiel des Jahres
# 2                  Liberalism in the United Kingdom
# 3                               Ibrahim Pasha Milli
# 4                            Heated tobacco product
#
#                                    generated_comment
# 0                                  copyedits, wikify
# 1  daviau is not credited as the designer of over...
# 2                                             update
# 3                               reworded intro a bit
# 4              /* prevalence */ reword who reference

# %%
train.shape
# Out:
# (114515, 7)

# %%
import pandas as pd

a = pd.read_csv('train_fruit_full.csv')

# %%
a.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                             old_text  \
# 0  Daniel R. Lucey is a senior scholar with the O...
# 1  Rob Daviau is a prolific American game designe...
# 2  North Down is a parliamentary constituency in ...
# 3  Chaldean Catholics (; ), also known as Chaldea...
# 4  Prevalence of tobacco use is reported by the W...
#
#                                             new_text  \
# 0  Daniel R. Lucey is an American physician, rese...
# 1  Rob Daviau is an American game designer known ...
# 2  North Down is a parliamentary constituency in ...
# 3  Chaldean Catholics () (), also known as Chalde...
# 4  Prevalence of tobacco use is reported by the W...
#
#                                       docs_processed  \
# 0  DOC0: 2016 Angola and DR Congo yellow fever ou...
# 1  DOC0: Return to Dark Tower Development In addi...
# 2  DOC0: List of parliamentary constituencies in ...
# 3  DOC0: Nusaybin History - Modern history Syrian...
# 4  DOC0: Sustainable Development Goal 3 Targets, ...
#
#                                              titles  comment  \
# 0  Public Health Emergency of International Concern      NaN
# 1                                  Spiel des Jahres      NaN
# 2                  Liberalism in the United Kingdom      NaN
# 3                               Ibrahim Pasha Milli      NaN
# 4                            Heated tobacco product      NaN
#
#                                    generated_comment
# 0                                  copyedits, wikify
# 1  daviau is not credited as the designer of over...
# 2                                             update
# 3                               reworded intro a bit
# 4              /* prevalence */ reword who reference

# %%
import difflib

from IPython.display import HTML as html_print

def colored(s, color='black'):
    if color == 'green':
        return f'\033[93m {s}'
    if color == 'yellow':
        return f'\033[92m {s}'
    if color == 'red':
        return f'\033[91m {s}'
    if color == 'blue':
        return f'\033[94m {s}'
    if color == 'pink':
        return f'\033[95m {s}'
    if color == 'bold':
        return f'\x1B[1m {s} \x1b[0m'
    return f'\033[39m {s}'

def diff_print(src_text, tgt_text):
    src_text_tok, tgt_text_tok = src_text.split(), tgt_text.split()
    matcher = difflib.SequenceMatcher(a=src_text_tok, b=tgt_text_tok)
    
    sti = []
    cur_idx = 0
    for match in matcher.get_matching_blocks():
        if match.size != 0:
            if match.b == cur_idx:
                sti.append((match.b, match.b + match.size, 'same'))
                cur_idx = match.b + match.size
            else:
                sti.append((cur_idx, match.b, 'diff'))
                sti.append((match.b, match.b + match.size, 'same'))
                cur_idx = match.b + match.size
    if cur_idx < len(tgt_text_tok) - 1:
        sti.append((cur_idx, len(tgt_text_tok), 'diff'))
    
    new_str = ''
    for (st_id, en_id, idxs_type) in sti:
        cur_txt = ' '.join(tgt_text_tok[st_id:en_id])
        if idxs_type != 'same':
            new_str += colored(cur_txt, color='bold') + ' '
        else:
            new_str += cur_txt + ' '
    return new_str

# %%
import numpy as np

idx_ = np.random.choice(len(a), 20)

for i in idx_:
    src_txt = a.iloc[i]['old_text']
    tgt_txt = a.iloc[i]['new_text']
    tgt_comment = a.iloc[i]['generated_comment']
    docs_processed = a.iloc[i]['docs_processed'].lower()
    src_txt = diff_print(tgt_txt, src_txt)
    tgt_txt = diff_print(src_txt, tgt_txt)

    print(colored(f'\n\n---------- QUERY {i} ----------', 'red'))
    print(colored(f'X_t:\n', 'pink') + colored(src_txt) + '\n', sep='')
    print(colored(f'X_t+1:\n', 'pink') + colored(tgt_txt) + '\n', sep='')
    print(colored(f'Comment:', 'yellow') + colored(tgt_comment) + '\n', sep='')

    doc_str = '\n'.join(docs_processed.split('doc'))
    print(colored(f'Docs:\n', 'yellow') + colored(doc_str) + '\n', sep='')
# Out:
#
#
# ---------- QUERY 76138 ----------
#  X_t:
#  Drumstick is the brand name, owned by Nestlé  since 1991,  for a variety of frozen dessert-filled ice cream cones sold in the United States, Australia, Canada, Malaysia, and other countries across the world. The original product was invented by I.C. Parker of the Drumstick Company of Fort Worth, Texas, in 1928.
#
#  X_t+1:
#  Drumstick is the brand name, owned by  Froneri, a joint venture between  Nestlé  and PAI Partners,  for a variety of frozen dessert-filled ice cream cones sold in the United States, Australia, Canada, Malaysia, and other countries across the world. The original product was invented by I.C. Parker of the Drumstick Company of Fort Worth, Texas, in 1928.
#
#  Comment: changed from 1991 to froneri, a joint venture between nestlé and pai partners.
#
#  Docs:
#
# 0: dreyer's introduction in 2020, froneri, the joint venture between nestlé and pai partners, agreed to take over all of nestlé's us ice cream businesses, including dreyer's, häagen-dazs, and drumstick.
# 1: dreyer's history in december 2019, nestle announced that it will be selling all of its usa ice cream businesses, including dreyer's, häagen-dazs, and drumstick, to froneri, the global ice cream manufacturer that nestlé co-owns with pai partners.
# 2: froneri history on 11 december, 2019, froneri announced that it will expand into the lucrative north american market with the acquisition of nestle usa's ice cream division for $4 billion usd which includes iconic brands such as dreyer's, häagen-dazs and drumstick.
# 3: dreyer's history - timeline *2020: nestle sells all of its us ice cream businesses, including dreyer's, häagen-dazs, and drumstick to froneri for $4 billion.
# 4: peters ice cream history pacific dunlop sold its food assets in the mid-1990s, and the ice-cream division was acquired by nestlé, which continued to market brands including choc-wedge, drumstick, and monaco bar.
# 5: joel turner (musician) introduction he has also appeared in several television commercials, most famously for drumstick loaded ice cream.
#
#
#
# ---------- QUERY 31143 ----------
#  X_t:
#  The Arctic oscillation (AO) or Northern Annular Mode/Northern Hemisphere Annular Mode (NAM) is a weather phenomenon at the Arctic  and Antarctic  poles north  (or south)  of 20 degrees latitude. The index varies over time with no particular periodicity, and is characterized by non-seasonal sea-level pressure anomalies of one sign in the Arctic, balanced by anomalies of opposite sign centered at about  37–45N.  The North Atlantic oscillation (NAO) is a close relative of the  AO.  There is debate over whether one or the other is more fundamentally representative of the atmosphere's dynamics. The NAO may be identified in a more physically meaningful way, which may carry more impact on measurable effects of changes in the atmosphere.
#
#  X_t+1:
#  The Arctic oscillation (AO) or Northern Annular Mode/Northern Hemisphere Annular Mode (NAM) is a weather phenomenon at the Arctic poles north of 20 degrees latitude.  It is an important mode of climate variability for the Northern Hemisphere. The southern hemisphere analogue is called the Antarctic oscillation or Southern Annular Mode (SAM).  The index varies over time with no particular periodicity, and is characterized by non-seasonal sea-level pressure anomalies of one sign in the Arctic, balanced by anomalies of opposite sign centered at about  37–45° N.  The North Atlantic oscillation (NAO) is a close relative of the  Arctic oscillation.  There is debate over whether one or the other is more fundamentally representative of the atmosphere's dynamics. The NAO may be identified in a more physically meaningful way, which may carry more impact on measurable effects of changes in the atmosphere.
#
#  Comment: it is an important mode of [[climate variability]] for the [[north hemisphere]]
#
#  Docs:
#
# 0: climate variability and change causes - internal variability - oscillations and cycles the northern annular mode or arctic oscillation (ao) in the northern hemisphere, and the southern annular mode or antarctic oscillation (aao) in the southern hemisphere.
# 1: climate variability and change causes - internal variability - oscillations and cycles * the arctic oscillation (ao) and antarctic oscillation (aao) – the annular modes are naturally occurring, hemispheric-wide patterns of climate variability.
# 2: trade winds weather and biodiversity effects when the phase of the arctic oscillation (ao) is warm, trade winds are stronger within the tropics.
# 3: 1257 samalas eruption climate effects - climate effects * warmer winters in the northern hemisphere continents owing to changes in the polar vortex and the arctic oscillation.
# 4: westerlies behaviour this occurs when the arctic oscillation is positive, and during winter low pressure near the poles is stronger than it would be during the summer.
# 5: geography of toronto climate this is determined by a number of complex global weather drivers, such as enso, noa/ao oscillations and the polar vortex.
# 6: meteorological history of hurricane sandy effect of climate change this typical pattern was blocked by a ridge of high pressure over greenland, resulting in a negative arctic oscillation, forming a kink in the jet stream and causing it to double back on itself off the east coast; sandy was caught up in this northwesterly flow.
#
#
#
# ---------- QUERY 39630 ----------
#  X_t:
#  Djair Terraii Carl Parfitt-Williams (born 1 October 1996) is a professional footballer who plays  for Rudar Velenje  as a
#
#  X_t+1:
#  Djair Terraii Carl Parfitt-Williams (born 1 October 1996) is a professional footballer who plays as a  forward for Icelandic side Fylkir.
#
#  Comment: transfer updated with soccerway
#
#  Docs:
#
# 0: west ham united f.c. under-23s and academy notable players - first team graduates since 2000 - table-0-38 [header] [col] player [col] position [col] west ham appearances [col] west ham goals [col] current club [col] born [col] international honours [col] debut [col] manager [row] [col] djair parfitt-williams [col] st [col] 2 [col] 0 [col] fylkir [col] hamilton [col] [col] age 18 vs. lusitanos, europa league, 2 july 2015 [col] slaven bilić
#
#
#
# ---------- QUERY 66203 ----------
#  X_t:
#  D.A.R.K. is an alternative rock band formed in New York City in early 2009. It was initially founded under the name Jetlag by Olé Koretsky and former Smiths bassist Andy Rourke. In April 2014, the band began recording new material with Cranberries vocalist Dolores O'Riordan, and they subsequently changed their name to D.A.R.K.  Since O’Riordan's death  on January 15,  2018, no announcement has been made concerning the future of the band.
#
#  X_t+1:
#  D.A.R.K. is an alternative rock band formed in New York City in early 2009. It was initially founded under the name Jetlag by Olé Koretsky and former  The  Smiths bassist Andy Rourke. In April 2014, the band began recording new material with  The  Cranberries vocalist Dolores O'Riordan, and they subsequently changed their name to D.A.R.K.  The album, titled ''Science Agrees'', was released on September 9, 2016 through Cooking Vinyl. In 2017, Koretsky teamed with DJ Wool under the D.A.R.K. name to tour as an opening act for The Cranberries. O’Riordan died as a result of accidental drowning  on January 15,
#
#  Comment: /* top */ added details about the release of the album.
#
#  Docs:
#
# 0: cooking vinyl artists - current *47soul
# *'68
# *adam cohen
# *area 11
# *ali campbell
# *alison moyet
# *amanda palmer
# *babymetal
# *billy bragg
# *black spiders
# *the bronx
# *calling all cars
# *camper van beethoven
# *carl barât and the jackals
# *chas & dave
# *city and colour
# *dam
# *d.a.r.k.
# 1: dolores o'riordan career - 2013–2018: the voice of ireland and ''something else'' they then formed a trio under the name d.a.r.k.
# 2: the cranberries introduction she had recently arrived in london for a studio mixing session on her d.a.r.k.
#
#
#
# ---------- QUERY 18810 ----------
#  X_t:
#  This is the list of total 37 cities and towns in Kosovo, listed by population according to the data of 2011 census. The capital city of Pristina is also the largest city, with a population of 145,149 people. Kosovo's second largest city is Prizren, followed by Gjilan,  Peć,  Mitrovica, Ferizaj and Gjakova. There are six cities/towns with 10,000–30,000 inhabitants and 24 with under 10,000 inhabitants.
#
#  X_t+1:
#  This is the list of total 37 cities and towns in Kosovo, listed by population according to the data of 2011 census. The capital city of Pristina is also the largest city, with a population of 145,149 people. Kosovo's second largest city is Prizren, followed by Gjilan,  Peja,  Mitrovica, Ferizaj and Gjakova. There are six cities/towns with 10,000–30,000 inhabitants and 24 with under 10,000 inhabitants.
#
#  Comment: pe -> peja
#
#  Docs:
#
# 0: kosovo demography - table-0-4 [header] [col] largest municipalities by population (2015) [row] 4 peja [col] 97,890 14 lipljan [col] 56,643
# 1: kosovo demography - table-0-6 [header] [col] largest municipalities by population (2015) [row] 6 podujevo [col] 83,425 16 vitina [col] 46,742
# 2: drenas introduction drenas (also known as ''gllogoc'' in albanian or ), is a town and municipality located in the pristina district in central kosovo.
# 3: kosovo demography - table-0-11 [header] [col] largest municipalities by population (2015) [row] [col]
# 4: kosovo demography - table-0-1 [header] [col] largest municipalities by population (2015) [row] 1 pristina [col] 204,721 11 suva reka [col] 59,681
# 5: kosovo demography - table-0-10 [header] [col] largest municipalities by population (2015) [row] 10 drenas [col] 60,175 20 kosovo polje [col] 37,048
# 6: kosovo demography - table-0-9 [header] [col] largest municipalities by population (2015) [row] 9 vučitrn [col] 64,578 19 klina [col] 39,208
# 7: kosovo demography - table-0-2 [header] [col] largest municipalities by population (2015) [row] 2 prizren [col] 186,986 12 orahovac [col] 58,908
# 8: kosovo demography - table-0-5 [header] [col] largest municipalities by population (2015) [row] 5 gjakova [col] 94,543 15 skenderaj [col] 51,746
# 9: kosovo demography - table-0-8 [header] [col] largest municipalities by population (2015) [row] 8 gjilan [col] 80,525 18 istok [col] 39,604
# 10: kosovo demography - table-0-7 [header] [col] largest municipalities by population (2015) [row] 7 mitrovica [col] 80,623 17 deçan [col] 41,173
# 11: kosovo demography - table-0-0 [header] [col] largest municipalities by population (2015) [row] [col] pristina
# prizren [col] rank [col] municipality [col] population [col] rank [col] municipality [col] population [col] ferizaj
# gjakova
# 12: kosovo demography - table-0-3 [header] [col] largest municipalities by population (2015) [row] 3 ferizaj [col] 101,174 13 mališevo [col] 57,301
# 13: kosovo demography municipalities of kosovo are largely rural, with only eight municipalities having more than 40,000 inhabitants living in the urban areas.
#
#
#
# ---------- QUERY 29232 ----------
#  X_t:
#  Reva Kay Williams is an American astrophysicist at the University of Toledo. She is generally considered to be the first  African-American  woman to  become  a  theoretical astrophysicist.  She is the first person to successfully work out the Penrose mechanism to extract energy from black holes. The Penrose mechanism uses Einstein's general theory of relativity to extract energy from the ergosphere of a rotating black hole.
#
#  X_t+1:
#  Reva Kay Williams is an American astrophysicist at the University of Toledo. She is generally considered to be the first  Black-American  woman to  receive  a  PhD in astrophysics.  She is  also  the first person to successfully work out the Penrose mechanism to extract energy from black holes. The Penrose mechanism uses  Albert  Einstein's general theory of relativity to extract energy from the ergosphere of a rotating black hole.
#
#  Comment: phd in astrophysics
#
#  Docs:
#
# 0: lynnae quick education her high school physics teacher, john brown, encouraged her interests, suggesting she pursue a post-graduate degree in astronomy or astrophysics, and connected her with astrophysicist reva williams who also encouraged her to pursue a ph.d. quick received her bachelor of science degree in physics from north carolina a&t state university in 2005, graduating summa cum laude.
#
#
#
# ---------- QUERY 55812 ----------
#  X_t:
#  ''Phenomenon'' is the third studio album by the British rock band UFO, released in May 1974.
#
#  X_t+1:
#  ''Phenomenon'' is the third studio album by the British rock band UFO, released in May 1974.  It is the band's first release to feature lead guitarist Michael Schenker, who replaced Mick Bolton.
#
#  Comment: added michael schenker ref
#
#  Docs:
#
# 0: michael schenker discography - table-0-2 [header] [col] year [col] band [col] title [col] notes [row] [col] 1974 [col] ufo [col] ''phenomenon'' [col]
# 1: hipgnosis work - table-0-102 [header] [col] year [col] artist [col] album [row] [col] ufo [col] ''phenomenon''
#
#
#
# ---------- QUERY 17974 ----------
#  X_t:
#  ''The Incredibles'' is an action-adventure video game based on  the  2004 film of the same name  by Disney  and  Pixar. The game's music was composed  by  Michael Giacchino, who also scored  the  film.  Samuel L. Jackson (Frozone/Lucius Best), Spencer Fox (Dash), Sarah Vowell (Violet), and Jason Lee  (young Buddy Pine;  Syndrome is absent from the game on the console and PC versions aside from scenes directly taken from the film) are the only actors to reprise their roles from the film, with the rest of the cast, including Craig T. Nelson and Holly Hunter, being replaced with other voice actors - the original movie dialogue and can be heard in cutscenes taken directly from the film.
#
#  X_t+1:
#  ''The Incredibles'' is an action-adventure video game based on  Pixar's  2004 film of the same name  and published  by  THQ. The GameCube, PlayStation 2,  and  Xbox versions were developed  by  Heavy Iron Studios, while Beenox handled  the  Windows and Mac OS X versions.  Samuel L. Jackson (Frozone/Lucius Best), Spencer Fox (Dash), Sarah Vowell (Violet), and Jason Lee  (Buddy Pine/Incrediboy;  Syndrome is absent from the game on the console and PC versions aside from scenes directly taken from the film) are the only actors to reprise their roles from the film, with the rest of the cast, including Craig T. Nelson and Holly Hunter, being replaced with other voice actors - the original movie dialogue and can be heard in cutscenes taken directly from the film.  The game's music was composed by Michael Giacchino, who also scored the film.
#
#  Comment: updated the names of the games developed by thq and mac os x
#
#  Docs:
#
# 0: list of renderware games introduction - table-0-230 [caption] |- [header] [col] game [col] year [col] platform(s) [col] publisher/developer [row] [col] ''the incredibles'' [col] 2004 [col] mac os x, gamecube, playstation 2, windows, xbox [col] thq, heavy iron studios
# 1: list of playstation 2 games (a–k) games list (a–k) - table-0-1642 [header] [col] title [col] developer [col] publisher [col] first released [col] jp [col] eu / pal [col] na [row] [col] ''the incredibles'' [col] heavy iron studios [col] thqeu,na, d3 publisherjp [col] 2004-10-31na [col] ✔ [col] ✔ [col] ✔
# 2: list of best-selling playstation 2 video games list - table-0-156 [header] [col] [col] game [col] copies sold [col] release date [col] genre(s) [col] developer(s) [col] publisher(s) [row] [col] 157 [col] ''the incredibles'' [col] [col] [col] action-adventure [col] heavy iron studios [col] thq
# 3: beenox games developed - ports - table-0-10 [header] [col] year [col] game [col] platform(s) [row] [col] ''the incredibles'' [col] microsoft windows, mac os x
# 4: list of thq games published titles - table-0-385 [caption] !title [header] [col] platform(s) [col] release date [col] developer(s) [col] ref. [row] [col] ''the incredibles'' [col] mac os [col] [col] beenox [col]
# 5: list of best-selling game boy advance video games list - table-1-28 [header] [col] 1 [col] ''pokémon ruby'' and ''sapphire'' [col] game freak [col] [col] [col] 16,220,000 [col] [row] [col] 30 [col] ''the incredibles'' [col] helixe [col] thq [col] [col] 1,366,000 [col]
# 6: list of samuel l. jackson performances video games - table-0-0 [caption] [header] [col] year [col] title [col] role [col] notes [col] [row] [col] 2004 [col] ''the incredibles'' [col] [col]
# 7: 2004 in video games notable releases - table-0-183 [caption] notable releases of the year ''2004'' [header] [col] release [col] title [col] pc [col] 5th gen [col] 6th gen [col] handheld [row] [col] october 29 [col] ''the incredibles (video game)'' [col] windows [col] [col] [col]
# 8: wallace shawn filmography - video games - table-0-2 [header] [col] year [col] title [col] voice role [col] notes [row] [col] 2004 [col] ''the incredibles'' [col] gilbert huph [col] archive recordings
# 9: list of game boy advance games introduction - table-2-596 [header] #coding [col] title(s) [col] multiplayer [col] year(s) released [col] developer(s) [col] publisher(s) [col] region(s) released [row] [col] ''the incredibles''•''mr. incredible''jp [col] yes [col] 2004 [col] helixe [col] thq [col] na, pal, jp
# 10: e. g. daily filmography - video games - table-0-12 [header] [col] year [col] video game [col] role [col] notes [row] [col] 2004 [col] ''the incredibles'' [col] helen parr/elastigirl [col]
# 11: richard mcgonagle filmography - voice performances - table-2-2 [caption] list of voice performances in video games [header] [col] year [col] title [col] role [col] notes [col] source [row] [col] 2004 [col] ''the incredibles'' [col] bob parr/mr. incredible [col] [col]
# 12: brad bird filmography - video games - table-0-0 [header] [col] year [col] title [col] voice role [row] [col] 2004 [col] ''the incredibles'' [col] edna mode
# 13: alessia amendola dubbing roles - video games *violet parr in ''the incredibles''
# 14: adalberto maria merli dubbing roles - video games incredible in ''the incredibles''
# *bob parr / mr.
# 15: the incredibles: rise of the underminer introduction ''the incredibles: rise of the underminer'' is a 2005 action-adventure video game which serves as an alternative sequel to the animated film ''the incredibles'' (2004) as well as its associated video game tie in.
# 16: massimo corvo dubbing roles - video games *jafar in ''disney's aladdin in nasira's revenge''
# *supreme leader snoke in ''lego star wars: the force awakens''
# *doomfist in ''overwatch''
# *lucius best / frozone in ''the incredibles''
# *lucius best / frozone in ''the incredibles: rise of the underminer''
# 17: list of thq games published titles - table-0-391 [caption] !title [header] [col] platform(s) [col] release date [col] developer(s) [col] ref. [row] [col] ''the incredibles'' [col] game boy advance [col] [col] helixe [col]
#
#
#
# ---------- QUERY 15627 ----------
#  X_t:
#  The Pinacoteca Nazionale is a national museum in Siena, Tuscany, Italy. Inaugurated in 1932, it houses especially late medieval and Renaissance paintings from Italian artists. It is housed in the Brigidi and Buonsignori palaces in the city's center: the former, built in the 14th century, it is traditionally identified as the Pannocchieschi family's residence. The Palazzo Bichi-Buonsignori, although built in the 15th century, has a 19th-century neo-medieval façade based on the city's Palazzo Pubblico. The gallery has one of the largest collections of Sienese paintings with gold backgrounds from the 14th and 15th centuries. Works in the gallery include: *Duccio di Buoninsegna's Polyptych N. 28 and ''Madonna of the Franciscans'' *Guido da Siena's ''St. Peter Enthroned'' *Simone Martini's ''Blessed Agostino Novello and His Miracles'' (c. 1330) *Ambrogio Lorenzetti's ''Annunciation'' (c. 1344) *Bartolo di Fredi's ''Adoration of the Magi'' *Michelino da Besozzo's ''Mystical Marriage of Saint Catherine'' (c. 1420) *Il Sodoma's ''Christ at the Column'' and ''Deposition'' *Domenico Beccafumi's ''Birth of the  Virgin'' and  ''St.  Michael Expelling the Rebel Angels'' Other artists represented include Ugolino di Nerio, Pietro Lorenzetti, Sassetta, Domenico di Bartolo, Taddeo di Bartolo, Francesco di Giorgio Martini, Matteo di Giovanni, Neroccio di Bartolomeo
#
#  X_t+1:
#  The Pinacoteca Nazionale is a national museum in Siena, Tuscany, Italy. Inaugurated in 1932, it houses especially late medieval and Renaissance paintings from Italian artists. It is housed in the Brigidi and Buonsignori palaces in the city's center: the former, built in the 14th century, it is traditionally identified as the Pannocchieschi family's residence. The Palazzo Bichi-Buonsignori, although built in the 15th century, has a 19th-century neo-medieval façade based on the city's Palazzo Pubblico. The gallery has one of the largest collections of Sienese paintings with gold backgrounds from the 14th and 15th centuries. Works in the gallery include: *Duccio di Buoninsegna's Polyptych N. 28 and ''Madonna of the Franciscans'' *Guido da Siena's ''St. Peter Enthroned'' *Simone Martini's ''Blessed Agostino Novello and His Miracles'' (c. 1330) *Ambrogio Lorenzetti's ''Annunciation'' (c. 1344) *Bartolo di Fredi's ''Adoration of the Magi'' *Michelino da Besozzo's ''Mystical Marriage of Saint Catherine'' (c. 1420) *Il Sodoma's ''Christ at the Column'' and ''Deposition'' *Domenico Beccafumi's ''Birth of the  Virgin'',  ''St.
#
#  Comment: removed non-notable artists
#
#  Docs:
#
# 0: coronation of the virgin (beccafumi) introduction 1539, now in the pinacoteca nazionale in siena.
# 1: trinity triptych introduction the trinity triptych is a 1513 oil on panel painting by domenico beccafumi, now in the pinacoteca nazionale in siena.
# 2: descent into limbo (beccafumi) introduction ''descent into limbo'' or ''descent into hell'' is a 1530-1535 oil on panel painting by domenico beccafumi, now in the sienese grand masters room in the pinacoteca nazionale in siena.
# 3: neroccio di bartolomeo de' landi introduction he painted ''scenes from the life of st benedict'', now in the uffizi, probably in collaboration with di giorgio, and ''madonna and child between saint jerome and saint bernard'', which is in the pinacoteca nazionale of siena.
# 4: saint catherine of siena receiving the stigmata introduction ''saint catherine of siena receiving the stigmata'' is a c.1515 oil on canvas painting by domenico beccafumi, now in the pinacoteca nazionale di siena.
# 5: madonna and child with saints polyptych (duccio) introduction it was painted between 1311 and 1318, (tempera and gold on wood) and is located at the pinacoteca nazionale in siena, italy.
# 6: saint michael defeats the rebel angels (beccafumi) introduction ''saint michael defeats the rebel angels'' or ''fall of the rebel angels'' is a c.1524 oil on canvas painting by domenico beccafumi, now in the pinacoteca nazionale di siena.
# 7: bellanti madonna introduction previously in the bellanti collection, it is now one of several works by beccafumi in the pinacoteca nazionale in siena, including another ''madonna and child'' from 1514.
# 8: enzo carli (art historian) life in 1937 he was made superintendent of aquila and two years later moved to siena, where he taught art history at the university of siena and was director of the pinacoteca nazionale until 1952 and of the museo dell'opera metropolitana del duomo until 1973.
# 9: blessed agostino novello triptych introduction it now hangs in the pinacoteca nazionale in siena.
# 10: st francis (strozzi) introduction it has similarities to other paintings of francis of assisi by strozzi now held in genoa (palazzo bianco, palazzo rosso and rubinacci collection) and the pinacoteca di siena.
#
#
#
# ---------- QUERY 40749 ----------
#  X_t:
#  Sergio Carlos Strandberg (born 14 April 1996) is a Swedish footballer who plays as a striker for  Al-Hazem,  on loan from  Malmö FF.
#
#  X_t+1:
#  Sergio Carlos Strandberg (born 14 April 1996) is a Swedish footballer who plays as a striker for  Abha  on loan from
#
#  Comment: abha loan ended.
#
#  Docs:
#
# 0: 2020–21 al-hazem f.c. season transfers and loans - loans out - table-0-0 [header] [col] start date [col] end date [col] position [col] no. [col] player [col] to club [col] fee [col] ref. [row] [col] 18 october 2020 [col] end of season [col] fw [col] 99 [col] carlos strandberg [col] abha [col] none [col]
# 1: list of foreign saudi professional league players sweden *nabil bahoui – al-ahli – 2015–16
# *nahir besara – al-fayha – 2018–19
# *carlos strandberg – al-hazem, abha – 2019–
# *christian wilhelmsson – al-hilal – 2008–12
# 2: 2020–21 saudi professional league teams - foreign players - table-0-0 [header] [col] club [col] player 1 [col] player 2 [col] player 3 [col] player 4 [col] player 5 [col] player 6 [col] player 7 [col] former players [row] [col] abha [col] mehdi tahrat [col] craig goodwin [col] amine atouchi [col] abdelali mhamdi [col] carlos strandberg [col] karim aouadhi [col] saad bguir [col]
# 3: ola toivonen honours - records *swedish u21 top scorer: 13 goals (level with carlos strandberg)
# 4: 2020–21 abha club season statistics - goalscorers - table-0-3 [header] [col] [col] [col] [col] [col] name [col] pro league [col] king cup [col] total [row] [col] 99 [col] fw [col] carlos strandberg [col] 1 [col] 0 [col] 1
# 5: hisingsbacka fc notable players bengt berndtsson
# carlos strandberg
# kristopher da graca
# fredrik zanjanchi
# ole söderberg
# tom söderberg
# emil wahlström
# david frölund
# dennis jonsson
# 6: history of aik fotboll 2016–2020: the second norling era a key player for the spring part of the 2016 season was carlos strandberg, a striker who joined the squad just two days before the first game of the allsvenskan season on a short loan spell from cska moscow.
# 7: 2020–21 abha club season transfers and loans - loans in - table-0-5 [header] [col] start date [col] end date [col] position [col] no. [col] player [col] from club [col] fee [col] ref. [row] [col] 18 october 2020 [col] end of season [col] fw [col] 99 [col] carlos strandberg [col] al-hazem [col] none [col]
# 8: 2019–20 saudi professional league season statistics - scoring - top scorers - table-0-5 [header] [col] rank [col] player [col] club [col] goals [row] 6 carlos strandberg
# al-hazem
# 13
#
#
#
# ---------- QUERY 25387 ----------
#  X_t:
#  A komboni is a type of  compound or  informal housing  area  common to Zambia, particularly the capital city of Lusaka. It is characterized by a low income and a high population density. Kombonis typically began as housing for employees of a particular company, estate, or mine. An estimated 35% of Zambians live in urban areas, and kombonis exist in many of them. It is estimated that 80% of the population of Lusaka live and work in these areas.
#
#  X_t+1:
#  A komboni is a type of  informal housing  compound or  shanty town  common to Zambia, particularly the capital city of Lusaka. It is characterized by a low income and a high population density. Kombonis typically began as housing for employees of a particular company, estate, or mine. An estimated 35% of Zambians live in urban areas, and kombonis exist in many of them. It is estimated that 80% of the population of Lusaka live and work in these areas.
#
#  Comment: added shanty town
#
#  Docs:
#
# 0: misisi foundation misisi was established in the mid 1960s as a shanty town or komboni located beside the kafue road, three kilometres south of the central business district of lusaka, zambia.
# 1: misisi introduction misisi compound is a shanty town or komboni located in lusaka, zambia.
# 2: chibolya introduction chibolya is a komboni in lusaka, zambia.
#
#
#
# ---------- QUERY 22778 ----------
#  X_t:
#  Vermont/Beverly is a heavy-rail subway station in the Los Angeles County Metro Rail system. It is located at Vermont Avenue and Beverly Boulevard, in Los Angeles, near the border between East Hollywood and Wilshire Center. This station is served by the  Red  Line. Vermont/Beverly features a cactus garden and large rocks incorporated into the structure of the station, a design by artist George Stone.
#
#  X_t+1:
#  Vermont/Beverly is a heavy-rail subway station in the Los Angeles County Metro Rail system. It is located at Vermont Avenue and Beverly Boulevard, in Los Angeles, near the border between East Hollywood and Wilshire Center. This station is served by the  B  Line. Vermont/Beverly features a cactus garden and large rocks incorporated into the structure of the station, a design by artist George Stone.
#
#  Comment: corrected the name of the red line.
#
#  Docs:
#
# 0: vermont transit corridor route - table-0-2 [header] [col] station options [col] alt 1 brt [col] alt 2 lrt [col] alt 3 hrt [col] connectingservices [col] community [row] [col] vermont/beverly station (already built as hrt) [col] × [col] - [col] × [col] b line [col] wilshire center
# 1: b line (los angeles metro) station listing - table-0-6 [header] [col] station [col] date opened [col] city/ neighborhood [col] major connections and notes [row] [col] vermont/beverly [col] june 12, 1999 [col] los angeles [col]
#
#
#
# ---------- QUERY 276 ----------
#  X_t:
#  The 2009 Abu Dhabi Grand Prix (formally the I Etihad Airways Abu Dhabi Grand Prix) was the seventeenth and final Formula One motor race of the 2009 Formula One season. It took place on 1 November 2009 at the 3.45-mile Hermann Tilke-designed Yas Marina Circuit. It was the inaugural Abu Dhabi Grand Prix and also the first ever day-night Grand Prix (starting at 17:00, with sunset at 17:43 on raceday). The race was won by Sebastian Vettel for Red Bull, with polesitter Lewis Hamilton (driving for McLaren) having retired due to a brake failure. This  was also  the last race for Kazuki Nakajima and Giancarlo Fisichella and the BMW Sauber and Toyota
#
#  X_t+1:
#  The 2009 Abu Dhabi Grand Prix (formally the I Etihad Airways Abu Dhabi Grand Prix) was the seventeenth and final Formula One motor race of the 2009 Formula One season. It took place on 1 November 2009 at the 3.45-mile Hermann Tilke-designed Yas Marina Circuit. It was the inaugural Abu Dhabi Grand Prix and also the first ever day-night Grand Prix (starting at 17:00, with sunset at 17:43 on raceday). The race was won by Sebastian Vettel for Red Bull, with polesitter Lewis Hamilton (driving for McLaren) having retired due to a brake failure. This  would be  the last  Formula One  race for Kazuki Nakajima and Giancarlo Fisichella and the  Brawn GP,  BMW Sauber and Toyota  teams (respectively).
#
#  Comment: brawn gp
#
#  Docs:
#
# 0: list of formula one constructors former constructors - table-0-18 [header] [col] constructor [col] licensed in [col] seasons [col] races entered [col] races started [col] drivers [col] total entries [col] wins [col] points [col] poles [col] fl [col] podiums [col] wcc [col] wdc [col] first grand prix [col] last grand prix [row] brawn gp [col] 17 [col] 17 [col] 2 [col] 34 [col] 8 [col] 172 [col] 5 [col] 4 [col] 15 [col] 1 [col] 1 2009 australian 2009 abu dhabi
# 1: rubens barrichello career results - complete formula one results - table-0-18 [header] [col] 1993 [col] sasol jordan [col] jordan 193 [col] hart 1035 3.5 v10 rsa bra eur smr esp mon can fra gbr ger hun bel ita por jpn aus [col] [col] [col] [col] 18th [col] 2 [row] [col] 2009 [col] brawn gp f1 team [col] brawn bgp 001 [col] mercedes fo 108w 2.4 v8 aus mal ''chn'' bhr ''esp'' mon tur gbr ger hun eur bel ita sin jpn bra abu [col] [col] 3rd 77
# 2: red bull racing grand prix results complete formula one results - 2000s - table-0-14 [header] [col] year [col] chassis [col] engine [col] tyres [col] drivers [col] 1 [col] 2 [col] 3 [col] 4 [col] 5 [col] 6 [col] 7 [col] 8 [col] 9 [col] 10 [col] 11 [col] 12 [col] 13 [col] 14 [col] 15 [col] 16 [col] 17 [col] 18 [col] 19 [col] points [col] wcc [row] [col] rb5 renault rs27 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] 153.5 2nd
# 3: motor racing career of fernando alonso racing record - complete formula one results - table-0-8 [header] [col] [col] european minardi f1 team [col] minardi ps01 [col] european (cosworth) 3.0 v10
# aus
# mal
# bra
# smr
# esp
# aut
# mon
# can
# eur
# fra†
# gbr
# ger
# hun
# bel
# ita
# usa
# jpn [col] [col] [col] [col] [col] 23rd [col] 0 [row] [col] renault f1 team [col] [col] [col] [col] [col] [col] [col] [col] [col] [col] [col] [col] [col] ''sin''
# jpn
# bra
# abu [col] [col] [col] [col]
# 4: list of formula one constructors former constructors - table-0-124 [header] [col] constructor [col] licensed in [col] seasons [col] races entered [col] races started [col] drivers [col] total entries [col] wins [col] points [col] poles [col] fl [col] podiums [col] wcc [col] wdc [col] first grand prix [col] last grand prix [row] toyota – [col] 140 [col] 139 [col] 9 [col] 276 [col] 0 [col] 278.5 [col] 3 [col] 3 [col] 13 [col] 0 [col] 0 2002 australian 2009 abu dhabi
# 5: list of formula one grand prix wins by sebastian vettel wins - number of wins at different circuits - table-0-7 [header] [col] [col] circuit [col] years won [col] wins [row] [col] yas marina circuit [col] 2009, 2010, 2013
# 6: mclaren grand prix results formula one results - works team entries - 2000s - table-0-29 [header] [col] mp4/15
# mercedes fo110j 3.0 v10 [col] [col] aus [col] bra [col] smr [col] gbr [col] esp [col] eur [col] mon [col] can [col] fra [col] aut [col] ger [col] hun [col] bel [col] ita [col] usa [col] jpn [col] mal [col] [col] 152
# 2nd [row] [col] mp4-24
# mercedes fo 108w 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] 71
# 3rd
# 7: williams grand prix results formula one world championship results - works team entries - 2000s - table-0-31 [header] [col] fw22
# bmw e41 3.0 v10 [col] [col] aus [col] bra [col] smr [col] gbr [col] esp [col] eur [col] mon [col] can [col] fra [col] aut [col] ger [col] hun [col] bel [col] ita [col] usa [col] jpn [col] mal [col] [col] 36
# 3rd [row] [col] fw31
# toyota rvx-09 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] [col] 34.5 [col] 7th
# 8: dhl fastest lap award winners - table-1-2 [header] [col] year [col] winner [col] nationality [col] constructor [col] car [col] fastest laps [col] [col] ref(s) [row] [col] [col] [col] [col] red bull racing [col] red bull rb5 [col] 3 [col] race 17 of 17 [col]
# 9: list of formula one grand prix wins by sebastian vettel wins - number of wins at different grands prix - table-0-7 [header] [col] [col] grand prix [col] years won [col] wins [row] [col] abu dhabi grand prix [col] 2009, 2010, 2013
# 10: toyota racing (formula one team) complete formula one results - as a constructor - table-0-23 [header] [col] tf102 rvx-02 3.0 v10 [col] [col] aus [col] mal [col] bra [col] smr [col] esp [col] aut [col] mon [col] can [col] eur [col] gbr [col] fra [col] ger [col] hun [col] bel [col] ita [col] usa [col] jpn [col] [col] [col] 2 [col] 10th [row] [col] tf109 rvx-09 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] [col] 59.5 [col] 5th
# 11: ferrari grand prix results formula one world championship results - scuderia ferrari - 2000s - table-0-26 [header] [col] [col] f1-2000 [col] 049 3.0 v10 [col] [col] [col] aus [col] bra [col] smr [col] gbr [col] esp [col] eur [col] mon [col] can [col] fra [col] aut [col] ger [col] hun [col] bel [col] ita [col] usa [col] jpn [col] mal [col] [col] [col] 170 [col] 1st [row] [col] f60 056 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] [col] 70 [col] 4th
# 12: renault engine customers' grand prix results complete formula one results - red bull (2007–2010) - table-0-5 [header] [col] [col] red bull racing red bull rb3 rs27 2.4 v8 [col] [col] aus [col] mal [col] bhr [col] esp [col] mon [col] can [col] usa [col] fra [col] gbr [col] eur [col] hun [col] tur [col] ita [col] bel [col] jpn [col] chn [col] bra [col] [col] [col] 24 [col] 5th [row] [col] [col] red bull racing red bull rb5 rs27 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] 153.5 2nd
# 13: sebastian vettel formula one career - red bull - 2009–2010: championship runner-up and youngest world champion further wins followed in great britain, japan and abu dhabi.
# 14: list of formula one driver records races entered and started - most consecutive race entries - table-0-3 [header] align="center" [col] 1 rubens barrichello [col] 326 [col] 1993 south african – 2011 brazilian [row] align="center" [col] 5 giancarlo fisichella [col] 223 [col] 1997 australian – 2009 abu dhabi
# 15: renault grand prix results complete formula one results - as a constructor - return and first titles (2002–2009) - table-0-22 [header] [col] year [col] chassis [col] engine [col] tyres [col] drivers [col] 1 [col] 2 [col] 3 [col] 4 [col] 5 [col] 6 [col] 7 [col] 8 [col] 9 [col] 10 [col] 11 [col] 12 [col] 13 [col] 14 [col] 15 [col] 16 [col] 17 [col] 18 [col] 19 [col] points [col] wcc [row] [col] r29 rs27 2.4 v8 [col] [col] aus [col] mal [col] chn [col] bhr [col] esp [col] mon [col] tur [col] gbr [col] ger [col] hun [col] eur [col] bel [col] ita [col] sin [col] jpn [col] bra [col] abu [col] [col] [col] 26 [col] 8th
# 16: list of formula one promotional trophy winners race promoters' trophy - by season - table-0-9 [header] [col] [col] mexican grand prix [col] mexico city [row] [col] [col] abu dhabi grand prix [col] yas marina
# 17: history of formula one history - cost-cutting measures and departure of factory teams (2009–2013) rubens barrichello, jenson button's teammate, was second in the drivers' championship for the whole season until he had a problem at the brazilian grand prix and was overtaken (in points) by sebastian vettel, a red bull driver, who won the abu dhabi grand prix to finish eleven points behind button.
#
#
#
# ---------- QUERY 100496 ----------
#  X_t:
#  Thamesmead is an area of south-east London, England, straddling the border between the Royal Borough of Greenwich and the London Borough of Bexley. It is located east of Charing Cross,  and  north-east of Woolwich and west of  Belvedere.  It mainly consists of social housing built from the mid-1960s onwards on former marshland on the south bank of the River Thames.
#
#  X_t+1:
#  Thamesmead is an area of south-east London, England, straddling the border between the Royal Borough of Greenwich and the London Borough of Bexley. It is located east of Charing Cross, north-east of Woolwich and west of  Erith.  It mainly consists of social housing built from the mid-1960s onwards on former marshland on the south bank of the River Thames.
#
#  Comment: erith --> erith
#
#  Docs:
#
# 0: harris garrard academy introduction harris garrard academy (formerly business academy bexley) is a 4–18 mixed, all-through school and sixth form with academy status in thamesmead, erith, greater london, england.
# 1: gary drostle public art career he now works from a studio at the lakeside centre, a bow arts trust and peabody trust partnership arts centre in thamesmead, south-east london
#
# in 2006 he received a queen elizabeth scholarship trust award to further study mosaic making at the famous orsoni mosaic works in venice.
# 2: list of bus routes in london list of routes - 200–299 - table-0-29 [header] [col] route [col] start [col] end [col] operator [col] notes [row] [col] 229 [col] sidcup, queen mary's hospital [col] thamesmead, town centre [col] arriva london [col]
# 3: london ringways ringway 2 - northern section at its eastern end, ringway 2 was planned to have crossed the river thames at gallions reach in a new tunnel between beckton and thamesmead.
# 4: list of radio stations in the united kingdom local and regional analogue and digital (dab) stations - local commercial radio - former english stations - table-0-21 [header] style="background:#c9c9c9;" [col] name [col] licence area [col] analogue (khz/mhz) [col] dab channels [col] notes [row] [col] time 106.8 [col] thamesmead [col] 106.8 fm [col] [col] closed down on 3 april 2009
# 5: gospel oak to barking line future - proposed - potential abbey wood extension despite recommending an extension of the dlr to thamesmead, the consultation also noted that an extension of the goblin line could provide good orbital transport links in the long term.
# 6: gospel oak to barking line future - proposed - potential abbey wood extension however, in 2019 transport for london and city hall proposed an extension of the
# klands light railway (dlr) to serve thamesmead instead of an extension of the overground, as part of the proposed thamesmead and abbey wood oapf (opportunity area planning framework).
# 7: rene claudel mugenzi political and human rights activities in 2010, he stood as a candidate in a local election in thamesmead moorings ward within royal borough of greenwich for the liberal democrats.
# 8: list of areas of london other use of place names - table-0-458 [header] [col] location [col] london borough [col] post town [col] postcode district [col] dial code [col] os grid ref [row] [col] thamesmead [col] bexley, greenwich [col] london, erith [col] se28, se2, da18 [col] 020 [col]
# 9: list of music videos set in london music videos set in london - table-0-94 [header] [col] year [col] track title [col] artist [col] video director [col] location(s) [row] [col] 2008 [col] "never miss a beat" [col] kaiser chiefs [col] goodtimes [col] abbey wood, thamesmead
# 10: welling transport - buses these connect it with places including abbey wood, bexleyheath, blackheath, bluewater, charlton, crayford, dartford, eltham, kidbrooke, north greenwich, orpington, plumstead, sidcup, slade green, st mary cray, thamesmead and woolwich.
# 11:
# klands light railway extension to thamesmead route and stations the route then continues southeast, crossing the river before arriving at thamesmead central.
# 12: royal school of artillery history - antecedents to ensure parity of training for the reserve forces, the school of gunnery established a branch at woolwich, which in 1874 took over responsibility for training militia and volunteer artillery; its instructors were based at the repository, but live firing now took place on plumstead marshes.
# 13: westminster tube station history - jubilee line platforms when the first section of the jubilee line was planned in the 1970s, the second phase of the project was intended to continue the line eastwards from the terminus at charing cross to the city of london, woolwich and thamesmead.
# 14: politics of greenwich greenwich london borough council - electoral wards - table-5-52 [row] [col] thamesmead moorings [col] lance mulcahy (lab) [col] edward claridge (lab) [col] don austen (alliance) [col] edward claridge (lab) [col] claude ramsay (lab) [col] peter brooks (lab)
# 15: ridgeway (london) route the ridgeway runs ene/wsw:  the western third between plumstead railway station and the link community centre in thamesmead is in the royal borough of greenwich, the remainder of the path towards the thames path and crossness pumping station is in the london borough of bexley.
# 16: gospel oak to barking line future - proposed - potential abbey wood extension following the plan to extend the line to barking riverside, there were also proposals to extend the line further across the river to abbey wood via thamesmead, to allow for easier orbital journeys in east london, and provide thamesmead with a railway connection for the first time.
# 17: royal artillery barracks, woolwich curtilage - gun park use of the mortar battery ended in the 1870s, when live artillery firing was restricted to plumstead marshes and shoeburyness.
# 18: list of music videos set in london music videos set in london - table-0-138 [header] [col] year [col] track title [col] artist [col] video director [col] location(s) [row] [col] 2004 [col] "what became of the likely lads" [col] the libertines [col] [col] thamesmead
# 19: list of bus routes in london list of routes - 600–699 - table-0-51 [header] [col] route [col] start [col] end [col] schools [col] operator [col] notes [row] [col] 672 [col] woolwich [col] thamesmead [col] hawksmoor primary school [col] stagecoach london [col]
# 20:
# klands light railway extension to thamesmead introduction the
# klands light railway extension to thamesmead is a proposed
# klands light railway (dlr) extension to serve the beckton riverside and thamesmead redevelopment areas of east london.
# 21:
# klands light railway extension to thamesmead project development thamesmead, former marshland on the south bank of the river thames in east london, was developed by the greater london council from the 1960s onwards to meet the demand from londoners for social housing.
# 22:
# klands light railway extension to thamesmead route and stations - table-0-1 [header] [col] station locale [col] london borough [row] [col] thamesmead central [col] greenwich
# 23:
# klands light railway extension to thamesmead project development following this, the dlr extension to thamesmead was first formally proposed in december 2019 by transport for london as part of the draft thamesmead and abbey wood opportunity area planning framework, with proposed stations at armada riverside in beckton and thamesmead.
# 24: gospel oak to barking line future - proposed - potential abbey wood extension following the plan to extend the line to barking riverside, there were also proposals to extend the line further across the river to abbey wood via thamesmead, to allow for easier orbital journeys in east london, and provide thamesmead with a railway connection for the first time.
# 25: tony craig personal life craig was born in greenwich in london, but grew up in thamesmead.
# 26: british narrow-gauge railways the narrow-gauge railways of britain and the isle of man - visitor attractions - table-0-18 [header] [col] name [col] years of operation [col] gauge [col] length [col] location [col] image [col] notes [row] [col] rang (royal arsenal narrow gauge) railway [col] 2019 [col] [col] [col] crossness pumping station, thamesmead, england [col] [col] the line is part built and working, and is used to transport visitors to the victorian pumping station. work to extend the line to 350 yds (315 mts) is planned for spring 2020. the train, bazalgette, is a severn-lamb 0-4-0 dh diesel engine.
#
#
#
# ---------- QUERY 66806 ----------
#  X_t:
#  Meredith Palmer (born May 12, 1959) is a fictional character on the U.S. comedy television series, ''The Office''. She is portrayed by Kate  Flannery,  and is an original character with no equivalent in the British version of the show.
#
#  X_t+1:
#  Meredith Palmer (born May 12, 1959) is a fictional character on the U.S. comedy television series, ''The Office''. She is portrayed by Kate  Flannery (Henriette Mantel in the pilot),  and is an original character with no equivalent in the British version of the show.
#
#  Comment: henriette mantel
#
#  Docs:
#
# 0: henriette mantel biography while only credited as "office worker", it was revealed that she was supposed to be meredith palmer.
# 1: women's appreciation plot on the drive back, pam takes a step toward asserting herself by changing a flat tire on meredith palmer's (kate flannery) car.
# 2: search committee synopsis the discussion gets out of control, with ryan (b. j. novak) preferring a homeless man, andy declaring he wants the job, meredith palmer (kate flannery) wanting a "smart, professional, decisive, well-hung man in his forties," kevin malone (brian baumgartner) and angela martin (angela kinsey) speaking solely for attention, and darryl's daughter jada asking out loud if jim is the guy making him manager.
# ...
#
#  Docs:
#
# 0: foreign minister of senegal list of foreign ministers of senegal - table-0-12 [header] [col] name [col] term of office [row] [col] moustapha niasse [col] 1993 [col] 1998
# 1: foreign minister of senegal list of foreign ministers of senegal - table-0-8 [header] [col] name [col] term of office [row] [col] moustapha niasse [col] 1978 [col] 1984
# 2: fredrick chien minister of foreign affairs at the joint communique signing ceremony with foreign minister moustapha niasse, chien noted that the "establishment of diplomatic ties marks a significant development in our pursuit of pragmatic diplomacy."
# 3: prime minister of senegal prime ministers of senegal (1960–2019) - table - table-0-5 [header] [col] [col] portrait [col] name [col] term of office [col] political party [row] [col] — [col] [col] moustapha niasse [col] 3 april 1983 [col] 29 april 1983 [col] 26 days [col] pss
# 4: list of presidents of senegal presidents of senegal (1960–present) - table-0-1 [header] [col] took office [col] left office [col] time in office [row] [col] 2 [col] [col] abdou diouf [col] 198319881993 [col] 1 january 1981 [col] 1 april 2000 [col] [col] pss [col] habib thiammoustapha niassehabib thiammoustapha niasse
# 5: cheikh sadibou fall biography he was appointed as minister of town planning and housing on 23 november 2000 by moustapha niasse, replacing the sacked amath dansokho.
# 6: prime minister of senegal prime ministers of senegal (1960–2019) - table - table-0-9 [header] [col] [col] portrait [col] name [col] term of office [col] political party [row] [col] 5 [col] [col] moustapha niasse [col] 5 april 2000 [col] 3 march 2001 [col] 332 days [col] afp
# 7: list of presidents of senegal presidents of senegal (1960–present) - table-0-2 [header] [col] took office [col] left office [col] time in office [row] [col] 3 [col] [col] abdoulaye wade [col] 20002007 [col] 1 april 2000 [col] 2 april 2012 [col] [col] pds [col] moustapha niassemame madior boyeidrissa seckmacky sallcheikh hadjibou soumarésouleymane ndéné ndiaye
# 8: list of presidents of senegal presidents of senegal (1960–present) - table-0-1 [header] [col] took office [col] left office [col] time in office [row] [col] 2 [col] [col] abdou diouf [col] 198319881993 [col] 1 january 1981 [col] 1 april 2000 [col] [col] pss [col] habib thiammoustapha niassehabib thiammoustapha niasse
#
#
#
# ---------- QUERY 21316 ----------
#  X_t:
#  David Matthew Macfadyen (born 17 October 1974) is an English  actor. He played MI5 Intelligence Officer Tom Quinn  in  the BBC television drama series ''Spooks'',  Mr. Darcy in  the 2005 film  ''Pride & Prejudice'' and Daniel in the Frank Oz comedy ''Death at a Funeral''. He also portrayed John Birt in the political drama ''Frost/Nixon'' and Detective Inspector Edmund Reid in the BBC series ''Ripper Street''. In  2015 he starred in the Sky Living series ''The Enfield Haunting'' as Guy Lyon Playfair. In  June 2010, Macfadyen won  a  British Academy Television Award for Best Supporting Actor for his work  in  ''Criminal Justice''.
#
#  X_t+1:
#  David Matthew Macfadyen (born 17 October 1974) is an English  actor who has appeared in film, television, and theatre.  He  is known for his performance as  Mr. Darcy in  Joe Wright's  ''Pride & Prejudice''  (2005),  and Daniel in the Frank Oz comedy ''Death at a Funeral''. He also portrayed John Birt in the political drama ''Frost/Nixon'' and Detective Inspector Edmund Reid in the BBC series ''Ripper Street''. In June 2010, Macfadyen won  the  British Academy Television Award for Best Supporting Actor for his work  on  ''Criminal Justice''.  Macfadyen currently stars as Tom Wambsgans in the critically acclaimed HBO drama series ''Succession''. For this role, he received a nomination for the Primetime Emmy Award for Outstanding Supporting Actor in a Drama Series in 2020.
#
#  Comment: updated infobox, added emmy award
#
#  Docs:
#
# 0: this is not for tears reception - accolades additionally, mark mylod was nominated for outstanding directing for a drama series, and matthew macfadyen and nicholas braun selected the episode to support their nominations in the categories of outstanding supporting actor in a drama series.
# 1: satellite award for best cast – television series winners - 2010s - table-0-9 [header] [col] year [col] winners [col] cast members [col] [row] [col] 2019 [col] ''succession'' [col] brian cox • jeremy strong • sarah snook • kieran culkin • matthew macfadyen • nicholas braun • alan ruck • hiam abbass • peter friedman • natalie gold • dagmara domińczyk • arian moayed • j. smith-cameron [col]
# 2: succession (tv series) reception - awards and nominations - table-0-4 [caption] |- [header] [col] year [col] award [col] category [col] nominee(s) [col] result [col] [row] [col] best supporting actor in a drama series [col] matthew macfadyen [col]
# 3: list of american films of 2012 introduction - table-0-23 [header] [col] title [col] director [col] cast (subject of
# umentary) [col] genre [col] notes [col] release date [row] [col] '' anna karenina'' [col] joe wright [col] keira knightley, jude law, aaron johnson, kelly macdonald, matthew macfadyen, domhnall gleeson [col] biography [col] focus features [col] november 9
# 4: list of british films of 2012 major releases - july – september - table-0-23 [caption] [header] style="background:#b0e0e6; text-align:center;" [col] opening [col] title [col] cast and crew [col] details [col] genre(s) [row] [col] 7 [col] ''anna karenina'' [col] director: joe wright cast: keira knightley, jude law, aaron johnson, kelly macdonald, matthew macfadyen, domhnall gleeson, ruth wilson, alicia vikander, olivia williams, emily watson [col] focus features based on ''anna karenina'' by leo tolstoy [col] epic romance drama historical
# 5: primetime emmy award for outstanding supporting actor in a drama series winners and nominations - 2020s - table-0-6 [header] style="background:#bebebe;" [col] year [col] actor [col] role [col] program [col] network [row] [col] matthew macfadyen [col] tom wambsgans [col] ''succession'' [col] hbo
# 6: british academy television award for best supporting actor winners - table-0-1 [header] style="background:#bebebe;" [col] year [col] actor [col] work [col] character [row] style="background:#b0c4de;" [col] matthew macfadyen [col] ''criminal justice'' [col] joe miller
# 7: peter morgan career - 2000s the film also starred kevin bacon, rebecca hall, mathew macfadyen, toby jones, oliver platt, and sam rockwell.
# 8: quiz (tv series) cast * matthew macfadyen as charles ingram
# * michael sheen as chris tarrant
# * sian clifford as diana ingram
# * mark bonnar as paul smith
# * helen mccrory as sonia woodley qc
# * michael jibson as tecwen whittock
# * aisling bea as claudia rosencrantz
# * trystan gravelle as adrian pollock
# * elliot levey as david briggs
# * risteárd cooper as david liddiment
# * jasmyn banks as nicola howson
# * andrew leung as kevin duff
# * martin trenaman as ds ferguson
# * nicholas woodeson as nicholas hilliard qc
# * paul bazely as lionel from legal
#
# davina mccall, will young, cat deeley, natasha kaplinsky, brendan cole and alan sugar appear as themselves in archive footage of millionaire's 7 victories in the most popular quiz programme category at the national television awards.
# 9: in my father's den (film) plot following the death of his father jeff (matthew chamberlain), renowned war photographer paul prior (matthew macfadyen) returns to his hometown in the south island of new zealand.
# 10: spooks (series 10) casting matthew macfadyen, who starred in the first three series as protagonist tom quinn, returned for a cameo appearance in the series finale.
# 11: list of american films of 2020 january–march - table-0-16 [caption] [header] style="background:#b0e0e6; text-align:center" [col] opening [col] title [col] production company [col] cast and crew [col] ref. [row] [col] ''the assistant'' [col] bleecker street [col] kitty green (director/screenplay); julia garner, matthew macfadyen [col]
# 12: 2010 in film 2010 films - april–june - table-0-47 [caption] [header] style="background:#b0e0e6; text-align:center" [col] opening [col] title [col] studio [col] cast and crew [row] [col] ''robin hood'' [col] universal pictures / imagine entertainment / relativity media / scott free productions [col] ridley scott (director); brian helgeland (screenplay); russell crowe, mark addy, cate blanchett, mark strong, william hurt, oscar isaac, danny huston, kevin durand, scott grimes, matthew macfadyen, eileen atkins, simon mcburney, max von sydow, alan doyle, léa seydoux, douglas hodge, gerard mcsorley, robert pugh, jonathan zaccaï, mark lewis jones, denis menochet, jessica raine
# 13: 2018 in film 2018 films - october–december - table-0-23 [caption] [header] style="background:#b0e0e6; text-align:center" [col] opening [col] title [col] studio [col] cast and crew [col] ref. [row] [col] ''the nutcracker and the four realms'' [col] walt disney pictures [col] lasse hallström, joe johnston (director); ashleigh powell (screenplay); keira knightley, mackenzie foy, eugenio derbez, matthew macfadyen, richard e. grant, misty copeland, helen mirren, morgan freeman, jack whitehall, omid djalili, sergei polunin [col]
# 14: sian clifford career - 2016–present: ''fleabag'' and acting for television she starred opposite matthew macfadyen in the april 2020 miniseries ''quiz'', based on the 2001 charles ingram ''[[who wants to be a millionaire?
# 15: the last kingdom (tv series) cast - recurring - introduced in series 1 * matthew macfadyen as lord uhtred
# * rutger hauer as ravn
# * peter gantzler as earl ragnar
# * tom taylor as young uhtred
# * henning valin jakobsen as storri
# * jason flemyng as king edmund
# * alec newman as king æthelred
# * lorcan cranitch as father selbix
# * victor mcguire as oswald
# * sean gilder as wulfhere
# * jonas malmsjö as skorpa of the white horse
# * paul ritter as king peredur
# * nicholas rowe as brother asser
# 16: who wants to be a millionaire? (british game show) controversies - ingram cheating scandal ''quiz'', a 2017 play based on the events of the scandal, was written by james graham'','' and a tv adaptation was commissioned by itv starring matthew macfadyen and sian clifford, which aired in april 2020.
# 17: spooks (series 10) cast - guest * simon russell beale as home secretary william towers
# * jonathan hyde as ilya gavrik
# * alice krige as elena gavrik
# * ''and'' matthew macfadyen as tom quinn (episode 6)
# 18: dc (succession) production to prepare for his scenes during tom's testimony, actor matthew macfadyen watched the house testimony of michael cohen, former attorney to president donald trump, and his questioning by rep. elijah cummings.
# 19: 2009 in film 2009 films - january–march - table-0-29 [caption] [header] [col] january [col] 2 [col] ''cargo 200'' [col] the disinformation company [col] aleksei balabanov (director); agniya kuznetsova, leonid bichevin, aleksei poluyan, leonid gromov, aleksei serebryakov [col] l [row] [col] ''incendiary'' [col] thinkfilm [col] sharon maguire (director/screenplay); michelle williams, ewan mcgregor, matthew macfadyen, nicholas gleaves, sidney johnston, usman khokhar, sasha behar, ed hughes, alibe parsons, stewart wright, al hunter ashton, benjamin wilkin, steve leatherbarrow, robin berry, mercy ojelade, joe marshall [col] l
# 20: operation mincemeat (film) production in december, matthew macfadyen, penelope wilton, johnny flynn, tom wilkinson, hattie morahan, simon russell beale, paul ritter and mark gatiss were added to the cast.
# 21: james hawes move to drama scripted by lyndsay shapero, the film co-stars matthew macfadyen and denis lawson.
# 22: 2011 in film 2011 films - july–september - table-0-31 [caption] [header] style="background:#b0e0e6; text-align:center" [col] opening [col] title [col] studio [col] cast and crew [col] genre [col] ref. [row] [col] ''the three musketeers'' [col] summit entertainment / constantin film [col] paul w. s. anderson (director); andrew davies, alex litvalk (screenplay); matthew macfadyen, logan lerman, ray stevenson, luke evans, milla jovovich, orlando bloom, christoph waltz [col] [col]
# 23: list of american films of 2011 introduction - table-0-188 [header] [col] title [col] director [col] cast (subject of
# umentary) [col] genre [col] notes [row] [col] ''the three musketeers'' [col] paul w. s. anderson [col] logan lerman, milla jovovich, matthew macfadyen, ray stevenson, luke evans, mads mikkelsen, gabriella wilde, james corden, juno temple, freddie fox, til schweiger, orlando bloom, christoph waltz [col] action-adventure [col] summit entertainmentbased on the novel of the same name by alexandre dumas
# 24: michael gambon career - 2000s: ''gosford park'' and ''harry potter'' in 2005 he finally achieved a lifelong ambition to play falstaff, in nicholas hytner's national production of ''henry iv, parts 1 and 2'', co-starring with matthew macfadyen as prince hal.
# 25: bbc natural history unit filmography television productions - table-0-106 [header] [col] series title [col] year(s) broadcast [col] subject [col] contributors [col] dvd release [col] video download [row] [col] ''24 hours on earth'' [col] 2014 [col] a two-part series of a day in the life of our planet. [col] matthew macfadyen (narrator) [col] no [col] yes
# 26: dc (succession) reception - critical reception club]]'' gave the episode an a-, praising the comedy of tom's testimony and matthew macfadyen's performance as "genuinely distressing".
# 27: hiroki tōchi filmography - dubbing - table-0-59 [caption] list of dub performances in overseas productions [header] [col] title [col] role [col] voice dub for, notes [col] source [row] [col] ''pride & prejudice'' [col] mr. darcy [col] matthew macfadyen [col]
# 28: stephen frears introduction his recent work in television includes the comic series ''state of the union'' (2019) starring rosamund pike, and chris o'dowd, as well as the miniseries ''quiz'' (2020) starring matthew macfadyen, sian clifford, and michael sheen based on a true story about a man who was accused of cheating on the show ''[[who wants to be a millionaire?
# 29: kazuhiko inoue filmography - overseas dubbing - live-action - table-0-40 [header] [col] series [col] role [col] voice dub for [col] notes [col] source [row] [col] ''agatha christie's marple'' [col] inspector neil [col] matthew macfadyen [col] season 4 [col]
# 30: quiz (play) tv adaptation in 2019, filming began on a three-part tv series of the same name for itv adapted from the play (written by and executive produced by graham) to air in 2020, directed by stephen frears and starring michael sheen as chris tarrant, matthew macfadyen as charles ingram, sian clifford as diana ingram and michael jibson as tecwen whittock.
# 31: vaulter (succession) reception - critical reception noel murray of ''the new york times'' praised matthew macfadyen's performance in the episode, saying that the episode featured some of the actor's best scenes in the series.
# 32: robin hood (2010 film) production - casting the castings of william hurt and matthew macfadyen were announced in april, with macfadyen portraying the sheriff.
# 33: operation mincemeat (film) cast *colin firth as ewen montagu
# *kelly macdonald
# *matthew macfadyen as charles cholmondeley
# *penelope wilton
# *johnny flynn
# *jason isaacs
# *tom wilkinson
# *hattie morahan
# *simon russell beale
# *paul ritter
# *mark gatiss
# *alexander beyer
# *nicholas rowe
# 34: quiz (play) tv adaptation - table-0-0 [header] [col] character [col] stage play [col] itv drama [row] [col] charles ingram [col] gavin spokes
# matthew macfadyen
# 35: eleven (company) introduction eleven's recent output includes ''sex education','' an eight part comedy drama series for netflix created by laurie nunn and directed by ben taylor, ''gap year,'' a comedy drama written by tom basden and the first uk tv scripted series to film in chinafor e4, bafta-nominated ''the enfield haunting,'' a drama series starring timothy spall, juliet stevenson and matthew macfadyen for sky living.
