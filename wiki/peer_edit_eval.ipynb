# %%
# !ls -l ./models/
# Out:
# total 8
# drwxrwxr-x 5 ubuntu ubuntu 4096 Jan  8 15:10 't5-small p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 ubuntu ubuntu 4096 Jan  8 13:26 't5-small_test_one_batch p(comment, x_t+1 | x_t, doc)'

# %%
import re
import os
import torch
import json
import numpy as np
import pandas as pd
import seaborn as sns
import transformers
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from transformers import T5Tokenizer, T5TokenizerFast, T5ForConditionalGeneration
from transformers.tokenization_utils import PreTrainedTokenizer
from transformers.tokenization_utils_fast import PreTrainedTokenizerFast
from typing import Callable, Union, Tuple
from tqdm.notebook import tqdm
from collections import Counter
from torch import nn
from catalyst import dl
from catalyst.callbacks.periodic_loader import PeriodicLoaderCallback
from langdetect import detect
from easse.sari import corpus_sari
from rouge import Rouge 

from utils.dataset_utils import extract_com8text_from_tgt, extract_text8docs_from_src
from utils.dataset_utils import EditDataset, get_tgt, get_src, COM_SEP, TEXT_SEP_SRC, TEXT_SEP_TGT, DOCS_SEP
from utils.metrics_utils import PeerEditMetricsCallback
from utils.config import Config


DOCS_DIR = 'data'
PAGES_DIR = 'data'

# %%
CONFIG = Config()
CONFIG.seed = 1337
CONFIG.beam_size = 1

# %%
import random

random.seed(CONFIG.seed)
os.environ['PYTHONHASHSEED'] = str(CONFIG.seed)
np.random.seed(CONFIG.seed)
torch.manual_seed(CONFIG.seed)
torch.cuda.manual_seed(CONFIG.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Data preparing

# %%
mp = json.load(open(r"data/column_mapper.json"))

train = pd.read_json(r'data/train.json')
train.set_axis(mp.values(), axis='columns', inplace=True)

test = pd.read_json(r'data/test.json')
test.set_axis(mp.values(), axis='columns', inplace=True)

val = pd.read_json(r'data/val.json')
val.set_axis(mp.values(), axis='columns', inplace=True)
val1 = val.sample(600)

# %%
train.head()
# Out:
#    obj_id                                           old_text  \
# 0   13807  People Who Fear People was another project tha...
# 1    1431  Thank you for signing my signbook. :) <3 Tinkl...
# 2    1362  Mark Ward may refer to:\n* Mark Ward (football...
# 3   10057  National Schools Tree Day is held on the last ...
# 4    4566  * Bea Alonzo as Architect Basha-Belinda Eugeni...
#
#                                             new_text  \
# 0  People Who Fear People Variety, August 17th, 1...
# 1  Thank you for signing my signbook. :) <3 Tinkl...
# 2  Mark Ward may refer to:\n* Mark Ward (football...
# 3  National Schools Tree Day is held on the last ...
# 4  * Bea Alonzo as Architect Basha-Belinda Eugeni...
#
#                                              comment  \
# 0  /* People Who Fear People (1999) */ Added refe...
# 1                                 /* Thank You */ re
# 2  Added in Mark Ward Sinn Féin TD for Dublin Mid...
# 3    Removed footnote reference to wikipedia article
# 4                             /* Cast */ Added links
#
#                                                 docs  \
# 0  Maria Pitillo (born January 8, 1966) is an Ame...
# 1  Councilmember Antonio López. 584 likes. Welcom...
# 2  Email me. Spokesperson for Mental Health. Mark...
# 3  While every day can be Tree Day, we dedicate c...
# 4  Top cast ; John Lloyd Cruz · Popoy ; Bea Alonz...
#
#                                              diff  \
# 0               Variety, August 17th, 1999 Page 5
# 1                                 \n:your welcome
# 2  \n* Mark Ward Sinn Féin TD for Dublin Mid West
# 3                               (See Planet Ark).
# 4                                       Rodolfo "
#
#                          title  \
# 0                Maria Pitillo
# 1                Antonio Lopez
# 2                    Mark Ward
# 3                    Arbor Day
# 4  A Second Chance (2015 film)
#
#                                       search_queries counter_found_docs  \
# 0  [Maria Pitillo  People Who Fear People (1999) ...               [28]
# 1         [Antonio Lopez  Thank You \n:your welcome]               [24]
# 2  [Mark Ward \n* Mark Ward Sinn Féin TD for Dubl...               [28]
# 3           [Arbor Day  Australia (See Planet Ark).]               [27]
# 4       [A Second Chance (2015 film) Cast Rodolfo "]               [27]
#
#                       section_name  is_good  \
# 0   People Who Fear People (1999)      True
# 1                       Thank You      True
# 2                                      True
# 3                       Australia      True
# 4                             Cast     True
#
#                                       docs_processed
# 0  DOC0: Maria Pitillo (born January 8, 1966) is ...
# 1  DOC0: Councilmember Antonio López. 584 likes. ...
# 2  DOC0: Email me. Spokesperson for Mental Health...
# 3  DOC0: While every day can be Tree Day, we dedi...
# 4  DOC0: Top cast ; John Lloyd Cruz · Popoy ; Bea...

# %%
CONFIG.src_max_len = 512
CONFIG.tgt_max_len = 512
CONFIG.pretrained = 't5-small'
CONFIG.pattern_path = './models/t5-small p(comment, x_t+1 | x_t, doc)'
CONFIG.batch_size = 4

tokenizer = T5TokenizerFast.from_pretrained(CONFIG.pretrained, model_max_length=CONFIG.src_max_len)

# %% [markdown]
# **Make dataset**

# %%
#ds_train = EditDataset(train, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
ds_val = EditDataset(val1, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
#ds_val_full = EditDataset(val, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)

# %% [markdown]
# **Len distribution**

# %%
idx_num = 100
src_text = tokenizer.decode(ds_val[idx_num][0]['input_ids'], skip_special_tokens=True)
tgt_text = tokenizer.decode(ds_val[idx_num][1]['input_ids'], skip_special_tokens=True)

# %%
print(f'{src_text}\n\n{tgt_text}')
# Out:
# TEXT_SEP canberra plaza is designed with three commercial stories that have a combined gross floor area of the main anchor tenants include a supermarket and food courts. other commercial units include restaurants, enrichment centres as well as clinics. a sheltered plaza for community activities and a water playground is incorporated into the design of canberra plaza as well. in order to improve connectivity, a portion of the ground level will be kept open for 24-hours and an sheltered elevated pedestrian footbridge will also link housing precincts (such as eastlink ii @ canberra) across canberra way to canberra plaza. a similar footbridge will connect canberra plaza to canberra mrt station which is located across canberra link.exhibition panel for canberra plaza at the exhibition(pdf), retrieved 2018-04-18. source: hdb DOCS_SEP doc0: canberra plaza is a new generation neighbourhood centre (ngnc) built by the housing. construction started in mid-2015 and the shopping centre opened on 18 doc1: construction started in mid-2015 and the shopping centre opened on 18 december 2020. the mall is directly linked to canberra mrt station by a footbridge doc2: celmonze the signature canberra plaza.. #02- 16,blk 133 canberra view, singapore 750133. +65 6980 5233. date:18/12/2022 ( sunday ) doc3: book an appointment to view the watergardens at canberra showflat & get vvip discounts (limited time), direct developer price, & hardcopy e-brochure. guaranteed doc4: dec 2, 2020 — canberra plaza will be opening on 18 dec 2020! some of the most anticipated shops like ntuc fairprice supermarket, daiso singapore, a&w doc5: a new shopping mall is arriving in the northern part of singapore, and it is linked seamlessly to the canberra mrt station – so no more getting wet when it
#
# COM_SEP date formats per [[mos:dateformat]] by [[wp:mosnumscript|script]] TEXT_SEP canberra plaza is designed with three commercial stories that have a combined gross floor area of the main anchor tenants include a supermarket and food courts. other commercial units include restaurants, enrichment centres as well as clinics. a sheltered plaza for community activities and a water playground is incorporated into the design of canberra plaza as well. in order to improve connectivity, a portion of the ground level will be kept open for 24-hours and an sheltered elevated pedestrian footbridge will also link housing precincts (such as eastlink ii @ canberra) across canberra way to canberra plaza. a similar footbridge will connect canberra plaza to canberra mrt station which is located across canberra link.exhibition panel for canberra plaza at the exhibition(pdf), retrieved 18 april 2018. source: hdb

# %% [markdown]
# ## Model training

# %%
class EditModel(nn.Module):
    def __init__(self, 
                 pretrained: transformers.modeling_utils.PreTrainedModel, 
                 config: Config):
        super(EditModel, self).__init__()
        self.pretrained = pretrained
        

    def forward(self, 
                x: Tuple[torch.Tensor, torch.Tensor]):
        src, tgt = x
        
        tgt[tgt == 0] == -100
        
        loss = self.pretrained(
            input_ids = src,
            attention_mask = (src != 0).float(),
            labels=tgt,
        ).loss
        return loss
    
    
class Criterion(nn.Module):
    def __init__(self):
        super(Criterion, self).__init__()
        
    def forward(self, pred, tgt):
        return pred

# %%
CONFIG.device = 'cuda'

# %%
model_edit = EditModel(T5ForConditionalGeneration.from_pretrained(CONFIG.pretrained), CONFIG)
model_edit.load_state_dict(
    torch.load(f'{CONFIG.pattern_path}/checkpoints/model.best.pth', 
               map_location=CONFIG.device))
model_edit = model_edit.pretrained
model_edit.to(CONFIG.device)
model_edit.eval()
print('Success')
# Out:
# Success

# %%
METRIC_LIST = [
    'full__exact_match@1',
    'text__exact_match@1',
    'text__diff_exact_match@1',
    'comment__exact_match@1',
    'text__sari@1',
    'text__rouge-1@1',
    'text__rouge-2@1',
    'text__rouge-l@1'
]

# %%
val1
# Out:
#       obj_id                                           old_text  \
# 7191    1252  Argyle, M. (1975).  Bodily communication.  New...
# 1582     213  *Daniel Hack Tuke (1827–1895), English alienis...
# 1393   15579  "I Luv U" is a song by English indie rock grou...
# 6007     329  Frank worked in the bank his family ran until ...
# 2837   10186  Distance Measurement Equipment (DME) is used t...
# ...      ...                                                ...
# 2659     358  Moazzam Tufail Malik  is a British diplomat se...
# 2856    3558  *Hatton\n*Lind\n*Othello\n*Ritzville\n*Washtuc...
# 4610    1132  * Brian Bruney, New York Yankees reliever\n* H...
# 3796    3542  The Soča (in Slovene) or Isonzo (in Italian) (...
# 4536     262  Geoffrey of Monmouth (, ) (c. 1100 – c. 1155) ...
#
#                                                new_text  \
# 7191  Argyle, M. (1975).  Bodily communication.  New...
# 1582  *Daniel Hack Tuke (1827–1895), English alienis...
# 1393  "I Luv U" is a song by English indie rock grou...
# 6007  Frank worked in the bank that his father initi...
# 2837  Distance Measurement Equipment (DME) is used t...
# ...                                                 ...
# 2659  Moazzam Tufail Malik  is a British civil serva...
# 2856  *Hatton\n*Lind\n*Othello\n*Ritzville\n*Washtuc...
# 4610  * Brian Bruney, New York Yankees reliever\n* H...
# 3796  The Soča ( in Slovene) or Isonzo (in Italian) ...
# 4536  Geoffrey of Monmouth (, ) (c. 1100 – c. 1155) ...
#
#                                            comment  \
# 7191                                         + ja:
# 1582                         Added Gordon Turnbull
# 1393                 "to date" does not make sense
# 6007      /* Marriage and children */Added content
# 2837                                       tighten
# ...                                            ...
# 2659               Updated professional background
# 2856                    /* Cities and towns */ +pt
# 4610       added Joshua Marquis, District Attorney
# 3796                                 Pronunciation
# 4536  this is important and should be in the intro
#
#                                                    docs  \
# 7191  Category:ja:Body language · あくび · 欠伸 · メロイックサイ...
# 1582  Additional lists of psychiatrists can be found...
# 1393  The Ordinary Boys - I Luv U - With Full Lyrics...
# 6007  Otto Frank married former Amsterdam neighbor a...
# 2837  DME is a fundamentally simple technology that ...
# ...                                                 ...
# 2659  Moazzam Tufail Malik CMG is a British civil se...
# 2856  Adams County's two most populous cities are Ri...
# 4610  Joshua K. Marquis (born 1952) is an attorney a...
# 3796  Soča (pronounced [ˈsoːtʃa], Italian: Sonzia) i...
# 4536  No. It's not even a historical record.\n\nDOC_...
#
#                                                    diff  \
# 7191                                    \nja:ボディー・ランゲージ
# 1582  \n*Gordon Turnbull, Scottish, posttraumatic st...
# 1393                                       . It reached
# 6007  that his\nther initially run -and that he and ...
# 2837  . Once a pilot tunes onto a particular VOR fre...
# ...                                                 ...
# 2659                                 civil servant and
# 2856                 \npt:Condado de Adams (Washington)
# 4610              \n* Joshua Marquis, District Attorney
# 3796                                     in Slovene) or
# 4536      ; but is now considered unreliable as history
#
#                                  title  \
# 7191                     Body language
# 1582             List of psychiatrists
# 1393  I Luv U (The Ordinary Boys song)
# 6007                        Otto Frank
# 2837                          Avionics
# ...                                ...
# 2659          Moazzam Malik (diplomat)
# 2856          Adams County, Washington
# 4610                   Astoria, Oregon
# 3796                              Soča
# 4536              Geoffrey of Monmouth
#
#                                          search_queries counter_found_docs  \
# 7191          [Body language Reference \nja:ボディー・ランゲージ]               [20]
# 1582  [List of psychiatrists  T \n*Gordon Turnbull, ...               [28]
# 1393    [I Luv U (The Ordinary Boys song) . It reached]               [28]
# 6007  [Otto Frank Marriage and children that his, Ot...           [27, 27]
# 2837  [Avionics  DME . Once a pilot tunes onto a par...       [29, 29, 29]
# ...                                                 ...                ...
# 2659      [Moazzam Malik (diplomat) civil servant and ]               [28]
# 2856  [Adams County, Washington  Cities and towns \n...                [8]
# 4610  [Astoria, Oregon Notable residents \n* Joshua ...               [13]
# 3796                             [Soča  in Slovene) or]               [28]
# 4536  [Geoffrey of Monmouth ; but is now considered ...               [28]
#
#                section_name  is_good  \
# 7191              Reference     True
# 1582                     T      True
# 1393                            True
# 6007  Marriage and children     True
# 2837                   DME      True
# ...                     ...      ...
# 2659                            True
# 2856      Cities and towns      True
# 4610      Notable residents     True
# 3796                            True
# 4536                            True
#
#                                          docs_processed
# 7191  DOC0: Category:ja:Body language · あくび · 欠伸 · メ...
# 1582  DOC0: Additional lists of psychiatrists can be...
# 1393  DOC0: The Ordinary Boys - I Luv U - With Full ...
# 6007  DOC0: Otto Frank married former Amsterdam neig...
# 2837  DOC0: DME is a fundamentally simple technology...
# ...                                                 ...
# 2659  DOC0: Moazzam Tufail Malik CMG is a British ci...
# 2856  DOC0: Adams County's two most populous cities ...
# 4610  DOC0: Joshua K. Marquis (born 1952) is an atto...
# 3796  DOC0: Soča (pronounced [ˈsoːtʃa], Italian: Son...
# 4536  DOC0: No. It's not even a historical record DO...
#
# [600 rows x 12 columns]

# %%
device = CONFIG.device
CONFIG.beam_size = 3
idx_ = np.random.choice(len(ds_val), 20)

with torch.no_grad():
    for i in idx_:
        src_, tgt_ = ds_val[i]

        generated = model_edit.generate(torch.tensor(src_['input_ids']).view(1,-1).to(device), 
                                                      num_beams=CONFIG.beam_size, 
#                                                       pad_token_id=tokenizer.pad_token_id, 
#                                                       bos_token_id=tokenizer.bos_token_id, 
#                                                       eos_token_id=tokenizer.eos_token_id,
                                                          num_return_sequences=1,
                                                     max_length=512)
        generated = generated.cpu()

        src_text = tokenizer.decode(src_['input_ids'], skip_special_tokens=True)
        tgt_text = tokenizer.decode(tgt_['input_ids'], skip_special_tokens=True)
        
        tgt_comment, tgt_txt = extract_com8text_from_tgt(tgt_text)
        src_txt, _ = extract_text8docs_from_src(src_text)

        print(f'\n\n---------- QUERY {i} ----------')
        print(f'X_t:\n{src_txt}\n')
        print(f'X_t+1:\n{tgt_txt}\n')
        print(f'Comment:\t{tgt_comment}\n')
        print(f'GENERATED:')

        for j in range(1):
            to_gen = generated[j]
            gen_text = tokenizer.decode(to_gen, skip_special_tokens=True)
            gen_comment, gen_txt = extract_com8text_from_tgt(tgt_text)
            print(f'Comment:\t{gen_comment}\n')
            print(f'gen X_t+1:\n{gen_txt}\n')
            
        diff = val1.iloc[i]['diff']
        print(f'Tgt diff:\n{diff}\n')
        
        doc_str = '\n'.join(_.split('doc'))
        print(f'Docs:\n{doc_str}')
# Out:
# ---------- QUERY 256 ----------
# X_t:
# * sister cities of bishkek include colorado springs, colorado (1994) and meriden, connecticut (2005).
#
# X_t+1:
# * sister cities of bishkek include colorado springs, colorado (1994) and meriden, connecticut (2005). *ankara, turkey
#
# Comment:	COM_SEP added a sister city based on list of sister cities
#
# GENERATED:
# Comment:	COM_SEP added a sister city based on list of sister cities
#
# gen X_t+1:
# * sister cities of bishkek include colorado springs, colorado (1994) and meriden, connecticut (2005). *ankara, turkey
#
# Tgt diff:
#
# *Ankara, Turkey
#
# Docs:
#
# 0: bishkek is situated near the kazakhstan-kyrgyzstan border. its population was 1,074,075 in 2021.. sister cities. bishkek is twinned with: almaty, kazakhstan (1994) ankara, turkey (1992) ashgabat, turkmenistan (2018) colorado springs, united states (1994) doha, qatar (2014) gumi, south korea (1991) izmir, turkey (1994) kyiv
# 1: amman, jordan ashgabat, turkmenistan astana, kazakhstan bangkok, thailand beijing, china bishkek, kyrgyzstan bissau, guinea-bissau bucharest, romania budapest, hungary chișinău, moldova damascus, syria doha, qatar dushanbe, tajikistan hanoi, vietnam havana, cuba islamabad, pakistan kabul, afghanistan kazan, russia khartoum, sudan
# 2: there are 9 ways to get from ankara to bishkek by plane, bus, train or car select an option below to see step-by-step directions and to compare ticket prices and travel times in rome2rios travel planner. recommended option fly ankara to manas fly from ankara (esb) to manas (fru) 10h 37m $162 - $652 cheapest option fly ankara to almaty, bus
# 3: bishkek (kyrgyz: икек, bişkek,, ipa: [bikek], kazakh: кек), formerly pishpek
#
#
# ---------- QUERY 582 ----------
# X_t:
# anta sports is the official supplier and sponsor of numerous teams, players and associations, and athletes including: kevin garrnett, klay thompson and rajon rondo.
#
# X_t+1:
# anta sports is the official supplier and sponsor of numerous teams, players and associations, and athletes including: kevin garrnett, klay thompson, rajon rondo, and chandler parsons.
#
# Comment:	COM_SEP /* sponsorships */added content
#
# GENERATED:
# Comment:	COM_SEP /* sponsorships */added content
#
# gen X_t+1:
# anta sports is the official supplier and sponsor of numerous teams, players and associations, and athletes including: kevin garrnett, klay thompson, rajon rondo, and chandler parsons.
#
# Tgt diff:
# , and Chandler Parsons
#
# Docs:
#
# 0: mar 10, 2015 — mavericks f chandler parsons, who has a five-year, $5m deal with chinese shoe company anta, "wore jordan brand sneakers with the logos
# 1: sources told sole collector's nick depaula the houston rockets forward will be leaving nike to sign a new deal with chinese brand anta: after weighing interest
# 2: chandler parsons, aged 25, was selected by the houston rockets in the 2011. great emphasis on branding by integrating sports resources and sponsorship,
# 3: anta sports signs on as official sponsor for chandler parsons. participating in this sponsorship deal: data open uri20141112 64162 lbwb1g?1415810660
# 4: research sponsorship activity for chandler parsons including latest sponsorship. sports, parsons has gained endorsements with chinese sneaker brand anta,
# 5: mar 6, 2014 — since signing with relativity sports, parsons has gained endorsements with chinese sneaker brand anta, smartphone provider zte and buffalo [
#
#
# ---------- QUERY 320 ----------
# X_t:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12. in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion. the episode was dedicated to isaac hayes who died on august 10 of that year.
#
# X_t+1:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12, and was dedicated to isaac hayes who died on august 10 of that year.in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion.
#
# Comment:	COM_SEP /* top */ moved sentence
#
# GENERATED:
# Comment:	COM_SEP /* top */ moved sentence
#
# gen X_t+1:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12, and was dedicated to isaac hayes who died on august 10 of that year.in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion.
#
# Tgt diff:
# , and was dedicated to Isaac Hayes who died on August 10 of that year
#
# Docs:
#
# 0: isaac lee hayes jr. (august 20, 1942 – august 10, 2008) was an american singer, actor, songwriter, and composer. he was one of the creative forces behind
# 1: aug 13, 2008 — the soul legend died on sunday (august 10) after apparently suffering a stroke at his home in memphis. hayes supplied the voice for the
# 2: nov 20, 2019 — the china probrem dedicated to isaac hayes-810-flipper. is dedicated to isaac hayes(chef) who died on 8/10/8. 8/10 front and back
# 3: isaac hayes : biography. august 20, 1942 – august 10, 2008. two months after his death, the south park episode "the china probrem" was dedicated to him
# 4: the episode was dedicated to isaac hayes who died in august of that year. contents. 1 plot; 2 cultural references; 3
# 5: aug 30, 2022 — as for isaac hayes, he passed away in 2008, and the episode “the china problem” was dedicated to him. south park is no stranger to
#
#
# ---------- QUERY 428 ----------
# X_t:
# i have to admit that this article needs a lot of fixing-up. need to define a lot of concepts (they produce wind??), better sentence formatting, etc. --gabycs 21:15, 18 may 2007 (utc) hey who wrote this its great —preceding unsigned comment added by 66.214.171.70 (talk) 01:48, 10 june 2008 (utc)
#
# X_t+1:
# i have to admit that this article needs a lot of fixing-up. need to define a lot of concepts (they produce wind??), better sentence formatting, etc. --gabycs 21:15, 18 may 2007 (utc) hey who wrote this its great —preceding unsigned comment added by 66.214.171.70 (talk) 01:48, 10 june 2008 (utc) :excuse me? you might need a lesson in wp:own :d. anyways, even though i only have a basic understanding of the subject, i'm working on the refs. iceunshattered (talk) 00:49, 13 august 2008 (utc)
#
# Comment:	COM_SEP /* really unclear */ reply
#
# GENERATED:
# Comment:	COM_SEP /* really unclear */ reply
#
# gen X_t+1:
# i have to admit that this article needs a lot of fixing-up. need to define a lot of concepts (they produce wind??), better sentence formatting, etc. --gabycs 21:15, 18 may 2007 (utc) hey who wrote this its great —preceding unsigned comment added by 66.214.171.70 (talk) 01:48, 10 june 2008 (utc) :excuse me? you might need a lesson in wp:own :d. anyways, even though i only have a basic understanding of the subject, i'm working on the refs. iceunshattered (talk) 00:49, 13 august 2008 (utc)
#
# Tgt diff:
#
#
# :Excuse me? You might need a lesson in WP:OWN :D. Anyways, even though I only have a basic understanding of the subject, I'm working on the refs. IceUnshattered (talk) 00:49, 13 August 2008 (UTC)
#
# Docs:
#
# 0: based on data taken in the united states, cirrus cloud cover varies diurnally and seasonally. in the summer, at noon, the cover is the lowest, with an average
#
#
# ---------- QUERY 339 ----------
# X_t:
# the lough mask murders were the murders on 3 january 1882 of joseph huddy and his grandson, john huddy, in the townland of upper cloghbrack, county galway, on the southern shore of lough mask in the west of ireland. joseph huddy was the bailiff for arthur guinness, lord ardilaun, a major landlord in a region where agrarian disturbances of the land war were prominent. the victims' bodies were found in the lough itself. the controversial lack of credible witnesses led to four well-publicised trials of the accused in december 1882.
#
# X_t+1:
# the lough mask murders were the murders on 3 january 1882 of joseph huddy and his grandson, john huddy, in the townland of upper cloghbrack, county galway, on the southern shore of lough mask in the west of ireland. joseph huddy was the bailiff for arthur guinness, lord ardilaun, a major landlord in a region where agrarian disturbances of the land war were prominent. the victims' bodies were weighed down and concealed in the lough itself. the controversial lack of credible witnesses led to four well-publicised trials of the accused in december 1882.
#
# Comment:	COM_SEP concealed, not just "found"
#
# GENERATED:
# Comment:	COM_SEP concealed, not just "found"
#
# gen X_t+1:
# the lough mask murders were the murders on 3 january 1882 of joseph huddy and his grandson, john huddy, in the townland of upper cloghbrack, county galway, on the southern shore of lough mask in the west of ireland. joseph huddy was the bailiff for arthur guinness, lord ardilaun, a major landlord in a region where agrarian disturbances of the land war were prominent. the victims' bodies were weighed down and concealed in the lough itself. the controversial lack of credible witnesses led to four well-publicised trials of the accused in december 1882.
#
# Tgt diff:
# weighed down and concealed in the lough
#
# Docs:
#
# 0: the victims' bodies were weighed down and concealed in the lough itself. the controversial lack of credible witnesses led to four well-publicised trials of
# 1: the boy ran. it was at the corner of the house joe huddy was knocked down. when the boy ran michael flynn followed him, caught him by the collar of the coat,
# 2: pass down through th e. and thirty- seven feet below th e surface of lough mask.. scarcely possible that 9000 persons were killed on either side
# 3: the lough mask murders were the murders on 3 january 1882 of joseph huddy and his grandson, john huddy, in the townland of upper cloghbrack, county galway,
# 4: by a dolan  2021  cited by 2 — the people who witnessed killing in ireland were part of why it challenged contemporary senses of what war was. it was not supposed to happen in
# 5: by h morris  1928  cited by 1 — it will be conceded right off that since the beginning of the. to the shore of lough mask, where he gets conveniently killed
# ---------- QUERY 85 ----------
# X_t:
# patrick richard henry wright, baron wright of richmond (born 28 june 1931) is a retired british diplomat and former head of hm diplomatic service. he sat in the house of lords as a crossbencher until his retirement on 17 december 2019.lord wright of richmond, parliament.uk, 18 december 2019
#
# X_t+1:
# patrick richard henry wright, baron wright of richmond (born 28 june 1931) is a retired british diplomat and former head of hm diplomatic service. he sat in the house of lords as a crossbencher from 10 february 1994 until his retirement on 17 december 2019.lord wright of richmond, parliament.uk, 18 december 2019
#
# Comment:	COM_SEP /* top */ m
#
# GENERATED:
# Comment:	COM_SEP /* top */ m
#
# gen X_t+1:
# patrick richard henry wright, baron wright of richmond (born 28 june 1931) is a retired british diplomat and former head of hm diplomatic service. he sat in the house of lords as a crossbencher from 10 february 1994 until his retirement on 17 december 2019.lord wright of richmond, parliament.uk, 18 december 2019
#
# Tgt diff:
#  from 10 February 1994
#
# Docs:
#
# 0: patrick richard henry wright, baron wright of richmond, gcmg (28 june 1931 - 6 march 2020) was a british diplomat who served as head of hm diplomatic service. he sat in the house of lords as a crossbencher from 10 february 1994 until his retirement on 17 december 2019. [2
# 1: patrick richard henry wright, baron wright of richmond gcmg (28 june 1931 - 6 march 2020) was a british diplomat and former head of hm diplomatic service. he sat in the house of lords as a crossbencher from 10 february 1994 until his retirement on 17 december 2019. [2
# 2: patrick richard henry wright, baron wright of richmond gcmg (28 june 1931 - 6 march 2020) was a british diplomat and former head of hm diplomatic service. he sat in the house of lords as a crossbencher from 10 february 1994 until his retirement on 17 december 2019.. in 1977, wright was appointed ambassador to luxembourg and to syria in 1979, where he remained until 1981
# 3: background. patrick wright, the son of herbert and rachel wright, was educated at marlborough college.having served in the royal artillery in 1950 and 1951, he went up to merton college, oxford where he graduated with a bachelor of arts in literae humaniores in 1955..
#
#
# ---------- QUERY 518 ----------
# X_t:
# new york state route 20sy was a state highway that connected u.s. route 20 to downtown syracuse via skaneateles, camillus, manlius, and cazenovia in onondaga county, new york and madison county, new york. the western terminus of the route was at us 20 and ny 321 in skaneateles while the eastern terminus was to the east at ny 20n, and ny 92 in cazenovia. in between, ny 20sy overlapped several routes, including ny 5, ny 92, ny 20n and ny 173; in fact, all but one mile of the route was concurrent with another state highway or u.s. route. ny 20sy was assigned by 1952 and removed from the state highway system in 1962, leaving the skaneateles-syracuse-manlius-cazenovia routing with only the routes that ny 20sy overlapped.
#
# X_t+1:
# new york state route 20sy was a state highway that connected u.s. route 20 to downtown syracuse via skaneateles, camillus, manlius, and cazenovia in onondaga county, new york and madison county, new york. the western terminus of the route was at us 20 and ny 321 in skaneateles while the eastern terminus was to the east at ny 20n, and ny 92 in cazenovia. in between, ny 20sy overlapped several routes, including ny 5, ny 92, ny 20n and ny 173; in fact, all but one mile (1.6 km) of the route was concurrent with another state highway or u.s. route. ny 20sy was assigned by 1952 and removed from the state highway system in 1962, leaving the skaneateles-syracuse-manlius-cazenovia routing with only the routes that ny 20sy overlapped.
#
# Comment:	COM_SEP units/dates/other using [[project:autowikibrowser|awb]]
#
# GENERATED:
# Comment:	COM_SEP units/dates/other using [[project:autowikibrowser|awb]]
#
# gen X_t+1:
# new york state route 20sy was a state highway that connected u.s. route 20 to downtown syracuse via skaneateles, camillus, manlius, and cazenovia in onondaga county, new york and madison county, new york. the western terminus of the route was at us 20 and ny 321 in skaneateles while the eastern terminus was to the east at ny 20n, and ny 92 in cazenovia. in between, ny 20sy overlapped several routes, including ny 5, ny 92, ny 20n and ny 173; in fact, all but one mile (1.6 km) of the route was concurrent with another state highway or u.s. route. ny 20sy was assigned by 1952 and removed from the state highway system in 1962, leaving the skaneateles-syracuse-manlius-cazenovia routing with only the routes that ny 20sy overlapped.
#
# Tgt diff:
# (1.6 km)
#
# Docs:
#
# 0: new york state route 20sy (ny 20sy) was a state highway in the vicinity of the city of. length, 38.13 mi (61.36 km). existed, 1951–1961. major junctions
# 1: u.s. route 20 in new york ; length, 372.32 mi (599.19 km) ; existed, november 11, 1926–present ; west end, us 20 at the pennsylvania state line in ripley
# 2: ny 173 parallels ny 5 for about 1 mile (1.6 km) before connecting to westbound ny 5 by way of a partial interchange; the eastbound connection is made by way of
# 3: new york state route 96 (ny 96) is a 126.01-mile-long (202.79 km). just over 1 mile (1.6 km) north of owego village in the town of owego, ny 96 meets the
# 4: not far to the northeast, the highway meets ny 386, which joins ny 33a for one mile (1.6 km) to chili center, chili
#
#
# ---------- QUERY 154 ----------
# X_t:
# wang bao wrote nine poems in the book of songs style, plus a luan (envoi), which were incorporated into the chu ci anthology. wang bao is also known for writing in the fu style which was particularly popular during the han dynasty, two examples being his "the flute" and "the ganquan palace".hawkes, 269 the fu on the ganquan palace () was written about the summer resort favored by han wudi and other emperors of the han, and was in what is now chunhua county, of xianyang region, shaanxi province, china), and the site is considered to be one of the major national historical and cultural sites of shaanxi. "the slave's contract" is an example of humorous writing.hawkes, 269
#
# X_t+1:
# wang bao wrote nine poems in the book of songs style, plus a luan (envoi), which were incorporated into the chu ci anthology. wang bao is also known for writing in the fu style, which was particularly popular during the han dynasty, two examples being his "the flute" and "the ganquan palace".hawkes, 269 the fu on the ganquan palace () was written about the summer resort favored by han wudi and other emperors of the han, and was in what is now chunhua county, of xianyang region, shaanxi province, china), and the site is considered to be one of the major national historical and cultural sites of shaanxi. "the slave's contract" is an example of humorous writing, in which wang bao somewhat cruelly pretends to propose the purchase of a certain irascible old slave, presenting an extended account of the onerous list of duties to which he would be responsible to perform.hawkes, 269
#
# Comment:	COM_SEP /* works */ more
#
# GENERATED:
# Comment:	COM_SEP /* works */ more
#
# gen X_t+1:
# wang bao wrote nine poems in the book of songs style, plus a luan (envoi), which were incorporated into the chu ci anthology. wang bao is also known for writing in the fu style, which was particularly popular during the han dynasty, two examples being his "the flute" and "the ganquan palace".hawkes, 269 the fu on the ganquan palace () was written about the summer resort favored by han wudi and other emperors of the han, and was in what is now chunhua county, of xianyang region, shaanxi province, china), and the site is considered to be one of the major national historical and cultural sites of shaanxi. "the slave's contract" is an example of humorous writing, in which wang bao somewhat cruelly pretends to propose the purchase of a certain irascible old slave, presenting an extended account of the onerous list of duties to which he would be responsible to perform.hawkes, 269
#
# Tgt diff:
# , which was particularly popular during the
# , in which Wang Bao somewhat cruelly pretends to propose the purchase of a certain irascible old slave, presenting an extended account of the onerous list of duties to which he would be responsible to perform
#
# Docs:
#
# 0: wang bao is particularly known today as the author of the chu ci section "nine regrets". his poetry was not as famous as "li sao" or "heavenly questions"
# 1: jun 7, 2018 — wang bao-yuan is a skilled craftsman of the cut-and-paste ceramic art. a student of he jinlong (, a cut-and-paste ceramics master from
# 2: his works were typically inspired by the densely tangled brushwork of wang meng of the yuan (exemplified by his painting bao'en temple, sumitomo collection,
# 3: may 18, 2016 — dating back to 1744, wang bao he was originally situated in the xiaodongmen area of the old city, before moving to its current fuzhou lu
# 4: nov 24, 2021 — for anyone interested in food in shanghai then hairy crab season is by far the most interesting part of the year. during the 9th and 10th
# 5: they were explored as physicochemical encapsulation materials. particularly, the sulfur cathode based on tripleshelled tio2x homss delivered a
# ---------- QUERY 336 ----------
# X_t:
# german does not have an ablative case (but exceptionally, latin ablative case-forms were used from the 17th to the 19th century after some prepositions, for example after von in von dem nomine: ablative of the latin loanword nomen). grammarians at that time, such as justus georg schottel, kaspar von stieler ("der spate"), johann balthasar von antesperg and johann christoph gottsched, listed an ablative case (as the sixth case after nominative, genitive, dative, accusative and vocative) for german words. they arbitrarily considered the dative case after some prepositions to be an ablative, as in ("from the man" or "of the man") and ("with the man"), while they considered the dative case after other prepositions or without a preposition as to be a dative.
#
# X_t+1:
# german does not have an ablative case (but exceptionally, latin ablative case-forms were used from the 17th to the 19th century after some prepositions, for example after von in von dem nomine: ablative of the latin loanword nomen). grammarians at that time, such as justus georg schottel, kaspar von stieler ("der spate"), johann balthasar von antesperg and johann christoph gottsched, listed an ablative case (as the sixth case after nominative, genitive, dative, accusative and vocative) for german words. they arbitrarily considered the dative case after some prepositions to be an ablative, as in ("from the man" or "of the man") and ("with the man"), while they considered the dative case after other prepositions or without a preposition, as in, to be a dative.
#
# Comment:	COM_SEP added commas for clarity
#
# GENERATED:
# Comment:	COM_SEP added commas for clarity
#
# gen X_t+1:
# german does not have an ablative case (but exceptionally, latin ablative case-forms were used from the 17th to the 19th century after some prepositions, for example after von in von dem nomine: ablative of the latin loanword nomen). grammarians at that time, such as justus georg schottel, kaspar von stieler ("der spate"), johann balthasar von antesperg and johann christoph gottsched, listed an ablative case (as the sixth case after nominative, genitive, dative, accusative and vocative) for german words. they arbitrarily considered the dative case after some prepositions to be an ablative, as in ("from the man" or "of the man") and ("with the man"), while they considered the dative case after other prepositions or without a preposition, as in, to be a dative.
#
# Tgt diff:
# , as in , to be a
#
# Docs:
#
# 0: there is no ablative case in modern germanic languages such as german and english. there was an ablative case in the early stages of ancient greek, but it
# 1: german distinguishes between the process of something/someone getting from a to b and the state of being there. when the movement to somewhere is emphasized,
# 2: like all the other cases (nominative, accusative, genitive), we can think of the dative case as being a particular'slot' in any given sentence that gets filled
# 3: the accusative case, known as the objective case in english, answers the question “wen?” or “whom?” and describes the direct object of a sentence. let's see how
# 4: the literal translation would be at first face or at first appearance, from the feminine form of "primus" (first) and "facies" (face), both in the ablative case
# 5: the answer is that grammatical relations are encoded in german in terms of morphological case marking. in particular, the subjects of finite clauses in german
#
#
# ---------- QUERY 120 ----------
# X_t:
# *2007 – the dumb waiter, directed by harry burton and starring lee evans as gus and jason isaacs as ben, at the trafalgar studios, in london, from february 2 to march 24, 2007; 50th-anniversary production., 1985 – a film version was broadcast by the bbc on july 23, 1985. * 1987 – robert altman directed a made-for-tv feature film version of the dumb waiter, starring john travolta and tom conti, filmed in canada and first televised in the united states on wabc-tv on may 12, 1987.. one of two-part series, including a film of the room. accessed june 27, 2008. [in the united states, this 60-min. film was televised on abc-tv with pinter's original title, the dumb waiter; it is the second of two parts of altman's two-film series entitled basements; part one includes altman's film version of the room.] [rpt. from all movie guide.]
#
# X_t+1:
# *2007 – the dumb waiter, directed by harry burton and starring lee evans as gus and jason isaacs as ben, at the trafalgar studios, in london, from february 2 to march 24, 2007; 50th-anniversary production., 1985 – a film version was broadcast by the bbc on july 23, 1985. * 1987 – robert altman directed a made-for-tv feature film version of the dumb waiter, starring john travolta and tom conti, filmed in canada and first televised in the united states on wabc-tv on may 12, 1987.. one of two-part series, including a film of pinter's first play, the room. accessed june 27, 2008. [in the united states, this 60-min. film was televised on abc-tv with pinter's original title, the dumb waiter; it is the second of two parts of altman's two-film series entitled basements.] [rpt. from all movie guide.]
#
# Comment:	COM_SEP /* television films */ removed redundancy
#
# GENERATED:
# Comment:	COM_SEP /* television films */ removed redundancy
#
# gen X_t+1:
# *2007 – the dumb waiter, directed by harry burton and starring lee evans as gus and jason isaacs as ben, at the trafalgar studios, in london, from february 2 to march 24, 2007; 50th-anniversary production., 1985 – a film version was broadcast by the bbc on july 23, 1985. * 1987 – robert altman directed a made-for-tv feature film version of the dumb waiter, starring john travolta and tom conti, filmed in canada and first televised in the united states on wabc-tv on may 12, 1987.. one of two-part series, including a film of pinter's first play, the room. accessed june 27, 2008. [in the united states, this 60-min. film was televised on abc-tv with pinter's original title, the dumb waiter; it is the second of two parts of altman's two-film series entitled basements.] [rpt. from all movie guide.]
#
# Tgt diff:
# Pinter's first play, The
#
# Docs:
#
# 0: the dumb waiter is a one-act play by harold pinter written in 1957. the dumb waiter. harold pinter's - the dumb waiter - presented by stairwell theater
# 1: the dumb waiter is a two-character play set in the basement of an old rooming house, connected to the rooms above by a dumbwaiter and an intercom
# 2: first encounter. although the dumb waiter is a one-act play with no scene divisions, it is unobtrusively divided into a series of encounters between ben and gus
# 3: in 1957, he wrote his first play in four days, the room, a sign of the prolific output to come. his first produced play—the birthday partycame a year later. the
# 4: nov 21, 2015 — capital t theatre is proud to present nobel prize-winning playwright harold pinter's acclaimed and sharp one-act play the
#
#
# ---------- QUERY 106 ----------
# X_t:
# the tepuis are table-like mountains found only in the guiana highlands. these geological formations tend to be found as isolated entities rather than in mountain range fashion, which makes them the host of a unique array of endemic plant and animal species. some of the most outstanding tepuis are autana, neblina (the highest one, on the venezuelan-brazil border), auyantepui and monte roraima. they are typically composed of precambrian sandstone rocks, very hard to climb, that rise abruptly from the jungle, giving rise to spectacular natural scenery. auyantepui in particular is the source of angel falls, the world's tallest waterfall. de:tepui no:tepui
#
# X_t+1:
# the tepuis are table-like mountains found only in the guiana highlands. these geological formations tend to be found as isolated entities rather than in mountain range fashion, which makes them the host of a unique array of endemic plant and animal species. some of the most outstanding tepuis are autana, neblina (the highest one, on the venezuelan-brazil border), auyantepui and monte roraima. they are typically composed of precambrian sandstone rocks, very hard to climb, that rise abruptly from the jungle, giving rise to spectacular natural scenery. auyantepui in particular is the source of angel falls, the world's tallest waterfall., little dee visited the venezualan tepuis in february 2005. de:tepui no:tepui
#
# Comment:	COM_SEP little dee visits the tepui
#
# GENERATED:
# Comment:	COM_SEP little dee visits the tepui
#
# gen X_t+1:
# the tepuis are table-like mountains found only in the guiana highlands. these geological formations tend to be found as isolated entities rather than in mountain range fashion, which makes them the host of a unique array of endemic plant and animal species. some of the most outstanding tepuis are autana, neblina (the highest one, on the venezuelan-brazil border), auyantepui and monte roraima. they are typically composed of precambrian sandstone rocks, very hard to climb, that rise abruptly from the jungle, giving rise to spectacular natural scenery. auyantepui in particular is the source of angel falls, the world's tallest waterfall., little dee visited the venezualan tepuis in february 2005. de:tepui no:tepui
#
# Tgt diff:
# ,  Little Dee visited the Venezualan Tepuis in February 2005.
#
#
#
# Docs:
#
# 0: the tepuis are table-like mountains found only in the guiana highlands. these geological formations tend to be found as isolated entities rather than in
# ---------- QUERY 167 ----------
# X_t:
# telenovelas are popular in venezuela, and some venezuelan productions (such as 1992's cara sucia) are distributed internationally. perhaps the best known television show internationally is however president hugo chávez' weekly talk show aló presidente, which began in 1999. state television in venezuela has an unusually low audience share, of around 2% to 5%, although the government also makes regular use of cadenas (mandatory interruptions on all channels to show government broadcasts).
#
# X_t+1:
# telenovelas are popular in venezuela, and some venezuelan productions (such as 1992's cara sucia) are distributed internationally. perhaps the best known television show internationally is however president hugo chávez' weekly talk show aló presidente, which began in 1999 and ran with occasional breaks until 2012. state television in venezuela has an unusually low audience share, of around 2% to 5%, although the government also makes regular use of cadenas (mandatory interruptions on all channels to show government broadcasts).
#
# Comment:	COM_SEP /* programming */ update
#
# GENERATED:
# Comment:	COM_SEP /* programming */ update
#
# gen X_t+1:
# telenovelas are popular in venezuela, and some venezuelan productions (such as 1992's cara sucia) are distributed internationally. perhaps the best known television show internationally is however president hugo chávez' weekly talk show aló presidente, which began in 1999 and ran with occasional breaks until 2012. state television in venezuela has an unusually low audience share, of around 2% to 5%, although the government also makes regular use of cadenas (mandatory interruptions on all channels to show government broadcasts).
#
# Tgt diff:
#  and ran with occasional breaks until 2012
#
# Docs:
#
# 0: perhaps the best known television show internationally is however president hugo chávez' weekly talk show aló presidente, which began in 1999 and ended in 2012
# 1: radio caracas televisión (rctv) was a venezuelan free-to-air television network headquartered in the caracas neighborhood of quinta crespo
# 2: an autopsy showed acosta suffered multiple broken bones, burns, and other wounds. on september 24, two low-ranking gnb officers were sentenced to imprisonment
# 3: haider film songs hd, tinni dutta facebook, szerelmeseknek program, over analyzing. chariot de feu bo, dressy casual mens fashion, judo broken bones,
# 4: by cj arnson  2021 — the wilson center's latin american program provides non-partisan ex-. venezuela, russian tv hosts can denounce us foreign policy in the
# 5: while chávez won three elections democratically, the last one in 2012 was. was the socialist/populist president of venezuela from 1999 until his death
#
#
# ---------- QUERY 110 ----------
# X_t:
# there is a general phrase of "up and down" used numerous times that is a common philacious statement unsustained by logical science. there might be a care taken to adjust it to "up or down" to distinguish movement instead of perpetuating the illogical nature of the statement. 2605:e000:9161:a500:3832:5234:5ba4:7db6 (talk) 06:36, 5 october 2017 (utc)
#
# X_t+1:
# there is a general phrase of "up and down" used numerous times that is a common philacious statement unsustained by logical science. there might be a care taken to adjust it to "up or down" to distinguish movement instead of perpetuating the illogical nature of the statement. 2605:e000:9161:a500:3832:5234:5ba4:7db6 (talk) 06:36, 5 october 2017 (utc) : not done: this has been discussed with you at length on your talk page. "up and down" is correct. nihlus 09:51, 5 october 2017 (utc)
#
# Comment:	COM_SEP /* semi-protected edit request on 5 october 2017 */ responded to edit request ([[wp:eph|eph]])
#
# GENERATED:
# Comment:	COM_SEP /* semi-protected edit request on 5 october 2017 */ responded to edit request ([[wp:eph|eph]])
#
# gen X_t+1:
# there is a general phrase of "up and down" used numerous times that is a common philacious statement unsustained by logical science. there might be a care taken to adjust it to "up or down" to distinguish movement instead of perpetuating the illogical nature of the statement. 2605:e000:9161:a500:3832:5234:5ba4:7db6 (talk) 06:36, 5 october 2017 (utc) : not done: this has been discussed with you at length on your talk page. "up and down" is correct. nihlus 09:51, 5 october 2017 (utc)
#
# Tgt diff:
#
# : Not done: This has been discussed with you at length on your talk page. "Up and down" is correct.  Nihlus 09:51, 5 October 2017 (UTC)
#
# Docs:
#
# 0: new teletubbies logo there are 60 episodes in both seasons of the new series altogether. on the right next to the title are air dates. the first season premiered on 9th november, 2015. the episode airings are divided into quarters, with 15 episodes per quarter
# 1: this article is within the scope of wikiproject television, a collaborative effort to develop and improve wikipedia articles about television programs.if you would like to participate, please visit the project page where you can join the discussion.to improve this article, please refer to the style guidelines for the type of work.style guidelines for
# 2: semi-protected edit request on 5 october 2017 [ edit] this edit request to list of teletubbies episodes and videos has been answered. set the |answered= or |ans= parameter to no to reactivate your request. there is a general phrase of up and down used numerous times that is a common philacious statement unsustained by logical science
# 3: teletubbies wiki is a teletubbies created website which aims to provide its visitors with information on all the different aspects of the hit cbbc television series, teletubbies which originally ran from 31 march 1997 - february 2001, 2002 - present on cbeebies in the uk and lasted for over 365 episodes
# 4: the gnu free
# umentation license ( gfdl) is a copyleft license for free content, designed by the free software foundation (fsf). the gfdl is a copyleft license, meaning the content can be copied, modified, and redistributed so long as the new version grants the same
#
#
# ---------- QUERY 58 ----------
# X_t:
# * john martin, author travel and history * rodger morrison, author and researcher * marlon anderson, major league baseball player *evan crawford, major league baseball player * bobby jon drinkard, contestant on reality television shows survivor: palau and survivor: guatemala * roman harper, nfl player. * wilson pickett (march 18, 1941 – january 19, 2006), r&b and soul singer and songwriter * kevin turner, nfl player
#
# X_t+1:
# * john martin, author, travel and history * rodger morrison, author and researcher * marlon anderson, major league baseball player *evan crawford, major league baseball player * bobby jon drinkard, contestant on reality television shows survivor: palau and survivor: guatemala * roman harper, nfl player. * wilson pickett (march 18, 1941 – january 19, 2006), r&b and soul singer and songwriter * kevin turner, nfl player
#
# Comment:	COM_SEP fix [[wp:dpl|links]] to [[wp:d|disambiguation]] page [[john martin]]
#
# GENERATED:
# Comment:	COM_SEP fix [[wp:dpl|links]] to [[wp:d|disambiguation]] page [[john martin]]
#
# gen X_t+1:
# * john martin, author, travel and history * rodger morrison, author and researcher * marlon anderson, major league baseball player *evan crawford, major league baseball player * bobby jon drinkard, contestant on reality television shows survivor: palau and survivor: guatemala * roman harper, nfl player. * wilson pickett (march 18, 1941 – january 19, 2006), r&b and soul singer and songwriter * kevin turner, nfl player
#
# Tgt diff:
#  author, travel and history
# * Rodger Morrison, author and researcher
# * Marlon
# nderson, Major Lea
#
# Docs:
#
# 0: elected by the people treas urer of jefferson county,. major in the 3rd alabama volu nteer infantry reg iment,. p leas ant ridge ; 3zu d district
# 1: sep 9, 2015 — saye's list of auburn accolades includes the 2006 outstanding faculty award. through their work on behalf of alabama citizens, state and
# 2: alabama. counties. pop. 1890. pop. 1900. county-towns. pop. 1900. autauga... 13,330. 17,915. prattville. albert lea.. 31,137. red wing
# 3: also, resolutions adopted at a meeting of 125 citizens of denver,. petition, signed by the lea.ding business men of new orleans, ask-
# 4: made in the county where the main office. equal to its outstanding warehouse re. alabama. basis m iddling. white. city and county: loan rate
# 5: togl'lher  ake forest college and the baptist people. born near the. one of the most important' announcements. church 1912-18; prattville, ala
# ---------- QUERY 272 ----------
# X_t:
# *callisto, the mythological figure *callisto, the moon of jupiter this is a disambiguation page; that is, one that just points to other pages that might otherwise have the same name. if you followed a link here, you might want to go back and fix that link to point to the appropriate specific page.
#
# X_t+1:
# *callisto, the mythological figure *callisto, the moon of jupiter *callisto, the content management system this is a disambiguation page; that is, one that just points to other pages that might otherwise have the same name. if you followed a link here, you might want to go back and fix that link to point to the appropriate specific page.
#
# Comment:	COM_SEP added cms link
#
# GENERATED:
# Comment:	COM_SEP added cms link
#
# gen X_t+1:
# *callisto, the mythological figure *callisto, the moon of jupiter *callisto, the content management system this is a disambiguation page; that is, one that just points to other pages that might otherwise have the same name. if you followed a link here, you might want to go back and fix that link to point to the appropriate specific page.
#
# Tgt diff:
#
# *Callisto, the content management system
#
# Docs:
#
# 0: callisto cms is an xml/xsl web-based content management system built on axkit. it supports wysiwyg xml content editing, transactional site deployment to multiple target webservers, multiple users, virtual hosting support and other features. project activity see all activity categories site management license
# 1: callisto converts your complex datasets from microsoft endpoint manager into crystal clear, responsive visuals. so intuitive, your non-technical users can easily interrogate it and take action. through one interactive portal, callisto is a single window into your entire microsoft management environment. pricing or watch our introductory video
# 2: callisto is the only dashboard portal for it pros and the helpdesk to convert complex data into clear, responsive insights from system center configuration manager. find out who callisto helps and why. who does callisto help? sys admins weve been working with microsoft sccm since sms 1.2 so we understand your challenges first hand
# 3: callisto started with a goal to build a system that empowers survivors, rebuilding their sense of agency, prioritizes privacy, and facilitates coordinated action. our solution, callisto vault, is a suite of tools designed to help survivors navigate barriers and define their own pathways toward heali
# 4: callisto is jupiters second largest moon and the third largest moon in our solar system. its surface is the most heavily cratered of any object in our solar system. images of callisto captured by passing spacecraft show bright white spots standing out against darker regions
# 5: callisto is on the list of possible places where life could exist in our solar system beyond earth. data gathered by the galileo spacecraft and from models created by scientists indicates callisto may have a salty ocean thats interacting with
#
#
# ---------- QUERY 313 ----------
# X_t:
# let f and g be functions and let x be a number such that f is differentiable at g(x) and g is differentiable at x. then by the definition of differentiability, : g(x+delta)-g(x)= delta g'(x) + epsilon(delta) where epsilon(delta)/deltato 0 as deltato 0. similarly, : f(g(x)+alpha) - f(g(x)) = alpha f'(g(x)) + eta(alpha) where eta(alpha)/alpha to 0 as alphato 0. now : f(g(x+delta))-f(g(x)) = f(g(x) + delta g'(x)+epsilon(delta)) - f(g(x)) :: = alpha_delta f'(g(x)) + eta(alpha_delta) where alpha_delta = delta g'(x) + epsilon(delta). observe that as deltato 0, alpha_delta/deltato g'(x) and eta(alpha_delta)/deltato 0. hence : fracf(g(x+delta))-f(g(x))delta to g'(x)f'(g(x))mbox as  delta to 0.
#
# X_t+1:
# let f and g be functions and let x be a number such that f is differentiable at g(x) and g is differentiable at x. then by the definition of differentiability, : g(x+delta)-g(x)= delta g'(x) + epsilon(delta), where epsilon(delta)/deltato 0, as deltato 0. similarly, : f(g(x)+alpha) - f(g(x)) = alpha f'(g(x)) + eta(alpha), where eta(alpha)/alpha to 0, as alphato 0., now : f(g(x+delta))-f(g(x)) = f(g(x) + delta g'(x)+epsilon(delta)) - f(g(x)), :: = alpha_delta f'(g(x)) + eta(alpha_delta), where alpha_delta = delta g'(x) + epsilon(delta),. observe that as deltato 0, alpha_delta/deltato g'(x) and eta(alpha_delta)/deltato 0. hence : fracf(g(x+delta))-f(g(x))delta to g'(x)f'(g(x))mbox as  delta to 0.
#
# Comment:	COM_SEP /* proof of the chain rule */ fix maths appearance
#
# GENERATED:
# Comment:	COM_SEP /* proof of the chain rule */ fix maths appearance
#
# gen X_t+1:
# let f and g be functions and let x be a number such that f is differentiable at g(x) and g is differentiable at x. then by the definition of differentiability, : g(x+delta)-g(x)= delta g'(x) + epsilon(delta), where epsilon(delta)/deltato 0, as deltato 0. similarly, : f(g(x)+alpha) - f(g(x)) = alpha f'(g(x)) + eta(alpha), where eta(alpha)/alpha to 0, as alphato 0., now : f(g(x+delta))-f(g(x)) = f(g(x) + delta g'(x)+epsilon(delta)) - f(g(x)), :: = alpha_delta f'(g(x)) + eta(alpha_delta), where alpha_delta = delta g'(x) + epsilon(delta),. observe that as deltato 0, alpha_delta/deltato g'(x) and eta(alpha_delta)/deltato 0. hence : fracf(g(x+delta))-f(g(x))delta to g'(x)f'(g(x))mbox as  delta to 0.
#
# Tgt diff:
# \, as \delta\to
# \, as \alpha\to
#
# Docs:
#
# 0: the chain rule is defined as the derivative of the composition of at least two different types of functions. this rule can be used to derive a composition of functions such as but not limited to: y ′ = d d
#
#
# ---------- QUERY 245 ----------
# X_t:
# *steven wilson – vocals, guitars, piano, samples *richard barbieri – synthesizers, hammond organ, mellotron *colin edwin – bass *chris maitland – drums, percussion
#
# X_t+1:
# *steven wilson – vocals, guitars, piano, samples, keyboards on "wake as gun" *richard barbieri – synthesizers, hammond organ, mellotron *colin edwin – bass *chris maitland – drums, percussion *theo travis - saxophone on ambulance chasing
#
# Comment:	COM_SEP /* personnel */ theo travis added
#
# GENERATED:
# Comment:	COM_SEP /* personnel */ theo travis added
#
# gen X_t+1:
# *steven wilson – vocals, guitars, piano, samples, keyboards on "wake as gun" *richard barbieri – synthesizers, hammond organ, mellotron *colin edwin – bass *chris maitland – drums, percussion *theo travis - saxophone on ambulance chasing
#
# Tgt diff:
# , Keyboards on "Wake As Gun"
#
# *Theo Travis - Saxophone on Ambulance Chasing
#
# Docs:
#
# 0: piano lessons is a single by british progressive rock band porcupine tree, from their album stupid dream, released in april 1999. wake as gun was originally recorded in 1995 and issued on the insignificance cassette. all titles by steven wilson except ambulance chasing by porcupine tree
# 1: piano lessons is a single by british progressive rock band porcupine tree, from their album stupid dream, released in april piano lessons - 4:28. ambulance chasing - 6:35. wake as gun - 3:30. wake as gun was originally recorded in 1995 and issued on the insignificance cassette. personnel. steven wilson - vocals, guitars, piano, samples, keyboards on wake as gun
# 2: piano lessons is a music singles/eps/fan club/promo recording by porcupine tree (heavy prog/progressive ambulance chasing would later appear on recordings in 2001 and wake as gun would later appear piano lessons was about as close to pop rock as porcupine tree could be. porcupine tree releases another interesting single of a great great song, piano lessons one of
# 3: listen free to porcupine tree - piano lessons (piano lessons, oceans have no memory). piano lessons - 4:28 ambulance chasing - 6:35 wake as gun - 3:30 wake as gun was originally recorded in 1995 and issued on the insignificance cassette
# 4: man wakes up as music and liberates the calm man wakes up as a child and builds a bridge of charm. oh, the silence you keep but i just wanna sleep man wakes up as a gun and doesnt get the joke. song comments on wake as gun by porcupine tree. must have javascript enabled to comment
# 5: press question mark to learn the rest of the keyboard shortcuts.
#
#
# ---------- QUERY 320 ----------
# X_t:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12. in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion. the episode was dedicated to isaac hayes who died on august 10 of that year.
#
# X_t+1:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12, and was dedicated to isaac hayes who died on august 10 of that year.in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion.
#
# Comment:	COM_SEP /* top */ moved sentence
#
# GENERATED:
# Comment:	COM_SEP /* top */ moved sentence
#
# gen X_t+1:
# "the china probrem" is the eighth episode in the twelfth season of the american animated television series south park. south park studios. accessed october 4, 2008 the 175th episode of the series overall, it originally aired on comedy central in the united states on october 8, 2008. it was the mid-season premiere for season 12, and was dedicated to isaac hayes who died on august 10 of that year.in the episode, kyle seeks to bring george lucas and steven spielberg to justice for "raping" indiana jones in indiana jones and the kingdom of the crystal skull, and cartman tries to avert a suspected chinese invasion.
#
# Tgt diff:
# , and was dedicated to Isaac Hayes who died on August 10 of that year
#
# Docs:
#
# 0: isaac lee hayes jr. (august 20, 1942 – august 10, 2008) was an american singer, actor, songwriter, and composer. he was one of the creative forces behind
# 1: aug 13, 2008 — the soul legend died on sunday (august 10) after apparently suffering a stroke at his home in memphis. hayes supplied the voice for the
# 2: nov 20, 2019 — the china probrem dedicated to isaac hayes-810-flipper. is dedicated to isaac hayes(chef) who died on 8/10/8. 8/10 front and back
# 3: isaac hayes : biography. august 20, 1942 – august 10, 2008. two months after his death, the south park episode "the china probrem" was dedicated to him
# 4: the episode was dedicated to isaac hayes who died in august of that year. contents. 1 plot; 2 cultural references; 3
# 5: aug 30, 2022 — as for isaac hayes, he passed away in 2008, and the episode “the china problem” was dedicated to him. south park is no stranger to
# ---------- QUERY 299 ----------
# X_t:
# '' cut of hkey_users if present.'this makes interoperating with regedit easier.'if len(sidstring) > 11 then if left(sidstring, 11) = "hkey_users" then sidstring = mid(sidstring, 12) end if end if'' open the wmi service and retrieve the sid'on error resume next set sidobject = getobject( _ "winmgmts:impersonationlevel=impersonate" _ ).get("win32_sid.sid='" & sidstring & "'") if err then msgbox "could not retrieve the sid.", vbokonly, "sorry" exit do end if (adapted from an example illustrating ways to create system administration tools.)
#
# X_t+1:
# '' cut off hkey_users if present.'this makes interoperating with regedit easier.'if len(sidstring) > 11 then if left(sidstring, 11) = "hkey_users" then sidstring = mid(sidstring, 12) end if end if'' open the wmi service and retrieve the sid'on error resume next set sidobject = getobject( _ "winmgmts:impersonationlevel=impersonate" _ ).get("win32_sid.sid='" & sidstring & "'") if err then msgbox "could not retrieve the sid.", vbokonly, "sorry" exit do end if (adapted from an example illustrating ways to create system administration tools.)
#
# Comment:	COM_SEP /* visual basic */ typo of->off, preformat
#
# GENERATED:
# Comment:	COM_SEP /* visual basic */ typo of->off, preformat
#
# gen X_t+1:
# '' cut off hkey_users if present.'this makes interoperating with regedit easier.'if len(sidstring) > 11 then if left(sidstring, 11) = "hkey_users" then sidstring = mid(sidstring, 12) end if end if'' open the wmi service and retrieve the sid'on error resume next set sidobject = getobject( _ "winmgmts:impersonationlevel=impersonate" _ ).get("win32_sid.sid='" & sidstring & "'") if err then msgbox "could not retrieve the sid.", vbokonly, "sorry" exit do end if (adapted from an example illustrating ways to create system administration tools.)
#
# Tgt diff:
#  SIDstring
#  End If
#  End If
#
#  '
#  '
#  If Err
#
# Docs:
#
# 0: you can add or remove comment symbols for a block of code by selecting one or more lines of code and choosing the comment () and uncomment () buttons on the edit toolbar. note you can also add comments to your code by preceding the text with the rem keyword
# 1: if you need to add comments to visual basic, here are some of the fundamental steps to making sure that you do this correctly. steps 1 determine which type of comment you want to add. programmers have several different main purposes for comments that determine the exact format and style of what will be included in the comment
# 2: the following table lists the functions that visual basic provides in the microsoft.visualbasic.strings class to search and manipulate strings. they can be regarded as visual basic intrinsic functions; that is, you do not have to call them as explicit members of a class, as the examples show
# 3: the string data type represents a series of characters (each representing in turn an instance of the char data type). this topic introduces the basic concepts of strings in visual basic. string variables an instance of a string can be assigned a literal value that represents a series of characters. for example: vb
# 4: in visual basic, the substring method is useful to
#
#
# ---------- QUERY 516 ----------
# X_t:
# binh luc () is a district (huyn) of ha nam province in the red river delta region of vietnam. bnh lc is where scientists excavated 6 dong son drum such as ngoc lu drum, v b drum and an lo drum. bnh lc is the father's homecountry of nguyen khuyen. vi:bnh lc
#
# X_t+1:
# binh luc () is a district (huyn) of ha nam province in the red river delta region of vietnam. as of 2003 the district had a population of. the district covers an area of km2. the district capital lies at. bnh lc is where scientists excavated 6 dong son drum such as ngoc lu drum, v b drum and an lo drum. bnh lc is the father's homecountry of nguyen khuyen.
#
# Comment:	COM_SEP adding text using [[project:autowikibrowser|awb]]
#
# GENERATED:
# Comment:	COM_SEP adding text using [[project:autowikibrowser|awb]]
#
# gen X_t+1:
# binh luc () is a district (huyn) of ha nam province in the red river delta region of vietnam. as of 2003 the district had a population of. the district covers an area of km2. the district capital lies at. bnh lc is where scientists excavated 6 dong son drum such as ngoc lu drum, v b drum and an lo drum. bnh lc is the father's homecountry of nguyen khuyen.
#
# Tgt diff:
#
#
# As of 2003 the district had a population of . The district covers an area of km². The district capital lies at .
#
# Docs:
#
# 0: as of 2003 the district had a population of 158,023. the district covers an area of 155 km2. the district capital lies at bnh m. bnh lc is where
# 1: in 2003, the district had a population of 80,517. the district covers an area of 998 km2. the district capital is na dng
# 2: bnh lc is a rural district of hà nam province in the red river delta region of vietnam. as of 2003 the district had a population of 158,023. the district
# 3: bnh lc is a rural district of hà nam province in the red river delta region of vietnam. as of 2003 the district had a population of 158,023
# 4: as of 2003 the district had a population of 128,849.the district covers an area of 290 km2. the district capital lies at ben luc
# 5: i t district ; capital, hùng sn ; area  total, 223 sq mi (578 km2) ; total, 223 sq mi (578 km2) ; population. (2003)  total, 163,637. time zone ; population

# %%
cc = '''Marc-André ter Stegen (born 30 April 1992) is a German professional footballer who plays as a goalkeeper for La Liga club Barcelona and the Germany national team. Known for his reflexes, passing, and ball-playing ability, he has been often nicknamed as the Berlin Wall because of his reflexes and ball control abilities as a goalkeeper'''
doc1 = """Marc-André ter Stegen signed for FC Barcelona in the summer of 2014 from Borussia Mönchengladbach. Born on 30 April 1992 in Mönchengladbach itself, the German did not take long to make his name as one Europe's most promising young goalkeepers."""
#doc2 = '''Marc-Andre Ter Stegen nationality is German. He was born in Monchengladbach, Germany. Ter Stegen grew up in a football loving family. He started kicking the ball, playing in his family's yard with his brother at the age of 2. When he turned 4, his grandfather enrolled him into Borussia Monchengladbach's academy.'''
#doc3 = '''Ter Stegen started his amateur career as a striker. According to himself he had a wonderful time during this period of his amateur career and enjoyed being the goal scorer of the team.'''
#doc4 = '''Ter Stegen was Monchengladbach's first-choice goalkeeper in his final three seasons with Gladbach, playing 39, 45 and 36 games respectively. In total, He played 127 games for Gladbach's first team, leaving behind an incredible stat of 45 clean sheets.'''

# %%
a = f'''TEXT_SEP {cc.lower()} DOCS_SEP doc0: {doc1.lower()}''' # ''' #doc1: {doc1.lower()} doc2: {doc1.lower()} doc3: {doc1.lower()}'''
b = 'COM_SEP when started to play in barcelona TEXT_SEP'

# %%
with torch.no_grad():
    src_ = tokenizer(
                      a,
                      max_length=512,
                      truncation=True,
                      return_attention_mask=False,
                     )
    b_tok = tokenizer(b, return_tensors = 'pt', padding=True, add_special_tokens = False)
    forced_decoder_ids = list(enumerate(b_tok, 1))
    
    generated = model_edit.generate(torch.tensor(src_['input_ids']).view(1,-1).to(device), 
                                                  num_beams=5, 
#                                                       pad_token_id=tokenizer.pad_token_id, 
#                                                       bos_token_id=tokenizer.bos_token_id, 
#                                                       eos_token_id=tokenizer.eos_token_id,
                                                  num_return_sequences=1,
                                                  decoder_input_ids=b_tok['input_ids'].to(device),
                                         max_length=512)
    generated = generated.cpu()

    src_text = tokenizer.decode(src_['input_ids'], skip_special_tokens=True)
    print(f'\n\n---------- QUERY {i} ----------')
    print(f'Src query: {src_text}')
    # print(f'Tgt query: {tgt_text}')
    print(f'Generated:')

    for j in range(1):
        to_gen = generated[j]
        gen_text = tokenizer.decode(to_gen, skip_special_tokens=True)
        print(f'   {j}: {gen_text}')
# Out:
# ---------- QUERY 516 ----------
# Src query: TEXT_SEP marc-andré ter stegen (born 30 april 1992) is a german professional footballer who plays as a goalkeeper for la liga club barcelona and the germany national team. known for his reflexes, passing, and ball-playing ability, he has been often nicknamed as the berlin wall because of his reflexes and ball control abilities as a goalkeeper DOCS_SEP doc0: marc-andré ter stegen signed for fc barcelona in the summer of 2014 from borussia mönchengladbach. born on 30 april 1992 in mönchengladbach itself, the german did not take long to make his name as one europe's most promising young goalkeepers.
# Generated:
#    0: COM_SEP when started to play in barcelona TEXT_SEP marc-andré ter stegen (born 30 april 1992) is a german professional footballer who plays as a goalkeeper for la liga club barcelona and the germany national team. known for his reflexes, passing, and ball-playing ability, he has been often nicknamed as the berlin wall because of his reflexes and ball control abilities as a goalkeeper in barc he he was signed to fc barcelona, marc-andré ter stegen (born in mönchengladbach itself, the german did not take long to make his name as one europe's most promising young goalkeepers.

# %%
com, txt = extract_com8text_from_tgt(gen_text)
src_txt, doc = extract_text8docs_from_src(src_text)

# %%
com, txt
# Out:
# ('COM_SEP when started to play in barcelona',
#  "marc-andré ter stegen (born 30 april 1992) is a german professional footballer who plays as a goalkeeper for la liga club barcelona and the germany national team. known for his reflexes, passing, and ball-playing ability, he has been often nicknamed as the berlin wall because of his reflexes and ball control abilities as a goalkeeper in barc he he was signed to fc barcelona, marc-andré ter stegen (born in mönchengladbach itself, the german did not take long to make his name as one europe's most promising young goalkeepers.")

# %%
src_txt, doc
# Out:
# ('marc-andré ter stegen (born 30 april 1992) is a german professional footballer who plays as a goalkeeper for la liga club barcelona and the germany national team. known for his reflexes, passing, and ball-playing ability, he has been often nicknamed as the berlin wall because of his reflexes and ball control abilities as a goalkeeper',
#  "doc0: marc-andré ter stegen signed for fc barcelona in the summer of 2014 from borussia mönchengladbach. born on 30 april 1992 in mönchengladbach itself, the german did not take long to make his name as one europe's most promising young goalkeepers.")
