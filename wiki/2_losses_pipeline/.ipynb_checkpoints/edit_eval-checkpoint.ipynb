# %%
# !ls -l ../models/
# Out:
# total 28
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:30 't5-base stage 2 p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:22 't5-base stage 2 p(comment, x_t+1 | x_t, doc)_new'
# drwxrwxr-x 5 shapkin shapkin 4096 Jan 30 07:51 't5-small p(comment | x_t, x_t+1, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  6 10:32 't5-small stage 2 _ 2 losses _ full p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  5 21:28 't5-small stage 2 _ 2 losses p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb 16 10:34 't5-small stage 2 p(comment, x_t+1 | x_t, doc)'
# drwxrwxr-x 5 shapkin shapkin 4096 Feb  4 09:10 't5-small stage 2 p(comment, x_t+1 | x_t, doc)_new'

# %%
import os
os.environ['TOKENIZERS_PARALLELISM']='true'
os.environ['CUDA_VISIBLE_DEVICES']='3'

# %%
import sys
sys.path.append('..')

# %%
import re
import os
import torch
import json
import numpy as np
import pandas as pd
import seaborn as sns
import transformers
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from transformers import T5Tokenizer, T5TokenizerFast, T5ForConditionalGeneration
from transformers.tokenization_utils import PreTrainedTokenizer
from transformers.tokenization_utils_fast import PreTrainedTokenizerFast
from typing import Callable, Union, Tuple
from tqdm.notebook import tqdm
from collections import Counter
from torch import nn
from catalyst import dl
from catalyst.callbacks.periodic_loader import PeriodicLoaderCallback
from langdetect import detect
from easse.sari import corpus_sari
from rouge import Rouge 

from utils.dataset_utils import extract_com8text_from_tgt, extract_text8docs_from_src
from utils.dataset_utils import EditDataset, get_tgt, get_src, COM_SEP, TEXT_SEP_SRC, TEXT_SEP_TGT, DOCS_SEP
from utils.metrics_utils import PeerEditMetricsCallback
from utils.config import Config


DOCS_DIR = 'data'
PAGES_DIR = 'data'

# %%
CONFIG = Config()
CONFIG.seed = 1337
CONFIG.beam_size = 1

# %%
import random

random.seed(CONFIG.seed)
os.environ['PYTHONHASHSEED'] = str(CONFIG.seed)
np.random.seed(CONFIG.seed)
torch.manual_seed(CONFIG.seed)
torch.cuda.manual_seed(CONFIG.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Data preparing

# %%
mp = json.load(open(r"../data/column_mapper.json"))

train = pd.read_json(r'../data/new_train.json')
train.set_axis(mp.values(), axis='columns', inplace=True)

test = pd.read_json(r'../data/new_test.json')
test.set_axis(mp.values(), axis='columns', inplace=True)

val = pd.read_json(r'../data/new_val.json')
val.set_axis(mp.values(), axis='columns', inplace=True)
val1 = val.iloc[:600]

# %%
train.head()
# Out:
#    obj_id                                           old_text  \
# 0    1005  In rural regions of Germany, especially the Ha...
# 1      55  "This is the new WikiPedia!" \n-HomePage, the ...
# 2    2329  Ares (Ancient Greek:  , Μodern Greek: Άρης ) i...
# 3   17206  Peter Velhorn (born 24 November 1932) is a Ger...
# 4      47  Michael Palin was educated at Birkdale School,...
#
#                                             new_text  \
# 0  In rural regions of Germany, especially the Ha...
# 1  "This is the new WikiPedia!" \n-HomePage, the ...
# 2  Ares (Ancient Greek:  , Μodern Greek: Άρης ) i...
# 3  Peter Velhorn (24 November 1932 – 20 July 2016...
# 4  Michael Palin was educated at Birkdale School,...
#
#                                     comment  \
# 0                     /* Germany */ grammar
# 1                             Added subpage
# 2       repaired link to 'masculinity' ~~~~
# 3  Passed away 2016, look at German article
# 4             /* Early career */ added info
#
#                                                 docs  \
# 0  Apr 30, 2020 — Depending on whom you ask, May ...
# 1  English: Results of the 1929 New York City ald...
# 2  Apr 7, 2014 — Let's explore the essence of mas...
# 3  Peter Velhorn (24 November 1932 – 20 July 2016...
# 4  Michael Palin, Nightingale House, in Clapham, ...
#
#                                             diff           title  \
# 0                     this opportunity to party,         May Day
# 1            \n*/New York City Board of Aldermen  John M Wolfson
# 2  masculinity, integrity, and personal courage.            Ares
# 3                                 – 20 July 2016   Peter Velhorn
# 4  , Graeme Garden, Bill Oddie and Jonathan Lynn   Michael Palin
#
#                                       search_queries counter_found_docs  \
# 0       [May Day Germany this opportunity to party,]               [27]
# 1  [John M Wolfson \n*/New York City Board of Ald...            [10, 4]
# 2  [Ares masculinity, integrity, and personal cou...               [30]
# 3                    [Peter Velhorn  – 20 July 2016]               [23]
# 4  [Michael Palin  Early career , Graeme Garden, ...               [29]
#
#      section_name  is_good                                     docs_processed
# 0         Germany     True  DOC0: Apr 30, 2020 — Depending on whom you ask...
# 1                     True  DOC0: English: Results of the 1929 New York Ci...
# 2                     True  DOC0: Apr 7, 2014 — Let's explore the essence ...
# 3                     True  DOC0: Peter Velhorn (24 November 1932 – 20 Jul...
# 4   Early career      True  DOC0: Michael Palin, Nightingale House, in Cla...

# %%
CONFIG.src_max_len = 512
CONFIG.tgt_max_len = 512
CONFIG.pretrained = 't5-small'
CONFIG.pattern_path = '../models/t5-small stage 2 _ 2 losses _ full p(comment, x_t+1 | x_t, doc)'
CONFIG.batch_size = 4

tokenizer = T5Tokenizer.from_pretrained(CONFIG.pretrained, model_max_length=CONFIG.src_max_len)

# %% [markdown]
# **Make dataset**

# %%
#ds_train = EditDataset(train, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
ds_val = EditDataset(val1, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)
#ds_val_full = EditDataset(val, tokenizer, CONFIG, text_to_lower=True, comment_to_lower=True)

# %% [markdown]
# ## Model training

# %%
class EditModel(nn.Module):
    def __init__(self, 
                 pretrained: transformers.modeling_utils.PreTrainedModel, 
                 config: Config):
        super(EditModel, self).__init__()
        self.pretrained = pretrained
        

    def forward(self, 
                x: Tuple[torch.Tensor, torch.Tensor]):
        src, tgt = x
        
        tgt[tgt == 0] == -100
        
        loss = self.pretrained(
            input_ids = src,
            attention_mask = (src != 0).float(),
            labels=tgt,
        ).loss
        return loss
    
    
class Criterion(nn.Module):
    def __init__(self):
        super(Criterion, self).__init__()
        
    def forward(self, pred, tgt):
        return pred

# %%
CONFIG.device = 'cuda'

# %%
model_edit = EditModel(T5ForConditionalGeneration.from_pretrained(CONFIG.pretrained), CONFIG)
model_edit.load_state_dict(
    torch.load(f'{CONFIG.pattern_path}/checkpoints/model.best.pth', 
               map_location=CONFIG.device))
model_edit = model_edit.pretrained
model_edit.to(CONFIG.device)
model_edit.eval()
print('Success')
# Out:
# Success

# %%
from utils.print_diff_utils import diff_print, colored

# %%
device = CONFIG.device
CONFIG.beam_size = 3
idx_ = np.random.choice(len(ds_val), 20)

with torch.no_grad():
    for i in idx_:
        src_, tgt_ = ds_val[i]

        generated = model_edit.generate(torch.tensor(src_['input_ids']).view(1,-1).to(device), 
                                                      num_beams=CONFIG.beam_size, 
#                                                       pad_token_id=tokenizer.pad_token_id, 
#                                                       bos_token_id=tokenizer.bos_token_id, 
#                                                       eos_token_id=tokenizer.eos_token_id,
                                                          num_return_sequences=1,
                                                     max_length=512)
        generated = generated.cpu()

        src_text = tokenizer.decode(src_['input_ids'], skip_special_tokens=True)
        tgt_text = tokenizer.decode(tgt_['input_ids'], skip_special_tokens=True)
        
        tgt_comment, tgt_txt = extract_com8text_from_tgt(tgt_text)
        src_txt, _ = extract_text8docs_from_src(src_text)

        src_txt = diff_print(tgt_txt, src_txt)
        tgt_txt = diff_print(src_txt, tgt_txt)
        
        print(colored(f'\n\n---------- QUERY {i} ----------', 'red'))
        print(colored(f'X_t:\n', 'pink') + colored(src_txt) + '\n', sep='')
        print(colored(f'X_t+1:\n', 'pink') + colored(tgt_txt) + '\n', sep='')
        print(colored(f'Comment:', 'yellow') + colored(tgt_comment) + '\n', sep='')
        

        for j in range(1):
            to_gen = generated[j]
            gen_text = tokenizer.decode(to_gen, skip_special_tokens=True)
            gen_comment, gen_txt = extract_com8text_from_tgt(gen_text)
            
            gen_txt = diff_print(src_txt, gen_txt)
            print(colored(f'Gen Comment:', 'blue') + colored(gen_comment) + '\n', sep='')
            print(colored(f'gen X_t+1:\n', 'pink') + colored(gen_txt) + '\n', sep='')
            
        diff = val1.iloc[i]['diff']
        print(colored(f'Tgt diff:\n', 'bold') + colored(diff) + '\n', sep='')
        
        doc_str = '\n'.join(_.split('doc'))
        print(colored(f'Docs:\n', 'yellow') + colored(doc_str) + '\n', sep='')
# Out:
#
#
# ---------- QUERY 151 ----------
#  X_t:
#  a superset of the general midi standard, added several proprietary extensions. the most notable addition was the ability to address multiple banks of programs (instrument sounds) by using an additional pair of bank select controllers to specify up to 16384 'variation' sounds (cc#0 is bank select msb, and cc#32 is bank select lsb). other most notable features were 9 drum kits with 14 additional drum sounds each, control change messages for controlling the send level of sound effect blocks (cc#91-94), entering additional parameters (cc#98-101), portamento, sostenuto, soft pedal (cc#65-67), and model-specific sysex messages for setting various parameters of the synth engine. gs was introduced with the roland sound canvas line, which was also roland's first general midi synth module.
#
#  X_t+1:
#  a superset of the general midi standard, added several proprietary extensions. the most notable addition was the ability to address multiple banks of programs (instrument sounds) by using an additional pair of bank select controllers to specify up to 16384 'variation' sounds (cc#0 is bank select msb, and cc#32 is bank select lsb). other most notable features were 9 drum kits with 14 additional drum sounds each,  simultaneous percussion kits - up to 2 (channels 10/11),  control change messages for controlling the send level of sound effect blocks (cc#91-94), entering additional parameters (cc#98-101), portamento, sostenuto, soft pedal (cc#65-67), and model-specific sysex messages for setting various parameters of the synth engine. gs was  in 1991  introduced with the roland sound canvas line, which was also roland's first general midi synth module.
#
#  Comment: COM_SEP gs can play two simultaneous drumkits too
#
#  Gen Comment: COM_SEP /* general midi standard */ gs was superseded by gm 2 in 1999.
#
#  gen X_t+1:
#  a superset of the general midi standard, added several proprietary extensions. the most notable addition was the ability to address multiple banks of programs (instrument sounds) by using an additional pair of bank select controllers to specify up to 16384 'variation' sounds (cc#0 is bank select msb, and cc#32 is bank select lsb). other most notable features were 9 drum kits with 14 additional drum sounds each, control change messages for controlling the send level of sound effect blocks (cc#91-94), entering additional parameters (cc#98-101), portamento, sostenuto, soft pedal (cc#65-67), and model-specific sysex messages for setting various parameters of the synth engine. gs was  superseded by general midi 2 in 1999. however, gs was  introduced with the roland sound canvas line, which was also roland's first general midi synth module.
#
#  Tgt diff:
#   simultaneous Percussion Kits - up to 2 (
# hannels 10/11),
# ontrol C
#  1991 introduced
#
#  Docs:
#
# 0: number of notes: 32 simultaneous notes  midi channels: 16  simultaneous melodic instruments – up to 16 (all channels)  simultaneous percussion kits – up to 2 (
# 1: midi channels: 16 - simultaneous melodic instruments = up to 16 (all channels) - simultaneous percussion kits = up to 2 (channel 10/11
# 2: the gm 1 specification was superseded by general midi 2 in 1999; however, gm 1. simultaneous percussion kits - up to 2 (channels 10/11), control change
# 3: general midi level 2 is a group of extensions made to general midi level 1, which increases both. simultaneous percussion kits = up to 2 (channel 10/11)
# 4: to enable a number of unpitched percussion sounds to be played simultaneously, the specification also lays down specific individual notes that these are
# 5: gm itself was later revised to become gm level 2 in 1999 and included some. all 16 channels simultaneously (with channel 10 reserved for percussion)
#
#
#
# ---------- QUERY 189 ----------
#  X_t:
#  a typical episode will begin in the real world, where pablo will be engaging in some sort of activity. when encountering a problem or something he doesn't understand (like the loss of his own smell following a bath), the episode will transition into an animated 'art world', represented by pablo's drawings. there, pablo and the book animals will work together to solve whatever problem is at hand.
#
#  X_t+1:
#  a typical episode will begin in the real world, where pablo will be engaging in some sort of activity. when encountering a problem or something he doesn't understand (like the loss of his own smell following a bath), the episode will transition into an animated 'art world', represented by pablo's drawings. there, pablo and the book animals will work together to solve whatever problem is at hand.  add tony finnegan to list of writers in right hand column.
#
#  Comment: COM_SEP /* format */added tony finnegan’s name to list of writers. he wrote episodes 37, 38, and 41
#
#  Gen Comment: COM_SEP /* premise */ wikilinks
#
#  gen X_t+1:
#  a typical episode will begin in the real world, where pablo will be engaging in some sort of activity. when encountering a problem or something he doesn't understand (like the loss of his own smell following a bath), the episode will transition into an animated  art world (tv series),  represented by pablo's drawings. there, pablo and the book animals will work together to solve whatever problem is at hand.
#
#  Tgt diff:
#
# Add Tony Finnegan to list of writers in right hand column.
#
#  Docs:
#
# 0: pablo is a british children's television series that premiered on cbeebies on 2 october 2017. the series features a voice cast and writing team who are all autistic
# 1: actor: pablo. tony finnegan is known for pablo (2017) and umbrella (2019).. pablo. 7.8. tv series. noasaurus; additional voices(voice)
# 2: pablo: created by gráinne mcguinness. with oliver burns, william burns, jake williamson, michael white. an autistic boy called pablo draws animal friends to
# 3: william and smith athletics, 330 south ocean blvd palm beach, nepw auburn me,. best machine gun in black ops 2 zombies, xiaolin monks tv show
# 4: kommissionierer lidl, mini cooper stereo system, drinkboy pisco sour, sg-01-002, mission eagles high school football, crocea clam lifespan, castle tv show
# 5: political animal series wiki, hierbas contra el cholesterol y. what is an author, la tempestad capitulo 93 dailymotion video, yugioh 2014 band list,
#
#
#
# ---------- QUERY 232 ----------
#  X_t:
#  frank herron (born july 9, 1994) is an american football defensive  end  for the carolina panthers of the national football league (nfl). he played college football at lsu. he has also been a member of the new england patriots, seattle seahawks, tennessee titans, miami dolphins, and detroit lions.
#
#  X_t+1:
#  frank herron (born july 9, 1994) is an american football defensive  tackle  for the carolina panthers of the national football league (nfl). he played college football at lsu. he has also been a member of the new england patriots, seattle seahawks, tennessee titans, miami dolphins, and detroit lions.
#
#  Comment: COM_SEP dt per most recent panthers depth chart - https://www.panthers.com/team/depth-chart
#
#  Gen Comment: COM_SEP update
#
#  gen X_t+1:
#  frank herron (born july 9, 1994) is an american football defensive  tackle who is a free agent.  he played college football at lsu. he has also been a member of the new england patriots, seattle seahawks, tennessee titans, miami dolphins, and detroit lions.
#
#  Tgt diff:
#   tackle for the
#
#  Docs:
#
# 0: frank herron (born july 9, 1994) is an american football defensive tackle who is a free agent. [1] he played college football at lsu. he has also been a member of the new england patriots, seattle seahawks, tennessee titans, miami dolphins, and detroit lions. contents 1 professional career 1.1 new england patriots 1.2 seattle seahawks
# 1: a 6-4, 305-pound tackle from lsu, herron went undrafted in 2018. he was a solid contributor for the tigers, racking up 67 total tackles, two sacks, with three forced fumbles and one fumble recovery
# 2: frank herrons career highs total tackles: 8 vs. texas am, 2015 tackles for loss: 1.0, 4x (last: vs. alabama, 2016; first: vs. auburn, 2015) sacks: 1.0, twice (last: vs. alabama, 2016; first
# 3: herron signed with panthers practice squad in september, but he was let go with an injury settlement thursday. since 2019, the 6-foot-5 defensive end suited up for eight games (seven with
# 4: frank herron is an american football defensive tackle for the carolina panthers of the national football league.[1] he played college football at lsu. he has also been a member of the new england patriots, seattle seahawks, tennessee titans, miami dolphins
#
#
# ---------- QUERY 167 ----------
#  X_t:
#  01. end of the world 02. love for air 03. normal people 04. everything 05. do it for yourself 06. honest to god 07. that feeling and the sound 08. dive 09. better friend 10. all the time 11. 365 12. crying wolf 13. wreckage in the rubble, ross leighton  -  vocals, guitar, songwriter, production * greg walkinshaw  -  vocals, drums, songwriter, production * marc strain  -  vocals, bass, songwriter, production
#
#  X_t+1:
#  01. end of the world 02. love for air 03. normal people 04. everything 05. do it for yourself 06. honest to god 07. that feeling and the sound 08. dive 09. better friend 10. all the time 11. 365 12. crying wolf 13. wreckage in the rubble, ross leighton  –  vocals, guitar, songwriter, production * greg walkinshaw  –  vocals, drums, songwriter, production * marc strain  –  vocals, bass, songwriter, production
#
#  Comment: COM_SEP fixed [[mos:dash|dashes]] using a [[user:gregu/dashes.js|script]]
#
#  Gen Comment: COM_SEP /* track listing */ copyedit
#
#  gen X_t+1:
#
#  X_t+1:
#  keyarris garrett (born september 26, 1992) is an american football wide receiver who is currently a free agent. he played college football at tulsa, and was signed by the carolina panthers as an undrafted free agent in 2016.  he was the leading receiver in division i fbs football in 2015 with 1,588 receiving yards.
#
#  Comment: COM_SEP add a bit
#
#  Gen Comment: COM_SEP added content
#
#  gen X_t+1:
#  keyarris garrett (born september 26, 1992) is an american football wide receiver who is currently a free agent.  he is currently leading receiver in division i fbs football in 2015 with 1,588 receiving yards.  he played college football at tulsa, and was signed by the carolina panthers as an undrafted free agent in 2016.
#
#  Tgt diff:
#    He was the leading receiver in Division I FBS football in 2015 with 1,588 receiving yards.
#
#  Docs:
#
# 0: during the 2015 season, he had 96 receptions for 1,588 yards and eight touchdowns. he led all division i players in rushing yardage for the 2015 season
# 1: nov 6, 2021 — keyarris garrett is an american football wide receiver for the toronto argonauts of the canadian football league (cfl). he played college
# 2: keyarris garrett (1) wide receiver - tulsa –– a three-year letterwinner and. 32 career games and has 23 starts... has 1,621 career receiving yards and
# 3: mar 16, 2016 — why isn't anyone talking about keyarris garrett? the nation's leading wide. oh, and he led the ncaa with 1,588 receiving yards last year
# 4: he was the leading receiver in division i fbs football in 2015 with 1,588 receiving yards. according to astrologers, keyarris garrett's zodiac sign is
# 5: keyarris garrett - tulsa (wr). keyarris garrett. school: tulsa. position: wr. 6-4, 221lb (193cm, 100kg). 1. keyarris garrett overview; game logs. 2015
#
#
#
# ---------- QUERY 82 ----------
#  X_t:
#  to use this userbox, insert the code  user:wildchild300/navajo  to use this userbox, insert the code  user:wildchild300/x  ambassadors
#
#  X_t+1:
#  to use this userbox, insert the code  user:wildchild300/userboxes/navajo  to use this userbox, insert the code  user:wildchild300/userboxes/x  ambassadors
#
#  Comment: COM_SEP changed links
#
#  Gen Comment: COM_SEP /* userboxes */ user:wildchild300/navajo
#
#  gen X_t+1:
#  to use this userbox, insert the code user:wildchild300/navajo to use this userbox, insert the code user:wildchild300/x ambassadors  to use this userbox, insert the code user:wildchild300/navajo to use this userbox, insert the code user:wildchild300/x ambassadors __toc__
#
#  Tgt diff:
#   Userboxes/
# Userboxes/
#
#  Docs:
#
# 0: this template creates a userbox that indicates the number of children of a user. useedit. to use this userbox template, place the following line of wiki
# 1: templates relating to family. the pages listed in this category are meant to be user templates, including userboxes. this page is part of wikipedia's
# 2: select code output method this is version two of the script used to create userboxes, written by me, the english wikipedia user the userboxer. all questions,
# 3: abuse (see child abuse, sexual abuse, physical abuse, emotional abuse.). adolescents (see also teens, youth.). adoption assistance (see also adoption subsidy.
#
#
# ---------- QUERY 84 ----------
#  X_t:
#  , the village has a total number of 28 houses and the population of 198 of which  include  99 are males while 99 are females. according to the report published by census india in 2011, out of the total population of the village 0 people are from schedule caste and the village does not have any schedule tribe population so far.
#
#  X_t+1:
#  , the village has a total number of 28 houses and the population of 198 of which 99 are males while 99 are females. according to the report published by census india in 2011, out of the total population of the village 0 people are from schedule caste and the village does not have any schedule tribe population so far.
#
#  Comment: COM_SEP clean up, replaced: of which include  of which
#
#  Gen Comment: COM_SEP /* demography */clean up, replaced: of which include  of which using [[project:awb|awb]]
#
#  gen X_t+1:
#  the village has a total number of 28 houses and the population of 198 of which include 99 are males while 99 are females. according to the report published by census india in 2011, out of the total population of the village 0 people are from schedule caste and the village does not have any schedule tribe population so far.
#
#  Tgt diff:
#   99 are
#
#  Docs:
#
# 0: tenaniwal is a village in batala in gurdaspur district of punjab state, india. it is located 30 kilometres (19 mi) from sub district headquarter,
# 1: the tenaniwal village has population of 198 of which 99 are males while 99 are females as per population census 2011
# 2: the total population of tenaniwal is 198 out of which 99 are males and 99 are females thus the average sex ratio of tenaniwal is 1,000
# 3: tenaniwal has a total population of 198 peoples, out of which male population is 99 while female population is 99. literacy rate of tenaniwal village is
# 4: get information on tenaniwal (59) village map, total geographical area,. as far as male population concern the number of population is 99 of the village
# 5: data presented for 2020 and 2021 are vintage 2021 population estimates. data presented for 2010 through 2019 are vintage 2020 estimates. each year the u.s.
#
#
#
# ---------- QUERY 72 ----------
#  X_t:
#  in epistemology, an axiom is a self-evident truth upon which other knowledge must rest, from which other knowledge is built up. not all epistemologists agree that any axioms, understood in that sense, exist. in mathematics, an axiom is not necessarily a self-evident truth, but rather a formal logical expression used in a deduction to yield further results. mathematics distinguishes two types of axioms: logical axioms and non-logical axioms.
#
#  X_t+1:
#  in epistemology, an axiom is a self-evident truth upon which other knowledge must rest, from which other knowledge is built up. not all epistemologists agree that any axioms, understood in that sense, exist. in  logic and  mathematics, an axiom is not necessarily a self-evident truth, but rather a formal logical expression used in a deduction to yield further results. mathematics distinguishes two types of axioms: logical axioms and non-logical axioms.
#
#  Comment: COM_SEP ins [logic]
#
#  Gen Comment: COM_SEP axioms aren't necessarily a self-evident truth.
#
#  gen X_t+1:
#  in epistemology, an axiom is a self-evident truth upon which other knowledge must rest, from which other knowledge is built up. not all epistemologists agree that any axioms, understood in that sense, exist. in mathematics, an axiom is not necessarily a self-evident truth, but rather a formal logical expression used in a deduction to yield further results. mathematics distinguishes two types of axioms: logical axioms and non-logical axioms.  in mathematics, an axiom is not necessarily a self-evident truth, but may or might not be self-evident.
#
#  Tgt diff:
#   logic and mathematics, an axiom is not
#
#  Docs:
#
# 0: in most cases, a non-logical axiom is simply a formal logical expression used in deduction to build a mathematical theory, and might or might not be self-
# 1: mathematicians assume that axioms are true without being able to prove them. however this is not as problematic as it may seem, because axioms are either
# 2: dec 29, 2015 — you're right that axioms cannot be proven - they are propositions that we assume are true. commutativity of addition of natural numbers is not an axiom. it is
# 3: mar 17, 2015 — the axioms may not be explicitly stated but they are always there. mathematical theorems are about objects (triangles, real numbers, functions, sets, matrices,
# 4: mar 22, 2013 — may also be considered a logical axiom, since its interpretation “if for all x x the formula a a is true, then the formula a a is true for an
# 5: 1. (logic and math.) a self-evident and necessary truth, or a proposition whose truth is so evident as first sight that no reasoning or demonstration
#
#
#
# ---------- QUERY 265 ----------
#  X_t:
#  arachnophobia is the  intense and irrational  fear of spiders and other arachnids such as scorpions.heather hatfield. "the fear factor: phobias". webmd.com
#
#  X_t+1:
#  arachnophobia is  an anxiety disorder centered around  the fear of spiders and other arachnids such as scorpions.heather hatfield. "the fear factor: phobias". webmd.com
#
#  Comment: COM_SEP the phrase "intense and irrational fear" lacks the sensitivity to deal with a subcategory of anxiety disorder.
#
#  Gen Comment: COM_SEP /* top */ added links to fear of spiders and scorpions.
#
#  gen X_t+1:
#  arachnophobia is the intense and irrational  fear of spiders, as well as the intense  fear of spiders and other arachnids such as scorpions.heather hatfield. "the fear factor: phobias". webmd.com
#
#  Tgt diff:
#    an anxiety disorder centered around
#
#  Docs:
#
# 0: jan 16, 2020 — arachnophobia, or a fear of spiders, is an intense and overwhelming response to arachnids. a mental health professional can help you work
# 1: jun 3, 2020 — arachnophobia is an intense and irrational fear of spiders or arachnids. people with this condition may show symptoms similar to a panic attack
# 2: jun 23, 2021 — being fearful of spiders is entirely different than having a phobia of spiders or arachnophobia. arachnophobia is an anxiety disorder that
# 3: jan 14, 2022 — often portrayed in movies, television, and other media, arachnophobia is an intense and excessive fear of spiders
# 4: dec 16, 2020 — panic attack are common with arachnophobia:the person suffering from may get a panic attack once they see a spider or when someone tells them
# 5: mar 14, 2022 — like other specific phobias, spider phobia falls within a category of anxiety disorders, which may or may not be genetic. fear of spiders can
#
#
#
# ---------- QUERY 390 ----------
#  X_t:
#  a canonical name record (abbreviated as cname record) is a type of resource record in the domain name system (dns) that maps one domain name (an alias) to another (the canonical name). this can prove convenient when running multiple services (like an  ftp server  and a web server, each running on different ports) from a single ip address. one can, for example, point ftp.example.com and www.example.com to the dns entry for example.com, which in turn has an a record which points to the ip address. then, if the ip address ever changes, one only has to record the change in one place within the network: in the dns a record for example.com. cname records must always point to another domain name, never directly to an ip address.
#
#  X_t+1:
#  a canonical name record (abbreviated as cname record) is a type of resource record in the domain name system (dns) that maps one domain name (an alias) to another (the canonical name). this can prove convenient when running multiple services (like an and a web server, each running on different ports) from a single ip address. one can, for example, point ftp.example.com and www.example.com to the dns entry for example.com, which in turn has an a record which points to the ip address. then, if the ip address ever changes, one only has to record the change in one place within the network: in the dns a record for example.com. cname records must always point to another domain name, never directly to an ip address.
#
#  Comment: COM_SEP undid revision 988772580 by [[special:contributions/2601:81:8400:130:95c3:ecfa:b4e6:22aa|2601:81:8400:130:95c3:ecfa:b4e6:22aa]] ([[user talk:2601:81:8400:130:95c3:ecfa:b4e6:22aa|talk]]) unexplained removal of useful internal links
#
#  Gen Comment: COM_SEP /* top */ copyedit
#
#  gen X_t+1:
#  a canonical name record (abbreviated as cname record) is a type of resource record in the domain name system (dns) that maps one domain name (an alias) to another (the canonical name). this can prove convenient when running multiple services (like an ftp server and a web server, each running on different ports) from a single ip address. one can, for example, point ftp.example.com and www.example.com to the dns entry for example.com, which in turn has an a record which points to the ip address. then, if the ip address ever changes, one only has to record the change in one place within the network: in the dns a record for example.com. cname records must always point to another domain name, never directly to an ip address.
#
#  Tgt diff:
#    and a web
#
#  Docs:
#
# 0: to add an alias (cname) resource record to a zone. applies to: windows server 2022, windows server 2019, windows server 2016. you can use this procedure to add an alias canonical name (cname) resource record for your web server to a zone in dns on your domain controller. with cname records, you can use more than one name to point to a single host, making it easy to do such things as host both a file transfer protocol (ftp) server and a web server on the same computer
# 1: a hostname defined in a cname record must have no other resource records of other types (mx, a, etc.), except for dnssec records like rrsig and nsec. cname records can point to other cname records, but this is not considered a good practice as it is inefficient. mx and ns records must never point to a cname alias. domains that are used for e-mail may not have a cname record - this can have undesirable results with different mail servers. cnames and alternative record types
# 2: a cname record is a standard dns resource record supported by all rf
#
#
# ---------- QUERY 438 ----------
#  X_t:
#  bahati is a constituency of the national assembly of zambia.bahati national assembly of zambia it covers the northern part of mansa and a rural area to the north of the city in luapula province.
#
#  X_t+1:
#  bahati is a constituency of the national assembly of zambia.bahati national assembly of zambia it covers the northern part of mansa and a rural area to the north of the city in  mansa district of  luapula province.
#
#  Comment: COM_SEP suggested change in display
#
#  Gen Comment: COM_SEP /* top */clean up, added [[cat:o|orphan]] tag using [[project:awb|awb]]
#
#  gen X_t+1:
#  bahati is a constituency of the national assembly of zambia.bahati national assembly of zambia it covers the northern part of mansa and a rural area to the north of the city in luapula province.
#
#  Tgt diff:
#    Mansa District of
#
#  Docs:
#
# 0: bahati is a constituency of the national assembly of zambia.[1] it covers the northern part of mansa and a rural area to the north of the city in mansa
# 1: the 2022 sahrds themed: " a journey to sustainability: protecting civic space through strengthening institutions for and networks of environmental and human
# 2: which to hold the parliamentary, and local government by-elections in bahati constituency of mansa district and roan constituency of luanshya district
# 3: may 22, 2016 — like most rural constituencies, the main economic activity for bahati constituency, located in mansa district of luapula province,
# 4: dec 16, 2021 — pipoz parliament we are in bahati constituency of mansa district,. leevan chibombwe and the mayor of mansa his worship njikho musuku
# 5: constituency: mongu central political party: united party for national development (upnd) portfolio: back bench -. hon., mr. mubita anakoka, mp
#
#
#
# ---------- QUERY 346 ----------
#  X_t:
#  keyarris garrett (born september 26, 1992) is an american football wide receiver who is currently a free agent. he played college football at tulsa, and was signed by the carolina panthers as an undrafted free agent in 2016.
#
#  X_t+1:
#  keyarris garrett (born september 26, 1992) is an american football wide receiver who is currently a free agent. he played college football at tulsa, and was signed by the carolina panthers as an undrafted free agent in 2016.  he was the leading receiver in division i fbs football in 2015 with 1,588 receiving yards.
#
#  Comment: COM_SEP add a bit
#
#  Gen Comment: COM_SEP added content
#
#  gen X_t+1:
#  keyarris garrett (born september 26, 1992) is an american football wide receiver who is currently a free agent.  he is currently leading receiver in division i fbs football in 2015 with 1,588 receiving yards.  he played college football at tulsa, and was signed by the carolina panthers as an undrafted free agent in 2016.
#
#  Tgt diff:
#    He was the leading receiver in Division I FBS football in 2015 with 1,588 receiving yards.
#
#  Docs:
#
# 0: during the 2015 season, he had 96 receptions for 1,588 yards and eight touchdowns. he led all division i players in rushing yardage for the 2015 season
# 1: nov 6, 2021 — keyarris garrett is an american football wide receiver for the toronto argonauts of the canadian football league (cfl). he played college
# 2: keyarris garrett (1) wide receiver - tulsa –– a three-year letterwinner and. 32 career games and has 23 starts... has 1,621 career receiving yards and
# 3: mar 16, 2016 — why isn't anyone talking about keyarris garrett? the nation's leading wide. oh, and he led the ncaa with 1,588 receiving yards last year
# 4: he was the leading receiver in division i fbs football in 2015 with 1,588 receiving yards. according to astrologers, keyarris garrett's zodiac sign is
# 2: calibre: directed by matt palmer. with jack lowden, martin mccann, tony curran, ian pirie. a shocking deed turned their weekend trip into a nightmare
# 3: calibre ; film run: 101' ; screenplay: matt palmer ; cast: jack lowden, martin mccann, tony curran, ian pirie, kate bracken, cal macaninch, cameron jack, george
# 4: jul 1, 2018 — the story follows soon-to-be-a-dad vaughn (jack lowden) who celebrates his engagement and future fatherhood by agreeing to a hunting trip with
# 5: oct 19, 2021 — an emotionally exhausting film, calibre examines the limits of humanity, friendship, cruelty, and cover-ups. all of which leads to
#
#
# ---------- QUERY 93 ----------
#  X_t:
#  stoke city football club (known as stoke football club until 1925) is a football club from stoke-on-trent in  england.  the club is reputedly the second-oldest football league club in the world, after notts county f.c., and claims to have been formed in 1863 (disputed by some, who claim it to be 1868). the club’s nickname is the potters and its home kit consists of a red & white vertical-striped shirt with white shorts. the club is managed by johan boskamp. it plays in the football league championship and is one of the twelve founder-members of the football league.
#
#  X_t+1:
#  stoke city football club (known as stoke football club until 1925) is a football club from stoke-on-trent in  england (the other league club in the city being port vale f.c.).  the club is reputedly the second-oldest football league club in the world, after notts county f.c., and claims to have been formed in 1863 (disputed by some, who claim it to be 1868). the club’s nickname is the potters and its home kit consists of a red & white vertical-striped shirt with white shorts. the club is managed by johan boskamp. it plays in the football league championship and is one of the twelve founder-members of the football league.
#
#  Comment: COM_SEP port vale
#
#  Gen Comment: COM_SEP port vale football club
#
#  gen X_t+1:
#  stoke city football club (known as stoke football club until 1925) is a football club from stoke-on-trent in england. the club is reputedly the second-oldest football league club in the world, after notts county f.c., and claims to have been formed in 1863 (disputed by some, who claim it to be 1868). the club’s nickname is the potters and its home kit consists of a red & white vertical-striped shirt with white shorts. the club is managed by johan boskamp. it plays in the  english  football league championship and is one of the twelve founder-members of the football league.  it is also the name of the only football league club not to be named after a football league.
#
#  Tgt diff:
#    (the other league club in the city being Port Vale F.C.).
#
#  Docs:
#
# 0: in english football, the potteries derby is the local derby between the two major clubs in the city of stoke-on-trent – port vale and stoke city,. stoke-on-trent is the least populous city to have two football league
# 1: port vale football club are a professional football club based in burslem, stoke-on-trent, england, which compete in efl league one.. vale are the only english football league club not to be named after a
# 2: nov 24, 2022 — port vale and stoke city played each other five times, recording two wins each and a draw as they slugged it out in what is now league one, the
# 3: oct 9, 2020 — port vale have made clear they don't want to be competing against premier league b teams in the football league
# 4: port vale football club was formed in 1876 and took its name from the venue. this rekindled the long awaited local derbies with stoke city and all went
# 5: come and watch championship league football at stoke city and take in the infectious. port vale football club play in the english football league one
#
#
#
# ---------- QUERY 22 ----------
#  X_t:
#  the reduction compass or proportional dividers is a geometry tool with asymmetric-length branches to allow performing homothetic transformations, reproducing a pattern while enlarging or reducing its size and conserving angles.
#
#  X_t+1:
#  the reduction compass or proportional dividers is a geometry tool with asymmetric-length branches to allow performing homothetic transformations, reproducing a pattern while enlarging or reducing its size and conserving angles.  it was invented by fabrizio mordente before 1567.
#
#  Comment: COM_SEP add ref
#
#  Gen Comment: COM_SEP expand.
#
#  gen X_t+1:
#  the reduction compass or proportional dividers is a geometry tool with asymmetric-length branches to allow performing homothetic transformations, reproducing a pattern while enlarging or reducing its size and conserving angles.  it was invented by fabrizio mordente before 1567.
#
#  Tgt diff:
#    It was invented by Fabrizio Mordente before 1567.
#
#  Docs:
#
# 0: he is best known for his invention of the "proportional eight-pointed compass" which has two arms with cursors that allow the solution of problems in measuring
# 1: the reduction compass or proportional dividers is a geometry tool with asymmetric-length. it was invented by fabrizio mordente before 1567
# 2: by f mordente — fabrizio mordente produced a first version of his compass in 1554. this was a four 4 point reduction compass with a ratio 1:60 between points, which served to
# 3: new theories for new instruments: fabrizio mordente's proportional compass and the genesis of giordano bruno's atomist geometry
# 4: the proportional eight spike compass, invented by fabrizio mordente (1532–1608). both the reduction compass and the proportional compass are based on the
# 5: jan 4, 2021 — the history of his scientific career began in venice in 1567, where he published a treatise for his new compass (see the compass of fabrizio
#
#
#
# ---------- QUERY 370 ----------
#  X_t:
#   :this article is about the 1955 film. for the remake, see the ladykillers (2004 film). for other uses, see ladykillers.  the ladykillers is a 1955 british black comedy film made by ealing studios. directed by alexander mackendrick, it stars katie johnson, alec guinness, cecil parker, herbert lom, peter sellers, danny green, and jack warner. american william rose wrote the screenplay, for which he was nominated for an academy award for writing original screenplay and won the bafta award for best british screenplay. he claimed to have dreamt the entire film and merely had to remember the details when he awoke.
#
#  X_t+1:
#  the ladykillers is a 1955 british black comedy film made by ealing studios. directed by alexander mackendrick, it stars katie johnson, alec guinness, cecil parker, herbert lom, peter sellers, danny green, and jack warner. american william rose wrote the screenplay, for which he was nominated for an academy award for writing original screenplay and won the bafta award for best british screenplay. he claimed to have dreamt the entire film and merely had to remember the details when he awoke.
#
#  Comment: COM_SEP standardized hatnote
#
#  Gen Comment: COM_SEP standardized hatnote
#
#  gen X_t+1:
#  :this article is about the 1955 film. for the remake, see the ladykillers (2004 film). for other uses, see ladykillers. the ladykillers  (film)  is a 1955 british black comedy film made by ealing studios. directed by alexander mackendrick, it stars katie johnson, alec guinness, cecil parker, herbert lom, peter sellers, danny green, and jack warner. american william rose wrote the screenplay, for which he was nominated for an academy award for writing original screenplay and won the bafta award for best british screenplay. he claimed to have dreamt the entire film and merely had to remember the details when he awoke.
#
#  Tgt diff:
#   e Ladykillers is a
# British black comedy
#  made by Ealing Studios
# Directed
#
#  Docs:
#
# 0: five oddball criminals planning a bank robbery rent rooms on a cul-de-sac from an octogenarian widow under the pretext that they are classical musicians
# 1: the lady the gang were intent on doing away with was a dear little old actress, kate johnson, who had played lots of small parts in films. it was curious to see
# 2: oct 25, 2015 — the ladykillers review – the greatest comedy caper. (alexander mackendrick, 1955; studiocanal, u, dvd/blu-ray)
# 3: in director alexander mackendrick's and one of ealing studio's best slapstick farces - this post-war, black comedy and crime-caper story received an academy
# 4: oct 29, 2020 — the ladykillers, the last of ealing studios' acclaimed comedies made before their complex was bought by the bbc and the brand absorbed into
# 5: a page for describing ymmv: ladykillers (1955). the film awesome music: boccherini's minuet note from string quintet in e major, op. 11, no. 5, which...
#
#
# ---------- QUERY 203 ----------
#  X_t:
#  amy hart redford (born october 22, 1970) is an american actress, director and producer. she is the daughter of academy award-winning film director and actor robert redford and his former wife lola van wagenen.the new york times
